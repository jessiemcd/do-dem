# %% [markdown]
# An example notebook to do a DEM with NuSTAR, AIA (and possibly XRT) with the xrt_dem_iterative2.pro DEM method. First, makes lightcurves to inform your time interval selection.
#
# If you don't want to deal with the aia error tables yet, you can always ignore that line and
# set real_aia_err=False in the dem call at the end of the notebook to use a flat uncertainty.

# %%
#AIA Error table - set path to location in your system.
errortab='/Users/jessieduncan/ssw/sdo/aia/response/aia_V3_error_table.txt'

#Sunpy data directory (or wherever else you store your downloaded AIA data)
sunpy_dir='/Users/jessieduncan/sunpy/data/'

#Path to top-level do-dem directory - edit for your system.
path_to_dodem = '/Users/jessieduncan/do-dem/'
from sys import path as sys_path
sys_path.append(path_to_dodem+'/dodem/')

#do-dem
import lightcurves as lc
import region_fitting as rf
import nustar_dem_prep as nu
import dodem

#Basics
import numpy as np
import importlib
import matplotlib.pyplot as plt
from astropy import units as u

#Time
import matplotlib.dates as mdates
import astropy.time
import datetime

#File wrangling
import glob
import pickle
import os
import pathlib
os.getcwd()
# Out:
# '/Users/jessieduncan/do-dem'

# %% [markdown]
# First, let's take a look at the NuSTAR lightcurves.

# %%
#Name your working directory
working_dir='./initial_dem/'

#Make a new working directory for prepped data/etc if it doesn't yet exist
save_path = pathlib.Path(working_dir)
if not save_path.exists():
    save_path.mkdir()

#Set path to obsid directory - initial pipeline should have been run already.
datapath='/Users/jessieduncan/nustar/may-2018/5_29pixpos/80410205001/'
obsid='80410205001'

#Comment second line if you're not using this same example nustar orbit
#Edit it to include only the desired time interval (default- all times in file) once you've run this once
timerange=[]
timerange=[datetime.datetime(2018, 5, 29, 22, 22), datetime.datetime(2018, 5, 29, 23, 20)]

evtA = glob.glob(datapath+'/event_cl/*A06_cl.evt')
evtB = glob.glob(datapath+'/event_cl/*B06_cl.evt')
hkA  = glob.glob(datapath+'/hk/*A_fpm.hk')
hkB  = glob.glob(datapath+'/hk/*B_fpm.hk')

importlib.reload(lc)
lc.prepare_nustar_lightcurves(evtA, evtB, hkA, hkB, timebin=15, erange=[2.,4.], 
                              livetime_corr=True, save_dir=working_dir)
lc.prepare_nustar_lightcurves(evtA, evtB, hkA, hkB, timebin=15, erange=[4.,6.], 
                              livetime_corr=True, save_dir=working_dir)
lc.prepare_nustar_lightcurves(evtA, evtB, hkA, hkB, timebin=15, erange=[6.,10.], 
                              livetime_corr=True, save_dir=working_dir)

lc.plot_nustar_lightcurves(eranges = [[2.,4.],[4.,6.],[6.,10.]],
                           timerange=timerange, save_dir=working_dir)
# Out:
# Using time limits:
# [datetime.datetime(2018, 5, 29, 22, 22), datetime.datetime(2018, 5, 29, 23, 20)]

# %% [markdown]
# Now, let's pick some initial time intervals for DEMs - how about every ten minutes?
#
# Note: later, you may want to make NuSTAR-statistics informed DEM intervals. Functionality for this is in nustar_dem_prep.find_intervals().

# %%
# #DEFINE ONE OR MORE 'MACRO INTERVALS' AND THEN MAKE SHORTER DEM TIME INTERVALS
macro_interval = [astropy.time.Time('2018-05-29T22:22:00', scale='utc', format='isot'),
                    astropy.time.Time('2018-05-29T23:19:00', scale='utc', format='isot')]

mins=10
time_intervals=[]
checktime = macro_interval[0]
while checktime < macro_interval[1]:
    time_intervals.append([checktime, checktime+mins*u.min])
    checktime = checktime+mins*u.min
    
    
count=0    
for t in time_intervals:
    print(count, t[0].strftime('%H-%M-%S'), t[1].strftime('%H-%M-%S'))
    count+=1
# Out:
# 0 22-22-00 22-32-00
# 1 22-32-00 22-42-00
# 2 22-42-00 22-52-00
# 3 22-52-00 23-02-00
# 4 23-02-00 23-12-00
# 5 23-12-00 23-22-00

# %% [markdown]
# Now, for the first time interval, let's find a good NuSTAR DEM region. For starters, we'll use this for AIA (and XRT, if available) as well. Note that given the NuSTAR pointing uncertainty, it's probably not the best choice for an AIA/XRT region. However, we will use it for an initial run.
#
# Note – this is the first cell that uses aspects of the NuSTAR pipeline. If you have not done so already, you'll need to quit the session and go back and initialize heasoft before opening this notebook. (If you don't, this will fail with an empty nuscreen_output.txt file.)
#
# We will be running aspects of the pipeline as a subprocess. To do this, you will need to make changes to your .bashrc or .cshrc file, as described in: https://heasarc.gsfc.nasa.gov/lheasoft/scripting.html

# %%
importlib.reload(nu)

gtifile=datapath+'event_cl/nu'+obsid+'A06_gti.fits'
regfile=path_to_dodem+'starter_region.reg'
time_interval=time_intervals[0]

nu.make_nustar_products(time_interval, 'A', gtifile, datapath, regfile, working_dir, edit_regfile=True,
                         nofit=True, pile_up_corr=True, clobber=True, nuradius=150, path_to_dodem=path_to_dodem)
# Out:
# ARF File:  ['./initial_dem/22-22-00_22-32-00/nu80410205001A06_0_p_sr.arf']
# RMF File:  ['./initial_dem/22-22-00_22-32-00/nu80410205001A06_0_p_sr.rmf']
# PHA File:  ['./initial_dem/22-22-00_22-32-00/nu80410205001A06_0_p_sr.pha']
# ARF File:  ['./initial_dem/22-22-00_22-32-00/nu80410205001A06_0_4_p_sr.arf']
# RMF File:  ['./initial_dem/22-22-00_22-32-00/nu80410205001A06_0_4_p_sr.rmf']
# PHA File:  ['./initial_dem/22-22-00_22-32-00/nu80410205001A06_0_4_p_sr.pha']
# ARF File:  ['./initial_dem/22-22-00_22-32-00/nu80410205001A06_21_24_p_sr.arf']
# RMF File:  ['./initial_dem/22-22-00_22-32-00/nu80410205001A06_21_24_p_sr.rmf']
# PHA File:  ['./initial_dem/22-22-00_22-32-00/nu80410205001A06_21_24_p_sr.pha']
# 100% [............................................................................] 449120 / 449120No region fitting: using 150 arcsec circle around COM
# ***Warning: You do not have an up-to-date version of Xspec.init
#       in your ~/.xspec directory.  It is recommended that you move
#       your old Xspec.init aside and start up XSPEC again.  This will
#       place a new version Xspec.init in your directory, which you may
#       then modify using your old settings.
# ***Warning: You do not have an up-to-date version of Xspec.init
#       in your ~/.xspec directory.  It is recommended that you move
#       your old Xspec.init aside and start up XSPEC again.  This will
#       place a new version Xspec.init in your directory, which you may
#       then modify using your old settings.
# ***Warning: You do not have an up-to-date version of Xspec.init
#       in your ~/.xspec directory.  It is recommended that you move
#       your old Xspec.init aside and start up XSPEC again.  This will
#       place a new version Xspec.init in your directory, which you may
#       then modify using your old settings.
# 0.8403527022341111

# %% [markdown]
# Now, we'll take the NuSTAR output region file and use it to make a dictionary that will be used to create a region object for AIA/XRT in the DEM data prep stage.

# %%
timestring = time_interval[0].strftime('%H-%M-%S')
stopstring = time_interval[1].strftime('%H-%M-%S')
timestring=timestring+'_'+stopstring
    
regfile=working_dir+timestring+'/nu'+obsid+'A06_0_p_cl_sunpos_COM_region.reg'
offset, rad = rf.read_regfile(regfile, time_interval[0], time_interval[1], 'hourangle')
print(offset)
print(rad)

xx = offset[0].value
yy = offset[1].value
# Out:
# [-78.99369034 259.47881806] arcsec
# 150.0 arcsec

# %%
#Set broad box for plotting (using region object)
bl=[(xx-200)*u.arcsec, (yy-200)*u.arcsec]
tr=[(xx+200)*u.arcsec,(yy+200)*u.arcsec]
print(tr[0]-bl[0], tr[1]-bl[1])

#Make region dictionary 
region_input = {'center': (xx,  yy)*u.arcsec,
                  'radius': rad}
# Out:
# 400.0 arcsec 400.0 arcsec

# %% [markdown]
# Now, let's set some other DEM input parameters (chosing which instruments to use, NuSTAR DEM energies, etc).

# %%
#What instruments are you using?
#---------------------------------
aia=True
#---------------------------------
eis=False
#---------------------------------
xrt=False
plot=False
#Here is the exposure time limits dictionary for each XRT filter combination:
exposure_dict={'Be_thin': [1*u.s, 10*u.s],
                'Be_med': [],
              'Al_poly': [0.1*u.s, 1*u.s]}
#---------------------------------
nustar=True
#If nustar is being used, here are the chosen energy ranges:
nuenergies=[[2.5,3.5],[3.5,6.], [6.,10.]]
#---------------------------------

#---------------------------------
#---------------------------------
#What temperature range would you like to use? (units: log(T))
minT=5.6
maxT=7.2

#Would you prefer to plot temperatures in MK, or the default (logT)
plotMK=False
#---------------------------------
#---------------------------------

name='initial_dem'

# %% [markdown]
# Note: sometimes, when running the DEM prep for the first time, there will be issues with the AIA data download via Fido.search and .fetch. This often seems to be resolvable by just repeating the same attempted download. To save time, aia_dem_prep.aia_for_DEM() can be used in isolation (see function for needed keywords) to avoid having to run all the other instrument prep as well.
#
# If the aia download/prep fails, the DEM in the following cell will fail – presently, the code is set up to be able to do AIA+NuSTAR, XRT+NuSTAR, or all-three DEMs – not to do just NuSTAR.
#
# This can take a while if you are downloading+prepping AIA data for this interval for the first time - particularly if your time interval is long.

# %%
#NuSTAR and AIA DEM
dodem.run_iterative_wrapper(time_interval, bl, tr, xrt=xrt, aia=aia, nustar=nustar, name=name,
                                    plotMK=plotMK, minT=minT, maxT=maxT,
                                    working_directory=working_dir,
                                    default_err=0.2, path_to_dodem=path_to_dodem,
            
                                    #xrt_dem_iterative2 related
                                    mc_iter=100, dT=0.1, chi_thresh=0.95, 
                                    
                                    #nustar related 
                                    combine_fpm=True,nuenergies=nuenergies, 
                                    datapath=datapath, gtifile=gtifile, make_nustar=True, 
                                    COM_nustar_region=True, nuclobber=False, edit_regfile=True,
            
                                    #aia related
                                    aiamethod='Auto', real_aia_err=True,
                                    input_aia_region="circle", input_aia_region_dict=region_input,
                                       sunpy_dir=sunpy_dir, errortab=errortab)
# Out:
# Start Time:  2018-05-29T22:22:00.000
# Stop Time:  2018-05-29T22:32:00.000
# You provided both a region box and a specific region.
# Bounding box will be used only for initial data prep (will save submap instead of full disk);
# specific region will be used for DEM
#
# Adding 10% error in quadrature with aiapy.estimate_error output.
#
# ARF File:  ['./initial_dem/22-22-00_22-32-00/nu80410205001A06_0_p_sr.arf']
# RMF File:  ['./initial_dem/22-22-00_22-32-00/nu80410205001A06_0_p_sr.rmf']
# PHA File:  ['./initial_dem/22-22-00_22-32-00/nu80410205001A06_0_p_sr.pha']
#
# Max NuSTAR Energy:  39.07999801635742
# Warning: there is at least one NuSTAR event of higher energy than your highest energy range
# Highest energy range: [6.0, 10.0]
# Total Above:  3
# Above Energies:  [11.96000004 28.36000061 39.07999802]
# ARF File:  ['./initial_dem/22-22-00_22-32-00/nu80410205001B06_0_p_sr.arf']
# RMF File:  ['./initial_dem/22-22-00_22-32-00/nu80410205001B06_0_p_sr.rmf']
# PHA File:  ['./initial_dem/22-22-00_22-32-00/nu80410205001B06_0_p_sr.pha']
#
# Max NuSTAR Energy:  7.479999542236328
#
# A94 :     2.97   1.51  51 %
# A131 :     24.25   4.29  18 %
# A171 :     653.07   68.07  10 %
# A193 :     761.51   78.54  10 %
# A211 :     277.02   29.19  11 %
# A335 :     20.06   2.87  14 %
# 2.5-3.5keV A+B :     5620.93   1124.51  20 %
# 3.5-6.0keV A+B :     576.73   115.67  20 %
# 6.0-10.0keV A+B :     2.05   0.66  32 %
# IDL Version 8.5, Mac OS X (darwin x86_64 m64).
# (c) 2015, Exelis Visual Information Solutions, Inc., a subsidiary of Harris Corporation.
# Installation number: 9389.
# Licensed for use by: Space Physics Lab License
#
# % Program caused arithmetic error: Floating illegal operand
# % Compiled module: SEARCH_NETWORK.
# % Compiled module: MKLOG.
# % Compiled module: CHKLOG.
# % Compiled module: IS_NUMBER.
# % Compiled module: GET_DELIM.
# % Compiled module: TRIM2.
# % Compiled module: FIX_SLASH.
# % Compiled module: RHESSI_SERVER.
# % Compiled module: SINCE_VERSION.
# % Compiled module: IS_NUMBER2.
# % Compiled module: USE_NETWORK.
# % Compiled module: ADD_PATH.
# % Compiled module: LOCAL_NAME.
# % Compiled module: EXPAND_TILDE.
# % Compiled module: IS_DIR.
# % Compiled module: GET_PATH_DELIM.
# % Compiled module: STR_SEP.
# % Compiled module: SSW_PATH.
# % Compiled module: SSW_INSTRUMENTS.
# % Compiled module: WC_WHERE.
# % Compiled module: PATHFIX.
# % Compiled module: REM_ELEM.
# % Compiled module: REM_ELEM2.
# % Compiled module: GET_UNIQ.
# % Compiled module: SSW_UNIQ.
# % Compiled module: DEFAULT.
# % Compiled module: DATATYPE.
# % Compiled module: REMOVE.
# % Compiled module: UNIQO.
# % Compiled module: STRJUSTIFY.
# % Compiled module: UNIQ.
# % Compiled module: PRSTR.
# % SSW_PATH: Number of paths changed from 180 to 196
# % Compiled module: HISSW_PROCEDURE.
# % Compiled module: XRT_DEM_ITERATIVE2.
# % Compiled module: REQUIRED_TAGS.
# % Compiled module: GT_TAGVAL.
# % Compiled module: STR_TAGVAL.
# % Compiled module: TAG_INDEX.
# % Compiled module: INTERPOL.
# % Compiled module: ROUND_OFF.
# % Compiled module: SPLINE.
# % Compiled module: MPFIT.
# % Program caused arithmetic error: Floating underflow
# % Program caused arithmetic error: Floating overflow
# % Program caused arithmetic error: Floating illegal operand
#
# /opt/X11/lib/flat_namespace
# SSW  setup will include: <gen gx_simulator gsfit AIA hessi spex xray chianti hinode xrt sot eis so stix>
#
# Type <sswidl> to start SSW IDL
# SSW  setup will include: <gen hinode/xrt sdo/aia hessi>
#
# Type <sswidl> to start SSW IDL
# --------------------------------------------------------
# Running SSW, Last Updated: Wed Nov 2 22:22:51 GMT 2005
#
# PROBLEMS? - e-mail TO: freeland@penumbra.nascom.nasa.gov
# --------------------------------------------------------
# Executing SSW IDL_STARTUP for: GEN
# Executing SSW IDL_STARTUP for: SITE
# Executing SSW IDL_STARTUP: (Personal)
# /Users/jessieduncan/foxsi/foxsi-science/vla added to IDL path.
# /Users/jessieduncan/foxsi/foxsi-science/util added to IDL path.
# /Users/jessieduncan/foxsi/foxsi-science/spec added to IDL path.
# /Users/jessieduncan/foxsi/foxsi-science/sam/foxsi1 added to IDL path.
# /Users/jessieduncan/foxsi/foxsi-science/sam added to IDL path.
# /Users/jessieduncan/foxsi/foxsi-science/resp added to IDL path.
# /Users/jessieduncan/foxsi/foxsi-science/psf added to IDL path.
# /Users/jessieduncan/foxsi/foxsi-science/proc added to IDL path.
# /Users/jessieduncan/foxsi/foxsi-science/parameters added to IDL path.
# /Users/jessieduncan/foxsi/foxsi-science/old added to IDL path.
# /Users/jessieduncan/foxsi/foxsi-science/nustar added to IDL path.
# /Users/jessieduncan/foxsi/foxsi-science/ishikawa/foxsi1 added to IDL path.
# /Users/jessieduncan/foxsi/foxsi-science/img/old added to IDL path.
# /Users/jessieduncan/foxsi/foxsi-science/img added to IDL path.
# /Users/jessieduncan/foxsi/foxsi-science/help/examples added to IDL path.
# /Users/jessieduncan/foxsi/foxsi-science/ghost-rays added to IDL path.
# /Users/jessieduncan/foxsi/foxsi-science/calibration_data added to IDL path.
# /Users/jessieduncan/foxsi/foxsi-science added to IDL path.
# Including Paths:
#  -------------------------------------
# | $SSW/sdo/gen/idl/utilities          |
# | $SSW/sdo/gen/idl/attitude           |
# | $SSW/hinode/gen/idl/pointing        |
# | $SSW/sdo/aia/idl/response           |
# | $SSW/sdo/aia/idl/util               |
# | $SSW/sdo/aia/idl/calibration        |
# | $SSW/sdo/aia/idl/pryoung            |
# | $SSW/sdo/aia/idl/pubrel             |
# | $SSW/sdo/aia/idl/psf/PRO            |
# | $SSW/hessi/idl/atest                |
# | $SSW/hessi/idl/sub_task             |
# | $SSW/hessi/idl/self_cal             |
# | $SSW/hessi/idl/spectra              |
# | $SSW/hessi/idl/util/time            |
# | $SSW/hessi/idl/util/annsec          |
# | $SSW/hessi/idl/util/cart            |
# | $SSW/hessi/idl/util/matrix          |
# | $SSW/hessi/idl/util                 |
# | $SSW/hessi/idl/image_spec           |
# | $SSW/hessi/idl/mission_archive      |
# | $SSW/hessi/idl/qlook_archive        |
# | $SSW/hessi/idl/gen                  |
# | $SSW/hessi/idl/image/polar          |
# | $SSW/hessi/idl/image/visibility/gh  |
# | $SSW/hessi/idl/image/visibility/ejs |
# | $SSW/hessi/idl/image/visibility     |
# | $SSW/hessi/idl/image                |
# | $SSW/hessi/idl/flare_stat           |
# | $SSW/hessi/idl/roll_db_dev          |
# | $SSW/hessi/idl/aspect/util          |
# | $SSW/hessi/idl/aspect/io            |
# | $SSW/hessi/idl/aspect/ras           |
# | $SSW/hessi/idl/aspect/pt            |
# | $SSW/hessi/idl/aspect/sas           |
# | $SSW/hessi/idl/aspect/sim           |
# | $SSW/hessi/idl/aspect               |
# | $SSW/hessi/idl/astro                |
# | $SSW/hessi/idl/pmtras               |
# | $SSW/hessi/idl/widgets              |
# | $SSW/hessi/idl/sims/menu            |
# | $SSW/hessi/idl/sims                 |
# | $SSW/hinode/xrt/idl/response/contam |
# | $SSW/hinode/xrt/idl/response/j      |
# | $SSW/hinode/xrt/idl/response        |
# | $SSW/hinode/xrt/idl/util            |
# | $SSW/hinode/xrt/idl/objects         |
# | $SSW/hinode/xrt/idl/info            |
# | $SSW/hinode/xrt/idl/ops             |
#  -------------------------------------
# Using the following measurements:
# A94 A131 A171 A193 A211 A335 2.5-3.5keV A+B 3.5-6.0keV A+B 6.0-10.0keV A+B
# CHISQ (0):       3.13148
#
# Chisq Cutoff:  15.50731305586545
# Good Chisq Fraction:  0.9702970297029703
# './initial_dem/22-22-00_22-32-00/22-22-00_22-32-00_5.6_7.2_initial_dem_iterative_DEM_result.pickle'

# %% [markdown]
# Below: re-run of AIA data download and prep, for if it fails above (change wavelength to the wavelength where download failed).

# %%
# import aia_dem_prep

# aia_dem_prep.aia_for_DEM(time_interval, bl, tr, wav=[94], sunpy_dir=sunpy_dir, method='Average')

# %% [markdown]
# Now that we've done a basic DEM, let's do one with a NuSTAR pile-up correction. This will involve the preparation of additional spectral products.
#
# Relevant keywords:
# - adjacent_grades:
#     - set True to use grades 0-4 for the DEM (if pile_up_corr==True, DEM input spectrum will be grades 0-4 - 5/4*(grades 21-24)
#     - set False to use grade 0 for the DEM (if pile_up_corr==True, DEM input spectrum will be grade 0 - 1/4*(grades 21-24)

# %%
#NuSTAR and AIA DEM
dodem.run_iterative_wrapper(time_interval, bl, tr, xrt=xrt, aia=aia, nustar=nustar, name=name,
                                    plotMK=plotMK, minT=minT, maxT=maxT,
                                    working_directory=working_dir,
                                    default_err=0.2, path_to_dodem=path_to_dodem,
            
                                    #xrt_dem_iterative2 related
                                    mc_iter=100, dT=0.1, chi_thresh=0.95, 
                                    
                                    #nustar related 
                                    combine_fpm=True,nuenergies=nuenergies, make_nustar=True, 
                                    datapath=datapath, gtifile=gtifile,
                                    COM_nustar_region=True, nuclobber=False, edit_regfile=True,
                                    adjacent_grades=True, pile_up_corr=True,
            
                                    #aia related
                                    aiamethod='Auto', real_aia_err=True,
                                    input_aia_region="circle", input_aia_region_dict=region_input,
                                       sunpy_dir=sunpy_dir, errortab=errortab)
# Out:
# Start Time:  2018-05-29T22:22:00.000
# Stop Time:  2018-05-29T22:32:00.000
# You provided both a region box and a specific region.
# Bounding box will be used only for initial data prep (will save submap instead of full disk);
# specific region will be used for DEM
#
# Adding 10% error in quadrature with aiapy.estimate_error output.
#
# ARF File:  ['./initial_dem/22-22-00_22-32-00/nu80410205001A06_0_p_sr.arf']
# RMF File:  ['./initial_dem/22-22-00_22-32-00/nu80410205001A06_0_p_sr.rmf']
# PHA File:  ['./initial_dem/22-22-00_22-32-00/nu80410205001A06_0_p_sr.pha']
# Using grades 0-4 NuSTAR events.
# ARF File:  ['./initial_dem/22-22-00_22-32-00/nu80410205001A06_0_4_p_sr.arf']
# RMF File:  ['./initial_dem/22-22-00_22-32-00/nu80410205001A06_0_4_p_sr.rmf']
# PHA File:  ['./initial_dem/22-22-00_22-32-00/nu80410205001A06_0_4_p_sr.pha']
# ARF File:  ['./initial_dem/22-22-00_22-32-00/nu80410205001A06_21_24_p_sr.arf']
# RMF File:  ['./initial_dem/22-22-00_22-32-00/nu80410205001A06_21_24_p_sr.rmf']
# PHA File:  ['./initial_dem/22-22-00_22-32-00/nu80410205001A06_21_24_p_sr.pha']
#
# Max NuSTAR Energy:  39.07999801635742
# Warning: there is at least one NuSTAR event of higher energy than your highest energy range
# Highest energy range: [6.0, 10.0]
# Total Above:  3
# Above Energies:  [11.96000004 28.36000061 39.07999802]
# ARF File:  ['./initial_dem/22-22-00_22-32-00/nu80410205001B06_0_p_sr.arf']
# RMF File:  ['./initial_dem/22-22-00_22-32-00/nu80410205001B06_0_p_sr.rmf']
# PHA File:  ['./initial_dem/22-22-00_22-32-00/nu80410205001B06_0_p_sr.pha']
# Using grades 0-4 NuSTAR events.
# ARF File:  ['./initial_dem/22-22-00_22-32-00/nu80410205001B06_0_4_p_sr.arf']
# RMF File:  ['./initial_dem/22-22-00_22-32-00/nu80410205001B06_0_4_p_sr.rmf']
# PHA File:  ['./initial_dem/22-22-00_22-32-00/nu80410205001B06_0_4_p_sr.pha']
# ARF File:  ['./initial_dem/22-22-00_22-32-00/nu80410205001B06_21_24_p_sr.arf']
# RMF File:  ['./initial_dem/22-22-00_22-32-00/nu80410205001B06_21_24_p_sr.rmf']
# PHA File:  ['./initial_dem/22-22-00_22-32-00/nu80410205001B06_21_24_p_sr.pha']
#
# Max NuSTAR Energy:  7.919999599456787
#
# A94 :     2.97   1.51  51 %
# A131 :     24.25   4.29  18 %
# A171 :     653.07   68.07  10 %
# A193 :     761.51   78.54  10 %
# A211 :     277.02   29.19  11 %
# A335 :     20.06   2.87  14 %
# 2.5-3.5keV A+B :     5687.34   1137.79  20 %
# 3.5-6.0keV A+B :     643.02   128.92  20 %
# 6.0-10.0keV A+B :     5.67   1.42  25 %
# IDL Version 8.5, Mac OS X (darwin x86_64 m64).
# (c) 2015, Exelis Visual Information Solutions, Inc., a subsidiary of Harris Corporation.
# Installation number: 9389.
# Licensed for use by: Space Physics Lab License
#
# % Program caused arithmetic error: Floating illegal operand
# % Compiled module: SEARCH_NETWORK.
# % Compiled module: MKLOG.
# % Compiled module: CHKLOG.
# % Compiled module: IS_NUMBER.
# % Compiled module: GET_DELIM.
# % Compiled module: TRIM2.
# % Compiled module: FIX_SLASH.
# % Compiled module: RHESSI_SERVER.
# % Compiled module: SINCE_VERSION.
# % Compiled module: IS_NUMBER2.
# % Compiled module: USE_NETWORK.
# % Compiled module: ADD_PATH.
# % Compiled module: LOCAL_NAME.
# % Compiled module: EXPAND_TILDE.
# % Compiled module: IS_DIR.
# % Compiled module: GET_PATH_DELIM.
# % Compiled module: STR_SEP.
# % Compiled module: SSW_PATH.
# % Compiled module: SSW_INSTRUMENTS.
# % Compiled module: WC_WHERE.
# % Compiled module: PATHFIX.
# % Compiled module: REM_ELEM.
# % Compiled module: REM_ELEM2.
# % Compiled module: GET_UNIQ.
# % Compiled module: SSW_UNIQ.
# % Compiled module: DEFAULT.
# % Compiled module: DATATYPE.
# % Compiled module: REMOVE.
# % Compiled module: UNIQO.
# % Compiled module: STRJUSTIFY.
# % Compiled module: UNIQ.
# % Compiled module: PRSTR.
# % SSW_PATH: Number of paths changed from 180 to 196
# % Compiled module: HISSW_PROCEDURE.
# % Compiled module: XRT_DEM_ITERATIVE2.
# % Compiled module: REQUIRED_TAGS.
# % Compiled module: GT_TAGVAL.
# % Compiled module: STR_TAGVAL.
# % Compiled module: TAG_INDEX.
# % Compiled module: INTERPOL.
# % Compiled module: ROUND_OFF.
# % Compiled module: SPLINE.
# % Compiled module: MPFIT.
# % Program caused arithmetic error: Floating underflow
# % Program caused arithmetic error: Floating overflow
# % Program caused arithmetic error: Floating illegal operand
#
# /opt/X11/lib/flat_namespace
# SSW  setup will include: <gen gx_simulator gsfit AIA hessi spex xray chianti hinode xrt sot eis so stix>
#
# Type <sswidl> to start SSW IDL
# SSW  setup will include: <gen hinode/xrt sdo/aia hessi>
#
# Type <sswidl> to start SSW IDL
# --------------------------------------------------------
# Running SSW, Last Updated: Wed Nov 2 22:22:51 GMT 2005
#
# PROBLEMS? - e-mail TO: freeland@penumbra.nascom.nasa.gov
# --------------------------------------------------------
# Executing SSW IDL_STARTUP for: GEN
# Executing SSW IDL_STARTUP for: SITE
# Executing SSW IDL_STARTUP: (Personal)
# /Users/jessieduncan/foxsi/foxsi-science/vla added to IDL path.
# /Users/jessieduncan/foxsi/foxsi-science/util added to IDL path.
# /Users/jessieduncan/foxsi/foxsi-science/spec added to IDL path.
# /Users/jessieduncan/foxsi/foxsi-science/sam/foxsi1 added to IDL path.
# /Users/jessieduncan/foxsi/foxsi-science/sam added to IDL path.
# /Users/jessieduncan/foxsi/foxsi-science/resp added to IDL path.
# /Users/jessieduncan/foxsi/foxsi-science/psf added to IDL path.
# /Users/jessieduncan/foxsi/foxsi-science/proc added to IDL path.
# /Users/jessieduncan/foxsi/foxsi-science/parameters added to IDL path.
# /Users/jessieduncan/foxsi/foxsi-science/old added to IDL path.
# /Users/jessieduncan/foxsi/foxsi-science/nustar added to IDL path.
# /Users/jessieduncan/foxsi/foxsi-science/ishikawa/foxsi1 added to IDL path.
# /Users/jessieduncan/foxsi/foxsi-science/img/old added to IDL path.
# /Users/jessieduncan/foxsi/foxsi-science/img added to IDL path.
# /Users/jessieduncan/foxsi/foxsi-science/help/examples added to IDL path.
# /Users/jessieduncan/foxsi/foxsi-science/ghost-rays added to IDL path.
# /Users/jessieduncan/foxsi/foxsi-science/calibration_data added to IDL path.
# /Users/jessieduncan/foxsi/foxsi-science added to IDL path.
# Including Paths:
#  -------------------------------------
# | $SSW/sdo/gen/idl/utilities          |
# | $SSW/sdo/gen/idl/attitude           |
# | $SSW/hinode/gen/idl/pointing        |
# | $SSW/sdo/aia/idl/response           |
# | $SSW/sdo/aia/idl/util               |
# | $SSW/sdo/aia/idl/calibration        |
# | $SSW/sdo/aia/idl/pryoung            |
# | $SSW/sdo/aia/idl/pubrel             |
# | $SSW/sdo/aia/idl/psf/PRO            |
# | $SSW/hessi/idl/atest                |
# | $SSW/hessi/idl/sub_task             |
# | $SSW/hessi/idl/self_cal             |
# | $SSW/hessi/idl/spectra              |
# | $SSW/hessi/idl/util/time            |
# | $SSW/hessi/idl/util/annsec          |
# | $SSW/hessi/idl/util/cart            |
# | $SSW/hessi/idl/util/matrix          |
# | $SSW/hessi/idl/util                 |
# | $SSW/hessi/idl/image_spec           |
# | $SSW/hessi/idl/mission_archive      |
# | $SSW/hessi/idl/qlook_archive        |
# | $SSW/hessi/idl/gen                  |
# | $SSW/hessi/idl/image/polar          |
# | $SSW/hessi/idl/image/visibility/gh  |
# | $SSW/hessi/idl/image/visibility/ejs |
# | $SSW/hessi/idl/image/visibility     |
# | $SSW/hessi/idl/image                |
# | $SSW/hessi/idl/flare_stat           |
# | $SSW/hessi/idl/roll_db_dev          |
# | $SSW/hessi/idl/aspect/util          |
# | $SSW/hessi/idl/aspect/io            |
# | $SSW/hessi/idl/aspect/ras           |
# | $SSW/hessi/idl/aspect/pt            |
# | $SSW/hessi/idl/aspect/sas           |
# | $SSW/hessi/idl/aspect/sim           |
# | $SSW/hessi/idl/aspect               |
# | $SSW/hessi/idl/astro                |
# | $SSW/hessi/idl/pmtras               |
# | $SSW/hessi/idl/widgets              |
# | $SSW/hessi/idl/sims/menu            |
# | $SSW/hessi/idl/sims                 |
# | $SSW/hinode/xrt/idl/response/contam |
# | $SSW/hinode/xrt/idl/response/j      |
# | $SSW/hinode/xrt/idl/response        |
# | $SSW/hinode/xrt/idl/util            |
# | $SSW/hinode/xrt/idl/objects         |
# | $SSW/hinode/xrt/idl/info            |
# | $SSW/hinode/xrt/idl/ops             |
#  -------------------------------------
# Using the following measurements:
# A94 A131 A171 A193 A211 A335 2.5-3.5keV A+B 3.5-6.0keV A+B 6.0-10.0keV A+B
# CHISQ (0):       3.21787
#
# Chisq Cutoff:  15.50731305586545
# Good Chisq Fraction:  0.9306930693069307
# './initial_dem/22-22-00_22-32-00/22-22-00_22-32-00_5.6_7.2_initial_dem_iterative_DEM_result.pickle'

# %% [markdown]
# Adding XRT: this requires a directory (xrt_path) containing level-1 XRT data and grade map files for times/pointings consistent with the NuSTAR data.

# %%
#This is where I'm putting my XRT level-1 data and grade maps:
xrt_path=working_dir+'/XRT_for_DEM/'
xrt=True
plot_xrt=False

#For this specific example, the automatically generated NuSTAR radius extended outside of the XRT data region. 
#Shifting our AIA/XRT region over to avoid this. (Set plot_xrt=True to check on the location of the region with
#respect to the XRT map; set it False to speed things up.)
region_input = {'center': (xx-32,  yy)*u.arcsec,
                  'radius': rad}

#NuSTAR and AIA and XRT DEM
dodem.run_iterative_wrapper(time_interval, bl, tr, xrt=xrt, aia=aia, nustar=nustar, name=name,
                                    plotMK=plotMK, minT=minT, maxT=maxT,
                                    working_directory=working_dir,
                                    default_err=0.2, path_to_dodem=path_to_dodem,
            
                                    #xrt_dem_iterative2 related
                                    mc_iter=100, dT=0.1, chi_thresh=0.95, 
                                    
                                    #nustar related 
                                    combine_fpm=True,nuenergies=nuenergies, make_nustar=True, 
                                    datapath=datapath, gtifile=gtifile,
                                    COM_nustar_region=True, nuclobber=False, edit_regfile=True,
            
                                    #aia related
                                    aiamethod='Auto', real_aia_err=True,
                                    input_aia_region="circle", input_aia_region_dict=region_input,
                                       sunpy_dir=sunpy_dir, errortab=errortab,
           
           
                                   #xrt related
                                   xrtmethod='Average', real_xrt_err=True, xrt_path=xrt_path,
                                    xrt_exposure_dict=exposure_dict,
                                    input_xrt_region="circle", input_xrt_region_dict=region_input)
# Out:
# Start Time:  2018-05-29T22:22:00.000
# Stop Time:  2018-05-29T22:32:00.000
# You provided both a region box and a specific region.
# Bounding box will be used only for initial data prep (will save submap instead of full disk);
# specific region will be used for DEM
#
# Adding 10% error in quadrature with aiapy.estimate_error output.
#
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# INFO: Missing metadata for solar radius: assuming the standard radius of the photosphere. [sunpy.map.mapbase]
# xrt_tresp_20180529_aiaspec.dat
# ['Be-thin', 'Be-med', 'Al-poly']
# Adding 10% error in quadrature with real error.
#
# ARF File:  ['./initial_dem/22-22-00_22-32-00/nu80410205001A06_0_p_sr.arf']
# RMF File:  ['./initial_dem/22-22-00_22-32-00/nu80410205001A06_0_p_sr.rmf']
# PHA File:  ['./initial_dem/22-22-00_22-32-00/nu80410205001A06_0_p_sr.pha']
#
# Max NuSTAR Energy:  39.07999801635742
# Warning: there is at least one NuSTAR event of higher energy than your highest energy range
# Highest energy range: [6.0, 10.0]
# Total Above:  3
# Above Energies:  [11.96000004 28.36000061 39.07999802]
# ARF File:  ['./initial_dem/22-22-00_22-32-00/nu80410205001B06_0_p_sr.arf']
# RMF File:  ['./initial_dem/22-22-00_22-32-00/nu80410205001B06_0_p_sr.rmf']
# PHA File:  ['./initial_dem/22-22-00_22-32-00/nu80410205001B06_0_p_sr.pha']
#
# Max NuSTAR Energy:  7.479999542236328
#
# A94 :     2.90   1.49  51 %
# A131 :     23.33   4.18  18 %
# A171 :     627.83   65.54  10 %
# A193 :     736.09   75.99  10 %
# A211 :     268.21   28.31  11 %
# A335 :     19.57   2.82  14 %
# Be-thin x2 :     37.01   5.08  14 %
# Be-med x2 :     6.48   0.89  14 %
# Al-poly x2 :     241.71   36.33  15 %
# 2.5-3.5keV A+B :     5620.93   1124.51  20 %
# 3.5-6.0keV A+B :     576.73   115.67  20 %
# 6.0-10.0keV A+B :     2.05   0.66  32 %
# IDL Version 8.5, Mac OS X (darwin x86_64 m64).
# (c) 2015, Exelis Visual Information Solutions, Inc., a subsidiary of Harris Corporation.
# Installation number: 9389.
# Licensed for use by: Space Physics Lab License
#
# % Program caused arithmetic error: Floating illegal operand
# % Compiled module: SEARCH_NETWORK.
# % Compiled module: MKLOG.
# % Compiled module: CHKLOG.
# % Compiled module: IS_NUMBER.
# % Compiled module: GET_DELIM.
# % Compiled module: TRIM2.
# % Compiled module: FIX_SLASH.
# % Compiled module: RHESSI_SERVER.
# % Compiled module: SINCE_VERSION.
# % Compiled module: IS_NUMBER2.
# % Compiled module: USE_NETWORK.
# % Compiled module: ADD_PATH.
# % Compiled module: LOCAL_NAME.
# % Compiled module: EXPAND_TILDE.
# % Compiled module: IS_DIR.
# % Compiled module: GET_PATH_DELIM.
# % Compiled module: STR_SEP.
# % Compiled module: SSW_PATH.
# % Compiled module: SSW_INSTRUMENTS.
# % Compiled module: WC_WHERE.
# % Compiled module: PATHFIX.
# % Compiled module: REM_ELEM.
# % Compiled module: REM_ELEM2.
# % Compiled module: GET_UNIQ.
# % Compiled module: SSW_UNIQ.
# % Compiled module: DEFAULT.
# % Compiled module: DATATYPE.
# % Compiled module: REMOVE.
# % Compiled module: UNIQO.
# % Compiled module: STRJUSTIFY.
# % Compiled module: UNIQ.
# % Compiled module: PRSTR.
# % SSW_PATH: Number of paths changed from 180 to 196
# % Compiled module: HISSW_PROCEDURE.
# % Compiled module: XRT_DEM_ITERATIVE2.
# % Compiled module: REQUIRED_TAGS.
# % Compiled module: GT_TAGVAL.
# % Compiled module: STR_TAGVAL.
# % Compiled module: TAG_INDEX.
# % Compiled module: INTERPOL.
# % Compiled module: ROUND_OFF.
# % Compiled module: SPLINE.
# % Compiled module: MPFIT.
# % Program caused arithmetic error: Floating underflow
# % Program caused arithmetic error: Floating overflow
# % Program caused arithmetic error: Floating illegal operand
#
# /opt/X11/lib/flat_namespace
# SSW  setup will include: <gen gx_simulator gsfit AIA hessi spex xray chianti hinode xrt sot eis so stix>
#
# Type <sswidl> to start SSW IDL
# SSW  setup will include: <gen hinode/xrt sdo/aia hessi>
#
# Type <sswidl> to start SSW IDL
# --------------------------------------------------------
# Running SSW, Last Updated: Wed Nov 2 22:22:51 GMT 2005
#
# PROBLEMS? - e-mail TO: freeland@penumbra.nascom.nasa.gov
# --------------------------------------------------------
# Executing SSW IDL_STARTUP for: GEN
# Executing SSW IDL_STARTUP for: SITE
# Executing SSW IDL_STARTUP: (Personal)
# /Users/jessieduncan/foxsi/foxsi-science/vla added to IDL path.
# /Users/jessieduncan/foxsi/foxsi-science/util added to IDL path.
# /Users/jessieduncan/foxsi/foxsi-science/spec added to IDL path.
# /Users/jessieduncan/foxsi/foxsi-science/sam/foxsi1 added to IDL path.
# /Users/jessieduncan/foxsi/foxsi-science/sam added to IDL path.
# /Users/jessieduncan/foxsi/foxsi-science/resp added to IDL path.
# /Users/jessieduncan/foxsi/foxsi-science/psf added to IDL path.
# /Users/jessieduncan/foxsi/foxsi-science/proc added to IDL path.
# /Users/jessieduncan/foxsi/foxsi-science/parameters added to IDL path.
# /Users/jessieduncan/foxsi/foxsi-science/old added to IDL path.
# /Users/jessieduncan/foxsi/foxsi-science/nustar added to IDL path.
# /Users/jessieduncan/foxsi/foxsi-science/ishikawa/foxsi1 added to IDL path.
# /Users/jessieduncan/foxsi/foxsi-science/img/old added to IDL path.
# /Users/jessieduncan/foxsi/foxsi-science/img added to IDL path.
# /Users/jessieduncan/foxsi/foxsi-science/help/examples added to IDL path.
# /Users/jessieduncan/foxsi/foxsi-science/ghost-rays added to IDL path.
# /Users/jessieduncan/foxsi/foxsi-science/calibration_data added to IDL path.
# /Users/jessieduncan/foxsi/foxsi-science added to IDL path.
# Including Paths:
#  -------------------------------------
# | $SSW/sdo/gen/idl/utilities          |
# | $SSW/sdo/gen/idl/attitude           |
# | $SSW/hinode/gen/idl/pointing        |
# | $SSW/sdo/aia/idl/response           |
# | $SSW/sdo/aia/idl/util               |
# | $SSW/sdo/aia/idl/calibration        |
# | $SSW/sdo/aia/idl/pryoung            |
# | $SSW/sdo/aia/idl/pubrel             |
# | $SSW/sdo/aia/idl/psf/PRO            |
# | $SSW/hessi/idl/atest                |
# | $SSW/hessi/idl/sub_task             |
# | $SSW/hessi/idl/self_cal             |
# | $SSW/hessi/idl/spectra              |
# | $SSW/hessi/idl/util/time            |
# | $SSW/hessi/idl/util/annsec          |
# | $SSW/hessi/idl/util/cart            |
# | $SSW/hessi/idl/util/matrix          |
# | $SSW/hessi/idl/util                 |
# | $SSW/hessi/idl/image_spec           |
# | $SSW/hessi/idl/mission_archive      |
# | $SSW/hessi/idl/qlook_archive        |
# | $SSW/hessi/idl/gen                  |
# | $SSW/hessi/idl/image/polar          |
# | $SSW/hessi/idl/image/visibility/gh  |
# | $SSW/hessi/idl/image/visibility/ejs |
# | $SSW/hessi/idl/image/visibility     |
# | $SSW/hessi/idl/image                |
# | $SSW/hessi/idl/flare_stat           |
# | $SSW/hessi/idl/roll_db_dev          |
# | $SSW/hessi/idl/aspect/util          |
# | $SSW/hessi/idl/aspect/io            |
# | $SSW/hessi/idl/aspect/ras           |
# | $SSW/hessi/idl/aspect/pt            |
# | $SSW/hessi/idl/aspect/sas           |
# | $SSW/hessi/idl/aspect/sim           |
# | $SSW/hessi/idl/aspect               |
# | $SSW/hessi/idl/astro                |
# | $SSW/hessi/idl/pmtras               |
# | $SSW/hessi/idl/widgets              |
# | $SSW/hessi/idl/sims/menu            |
# | $SSW/hessi/idl/sims                 |
# | $SSW/hinode/xrt/idl/response/contam |
# | $SSW/hinode/xrt/idl/response/j      |
# | $SSW/hinode/xrt/idl/response        |
# | $SSW/hinode/xrt/idl/util            |
# | $SSW/hinode/xrt/idl/objects         |
# | $SSW/hinode/xrt/idl/info            |
# | $SSW/hinode/xrt/idl/ops             |
#  -------------------------------------
# Using the following measurements:
# A94 A131 A171 A193 A211 A335 Be-thin x2 Be-med x2 Al-poly x2 2.5-3.5keV A+B
# 3.5-6.0keV A+B 6.0-10.0keV A+B
# CHISQ (0):       5.98643
#
# Chisq Cutoff:  19.67513757268249
# Good Chisq Fraction:  0.8613861386138614
# './initial_dem/22-22-00_22-32-00/22-22-00_22-32-00_5.6_7.2_initial_dem_iterative_DEM_result.pickle'
