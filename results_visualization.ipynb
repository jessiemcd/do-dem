# %% [markdown]
# Various figures, etc. to look at different aspects of DEM results.

# %%
# import matplotlib.pyplot as plt
# import numpy as np
# import glob
# from astropy.io import fits
# from astropy import units as u
# import importlib
# import pathlib

#Path to top-level do-dem directory - edit for your system.
path_to_dodem = '/Users/jmdunca2/do-dem/'
from sys import path as sys_path
sys_path.append(path_to_dodem+'/dodem/')


import all_nu_analysis as ana
import images_and_coalignment as iac
import visualize_dem_results as viz


import pickle
import pathlib
import importlib
import numpy as np
import subprocess
from matplotlib import pyplot as plt

# %%
keys = ['01-sep-15', '02-sep-15',
        '19-feb-16', '22-apr-16_2', '26-jul-16_1', '27-jul-16_1', '26-jul-16_2',
        '11-sep-17', '12-sep-17', '13-sep-17', '10-oct-17',
        '29-may-18_1', '29-may-18_2', '09-sep-18', '10-sep-18', 
        '12-apr-19', '13-apr-19', 
        '29-jan-20',
        '06-jun-20', '07-jun-20', 
        '08-jun-20', '09-jun-20',
        '08-jan-21', '20-jan-21',
        '29-apr-21', '03-may-21_1', '03-may-21_2', '07-may-21', '20-jul-21', 
        '30-jul-21_1', 
        '30-jul-21_2']

print(len(keys))

with open('all_targets.pickle', 'rb') as f:
    all_targets = pickle.load(f)

#keys = all_targets.keys()
#print(len(keys))
    
done_sources = {k: all_targets[k] for k in keys}
ana.get_exposures(done_sources, dogoes=False)
# Out:
# 31
# 01-sep-15
# Duration:  172.42 min | Effective Exposure:  3.01 min | Livetime %:  0.02
# 02-sep-15
# Duration:  238.83 min | Effective Exposure:  5.27 min | Livetime %:  0.02
# 19-feb-16
# Duration:  191.83 min | Effective Exposure:  4.26 min | Livetime %:  0.02
# 22-apr-16_2
# Duration:  211.42 min | Effective Exposure:  15.91 min | Livetime %:  0.08
# 26-jul-16_1
# Duration:  139.65 min | Effective Exposure:  7.63 min | Livetime %:  0.05
# 27-jul-16_1
# Duration:  60.47 min | Effective Exposure:  2.35 min | Livetime %:  0.04
# 26-jul-16_2
# Duration:  9.9 min | Effective Exposure:  0.53 min | Livetime %:  0.05
# 11-sep-17
# Duration:  229.05 min | Effective Exposure:  1.19 min | Livetime %:  0.01
# 12-sep-17
# Duration:  106.08 min | Effective Exposure:  9.84 min | Livetime %:  0.09
# 13-sep-17
# Duration:  119.1 min | Effective Exposure:  13.81 min | Livetime %:  0.12
# 10-oct-17
# Duration:  145.27 min | Effective Exposure:  3.6 min | Livetime %:  0.02
# 29-may-18_1
# Duration:  263.75 min | Effective Exposure:  4.67 min | Livetime %:  0.02
# 29-may-18_2
# Duration:  20.78 min | Effective Exposure:  2.95 min | Livetime %:  0.14
# 09-sep-18
# Duration:  179.25 min | Effective Exposure:  24.02 min | Livetime %:  0.13
# 10-sep-18
# Duration:  179.27 min | Effective Exposure:  23.57 min | Livetime %:  0.13
# 12-apr-19
# Duration:  273.77 min | Effective Exposure:  3.14 min | Livetime %:  0.01
# 13-apr-19
# Duration:  355.88 min | Effective Exposure:  2.99 min | Livetime %:  0.01
# 29-jan-20
# Duration:  219.83 min | Effective Exposure:  34.94 min | Livetime %:  0.16
# 06-jun-20
# Duration:  84.68 min | Effective Exposure:  1.19 min | Livetime %:  0.01
# 07-jun-20
# Duration:  95.17 min | Effective Exposure:  1.74 min | Livetime %:  0.02
# 08-jun-20
# Duration:  84.63 min | Effective Exposure:  2.63 min | Livetime %:  0.03
# 09-jun-20
# Duration:  60.08 min | Effective Exposure:  2.94 min | Livetime %:  0.05
# 08-jan-21
# Duration:  61.12 min | Effective Exposure:  3.36 min | Livetime %:  0.05
# 20-jan-21
# Duration:  120.68 min | Effective Exposure:  2.21 min | Livetime %:  0.02
# 29-apr-21
# Duration:  297.88 min | Effective Exposure:  3.58 min | Livetime %:  0.01
# 03-may-21_1
# Duration:  120.83 min | Effective Exposure:  12.1 min | Livetime %:  0.1
# 03-may-21_2
# Duration:  181.2 min | Effective Exposure:  33.14 min | Livetime %:  0.18
# 07-may-21
# Duration:  120.55 min | Effective Exposure:  0.19 min | Livetime %:  0.0
# 20-jul-21
# Duration:  426.17 min | Effective Exposure:  3.33 min | Livetime %:  0.01
# 30-jul-21_1
# Duration:  121.08 min | Effective Exposure:  10.15 min | Livetime %:  0.08
# 30-jul-21_2
# Duration:  60.55 min | Effective Exposure:  5.96 min | Livetime %:  0.1
#
# Total Dataset Effective Exposure:  4.1026921256361994 h
# Total Dataset Observation Duration:  82.51970833194444 h

# %%
# importlib.reload(viz)

# file = '/Users/jmdunca2/do-dem/initial_dem_26jul16_2/region_0/23-27-00_23-36-50/23-27-00_23-36-50_5.6_7.2_26-jul-16_2_MC_DEM_result.pickle'
# res = viz.load_DEM(file)
# data, timestring, time = res

# viz.DEMlocalmax(data['ts'], data['DEM'], plot=True)

# %%
#Individual parameter plots for each orbit (like peak, powerlaws, etc) - saved in working directory for each region
# importlib.reload(ana)

minT=5.6
maxT=7.2
for k in keys:
    key=k
    print(key)
    method = all_targets[key]['method']


    directories = ana.get_region_directories(key, method=method)

    for dd in directories:
        ana.make_orbit_plots(dd, key, minT=minT, maxT=maxT, show=False)
# Out:
# 01-sep-15
# 3
# Number of orbits: 3
# 02-sep-15
# 4
# Number of orbits: 4
# 4
# Number of orbits: 4
# 19-feb-16
# 4
# Number of orbits: 4
# 22-apr-16_2
# 4
# Number of orbits: 4
# 26-jul-16_1
# 3
# Number of orbits: 3
# 2
# Number of orbits: 2
# 27-jul-16_1
# 1
# Number of orbits: 1
# 1
# Number of orbits: 1
# 26-jul-16_2
# 1
# Number of orbits: 1
# 11-sep-17
# 4
# Number of orbits: 4
# Cant find max of:  [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
# Not saving params due to peak failure:
# [datetime.datetime(2017, 9, 11, 20, 59, 20)
#  datetime.datetime(2017, 9, 11, 21, 0, 10)]
# 12-sep-17
# 2
# Number of orbits: 2
# No DEM file:  /Users/jmdunca2/do-dem/initial_dem_12sep17/region_0/20-59-30_21-00-00/20-59-30_21-00-00_5.6_7.2_12-sep-17_MC_DEM_result.pickle
# No DEM file:  /Users/jmdunca2/do-dem/initial_dem
_fpmB_3s_RAW_centroid.pkl
# /Users/jmdunca2/nustar/jul-2021/90710201001/event_cl/nu90710201001A06_cl_sunpos.evt
# 2021-07-30 18:05:39.501056+00:00
# 2021-07-30 18:19:49.501056+00:00
#
# 2021-07-30 18:20:31.501056+00:00
# 2021-07-30 18:21:13.501056+00:00
#
# 2021-07-30 18:21:17.501056+00:00
# 2021-07-30 18:26:43.501056+00:00
#
# 2021-07-30 18:26:59.501056+00:00
# 2021-07-30 18:43:11.501056+00:00
#
# 2021-07-30 18:53:35.501056+00:00
# 2021-07-30 18:58:59.501056+00:00
#
# 2021-07-30 18:59:53.501056+00:00
# 2021-07-30 19:05:05.501056+00:00
#
# 21-18-19 22-18-51
# Using 1s GOES flux ("flx1s")
# Files Downloaded:   0%|          | 0/1 [00:00<?, ?file/s]
# /Users/jmdunca2/nustar/jul-2021/90710203001//event_cl/nu90710203001A06_cl.evt
# /Users/jmdunca2/nustar/jul-2021/90710203001/event_cl/nu90710203001A06_cl_sunpos.evt
# d
# Loading coordinates from pickle: ./centroid_coordinates/d_90710203001_fpmA_3s_RAW_centroid.pkl
# /Users/jmdunca2/nustar/jul-2021/90710203001/event_cl/nu90710203001A06_cl_sunpos.evt
# /Users/jmdunca2/nustar/jul-2021/90710203001//event_cl/nu90710203001B06_cl.evt
# /Users/jmdunca2/nustar/jul-2021/90710203001/event_cl/nu90710203001B06_cl_sunpos.evt
# d
# Loading coordinates from pickle: ./centroid_coordinates/d_90710203001_fpmB_3s_RAW_centroid.pkl
# /Users/jmdunca2/nustar/jul-2021/90710203001/event_cl/nu90710203001A06_cl_sunpos.evt
# 2021-07-30 21:18:55.502077+00:00
# 2021-07-30 21:37:53.502077+00:00
#
# 2021-07-30 21:39:57.502077+00:00
# 2021-07-30 22:02:29.502077+00:00
#
# 2021-07-30 22:03:07.502077+00:00
# 2021-07-30 22:18:21.502077+00:00
#
#
# 19-41-40 20-42-13
# Using 1s GOES flux ("flx1s")
# Files Downloaded:   0%|          | 0/1 [00:00<?, ?file/s]
# /Users/jmdunca2/nustar/jul-2021/90710202001//event_cl/nu90710202001A06_cl.evt
# /Users/jmdunca2/nustar/jul-2021/90710202001/event_cl/nu90710202001A06_cl_sunpos.evt
# d
# Loading coordinates from pickle: ./centroid_coordinates/d_90710202001_fpmA_3s_RAW_centroid.pkl
# /Users/jmdunca2/nustar/jul-2021/90710202001/event_cl/nu90710202001A06_cl_sunpos.evt
# /Users/jmdunca2/nustar/jul-2021/90710202001//event_cl/nu90710202001B06_cl.evt
# /Users/jmdunca2/nustar/jul-2021/90710202001/event_cl/nu90710202001B06_cl_sunpos.evt
# d
# Loading coordinates from pickle: ./centroid_coordinates/d_90710202001_fpmB_3s_RAW_centroid.pkl
# /Users/jmdunca2/nustar/jul-2021/90710202001/event_cl/nu90710202001A06_cl_sunpos.evt
# 2021-07-30 19:42:16.500315+00:00
# 2021-07-30 20:03:56.500315+00:00
#
# 2021-07-30 20:04:14.500315+00:00
# 2021-07-30 20:25:30.500315+00:00
#
# 2021-07-30 20:26:26.500315+00:00
# 2021-07-30 20:41:42.500315+00:00

# %%
#Make histograms of >10 MK emission individually for all keys/regions.

importlib.reload(ana)
importlib.reload(viz)
averages_=[]
averagesl_=[]
averagesh_=[]
time1s=[]
EMTs=[]
above10s=[]
#for key in keys[20:21]:
for key in keys:
    res = ana.get_dem_params(key=key, all=False, plot=True, time_weighted=True, paramssaved=False, doparam='above10s',
                             fromhome=True, keydict=all_targets, namesearchstring=key+'_'+'MC_')
    values, averages, averagesl, averagesh, time1, EMT = res
    averages_.append(averages)
    averagesl_.append(averagesl)
    averagesh_.append(averagesh)
    time1s.append(time1.datetime)
    EMTs.append(EMT)
    above10s.append(values)
# Out:
# doing  01-sep-15
# doing  02-sep-15
# doing  19-feb-16
# doing  22-apr-16_2
# doing  26-jul-16_1
# TIS failed on at least one orbit. Orbits completed:  2
# Orbits total:  3
# Region was:  /Users/jmdunca2/do-dem/initial_dem_26jul16_1/region_1/
#
#
#
# doing  27-jul-16_1
# doing  26-jul-16_2
# doing  11-sep-17
# For time,  09/11/17 15-55-50 - 09/11/17 15-56-20  mean accepted events,  94.5502627161799  below threshold,  95
# For time,  09/11/17 15-56-20 - 09/11/17 15-56-50  mean accepted events,  94.14248177378238  below threshold,  95
# For time,  09/11/17 15-56-50 - 09/11/17 15-57-20  mean accepted events,  94.03534948516287  below threshold,  95
# For time,  09/11/17 15-57-20 - 09/11/17 15-57-50  mean accepted events,  93.15836175867256  below threshold,  95
# For time,  09/11/17 15-57-50 - 09/11/17 15-58-20  mean accepted events,  93.0877695640616  below threshold,  95
# For time,  09/11/17 15-58-20 - 09/11/17 15-58-50  mean accepted events,  94.81194616015208  below threshold,  95
# For time,  09/11/17 15-58-50 - 09/11/17 15-59-20  mean accepted events,  94.43468508324331  below threshold,  95
# For time,  09/11/17 15-59-20 - 09/11/17 15-59-50  mean accepted events,  93.75532337797246  below threshold,  95
# For time,  09/11/17 15-59-50 - 09/11/17 16-00-20  mean accepted events,  93.7157861909021  below threshold,  95
# For time,  09/11/17 16-00-50 - 09/11/17 16-01-20  mean accepted events,  93.13031745969764  below threshold,  95
# For time,  09/11/17 16-01-20 - 09/11/17 16-01-50  mean accepted events,  93.46374963613505  below threshold,  95
# For time,  09/11/17 16-01-50 - 09/11/17 16-02-35  mean accepted events,  94.26053269834183  below threshold,  95
# For time,  09/11/17 16-04-10 - 09/11/17 16-04-40  mean accepted events,  94.6305517203669  below threshold,  95
# For time,  09/11/17 16-04-40 - 09/11/17 16-05-10  mean accepted events,  94.90249860141029  below threshold,  95
# For time,  09/11/17 16-05-10 - 09/11/17 16-05-40  mean accepted events,  94.4354547615458  below threshold,  95
# For time,  09/11/17 16-05-40 - 09/11/17 16-06-10  mean accepted events,  94.77529738628945  below threshold,  95
# For time,  09/11/17 16-06-10 - 09/11/17 16-06-40  mean accepted events,  94.43940785384595  below threshold,  95
# For time,  09/11/17 16-07-40 - 09/11/17 16-08-10  mean accepted events,  94.85812845942769  below threshold,  95
# For time,  09/11/17 16-08-10 - 09/11/17 16-08-40  mean accepted events,  94.81514152268099  below threshold,  95
# For time,  09/11/17 16-10-10 - 09/11/17 16-10-40  mean accepted events,  94.56873987942353  below threshold,  95
# For time,  09/11/17 16-19-50 - 09/11/17 16-20-20  mean accepted events,  94.25503700290903  below threshold,  95
# For time,  09/11/17 16-21-20 - 09/11/17 16-21-50  mean accepted events,  93.44358058017733  below threshold,  95
# For time,  09/11/17 16-21-50 - 09/11/17 16-22-20  mean accepted events,  94.51892996473094  below threshold,  95
# For time,  09/11/17 16-32-30 - 09/11/17 16-33-00  mean accepted events,  93.60425560402334  below threshold,  95
# For time,  09/11/17 16-33-30 - 09/11/17 16-34-00  mean accepted events,  94.89965514496141  below threshold,  95
# For time,  09/11/17 16-34-30 - 09/11/17 16-35-00  mean accepted events,  94.5432256041542  below threshold,  95
# For time,  09/11/17 16-35-00 - 09/11/17 16-35-30  mean accepted events,  94.7902775796905  below threshold,  95
# For time,  09/11/17 16-35-30 - 09/11/17 16-36-00  mean accepted events,  93.8295218902523  below threshold,  95
# For time,  09/11/17 16-36-00 - 09/11/17 16-36-30  mean accepted events,  94.90880792779161  below threshold,  95
# For time,  09/11/17 17-33-00 - 09/11/17 17-33-30  mean accepted events,  94.83899011076733  below threshold,  95
# For time,  09/11/17 17-36-45 - 09/11/17 17-37-15  mean accepted events,  94.95603793733774  below threshold,  95
# For time,  09/11/17 18-30-40 - 09/11/17 18-31-10  mean accepted events,  94.95807247808628  below threshold,  95
# Cant find max of:  [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan
#  nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
# Not saving params due to peak failure:
# [datetime.datetime(2017, 9, 11, 20, 59, 20)
#  datetime.datetime(2017, 9, 11, 21, 0, 10)]
# doing  12-sep-17
# 12-sep-17 0 20-59-30_21-00-00 []
# 12-sep-17 0 21-00-00_21-00-30 []
# doing  13-sep-17
# doing  10-oct-17
# doing  29-may-18_1
# For time,  05/29/18 16-31-50 - 05/29/18 16-34-25  mean accepted events,  94.90312619434442  below threshold,  95
# For time,  05/29/18 16-34-25 - 05/29/18 16-36-00  mean accepted events,  93.44632548656416  below threshold,  95
# For time,  05/29/18 18-13-45 - 05/29/18 18-14-15  mean accepted events,  94.63946761365885  below threshold,  95
# For time,  05/29/18 18-14-15 - 05/29/18 18-15-15  mean accepted events,  91.28921837177991  below threshold,  95
# For time,  05/29/18 19-54-40 - 05/29/18 19-55-25  mean accepted events,  94.83913609152842  below threshold,  95
# doing  29-may-18_2
# TIS failed on at least one orbit. Orbits completed:  0
# Orbits total:  1
# Region was:  /Users/jmdunca2/do-dem/initial_dem_29may18_2/region_1/
#
# doing  09-sep-18
# doing  10-sep-18
# doing  12-apr-19
# For time,  04/12/19 15-52-55 - 04/12/19 15-53-35  mean accepted events,  92.92318127223396  below threshold,  95
# For time,  04/12/19 17-20-30 - 04/12/19 17-21-00  mean accepted events,  90.59782514953045  below threshold,  95
# For time,  04/12/19 17-36-35 - 04/12/19 17-37-25  mean accepted events,  93.18758232777488  below threshold,  95
# For time,  04/12/19 17-47-25 - 04/12/19 17-47-55  mean accepted events,  93.86026362918751  below threshold,  95
# For time,  04/12/19 19-02-20 - 04/12/19 19-02-50  mean accepted events,  93.47080033819498  below threshold,  95
# For time,  04/12/19 19-02-50 - 04/12/19 19-03-20  mean accepted events,  89.75874868164632  below threshold,  95
# For time,  04/12/19 19-19-50 - 04/12/19 19-20-20  mean accepted events,  91.96508279112444  below threshold,  95
# For time,  04/12/19 19-20-20 - 04/12/19 19-20-50  mean accepted events,  91.18981114624472  below threshold,  95
# For time,  04/12/19 19-20-50 - 04/12/19 19-21-20  mean accepted events,  93.7639298045211  below threshold,  95
# For time,  04/12/19 19-21-20 - 04/12/19 19-22-10  mean accepted events,  94.6874408621506  below threshold,  95
# For time,  04/12/19 19-22-10 - 04/12/19 19-22-40  mean accepted events,  94.26068960331546  below threshold,  95
# For time,  04/12/19 20-43-15 - 04/12/19 20-46-15  mean accepted events,  93.4451862370902  below threshold,  95
# For time,  04/12/19 22-27-15 - 04/12/19 22-30-15  mean accepted events,  93.13102825407108  below threshold,  95
# 20-jan-21 14-16-25_14-16-55 []
# 20-jan-21 14-16-55_14-17-25 []
# 20-jan-21 14-17-25_14-17-55 []
# 20-jan-21 14-17-55_14-18-25 []
# 20-jan-21 14-18-25_14-18-55 []
# 20-jan-21 14-18-55_14-19-25 []
# 20-jan-21 14-19-25_14-20-00 []
# 20-jan-21 14-20-00_14-20-50 []
# 20-jan-21 14-20-50_14-21-50 []
# 20-jan-21 14-21-50_14-22-30 []
# 20-jan-21 14-22-30_14-23-35 []
# 20-jan-21 14-30-00_14-34-10 []
# 20-jan-21 14-34-10_14-36-20 []
# 20-jan-21 14-36-20_14-37-35 []
# 20-jan-21 14-37-35_14-39-05 []
# 20-jan-21 14-39-05_14-40-50 []
# 20-jan-21 14-40-50_14-42-30 []
# 20-jan-21 14-42-30_14-43-10 []
# 20-jan-21 14-43-10_14-45-40 []
# For time,  01/20/21 12-35-05 - 01/20/21 13-09-06  mean accepted events,  22.643413287462913  below threshold,  95
# doing  29-apr-21
# 29-apr-21 22-15-50_22-16-40 []
# For time,  04/29/21 18-07-00 - 04/29/21 18-07-30  mean accepted events,  91.73228338354653  below threshold,  95
# For time,  04/29/21 18-07-30 - 04/29/21 18-08-00  mean accepted events,  91.19803157349882  below threshold,  95
# For time,  04/29/21 18-08-00 - 04/29/21 18-08-30  mean accepted events,  92.76825486010571  below threshold,  95
# For time,  04/29/21 18-08-30 - 04/29/21 18-09-00  mean accepted events,  91.87855516508753  below threshold,  95
# For time,  04/29/21 18-09-00 - 04/29/21 18-09-30  mean accepted events,  93.1169687849944  below threshold,  95
# For time,  04/29/21 18-09-30 - 04/29/21 18-10-00  mean accepted events,  92.84006140399322  below threshold,  95
# For time,  04/29/21 18-10-00 - 04/29/21 18-10-30  mean accepted events,  94.00536910506825  below threshold,  95
# For time,  04/29/21 18-11-30 - 04/29/21 18-12-00  mean accepted events,  94.73365963660721  below threshold,  95
# For time,  04/29/21 18-21-00 - 04/29/21 18-21-30  mean accepted events,  94.59320158793554  below threshold,  95
# For time,  04/29/21 18-21-30 - 04/29/21 18-22-00  mean accepted events,  92.8732329995236  below threshold,  95
# For time,  04/29/21 18-22-00 - 04/29/21 18-22-30  mean accepted events,  94.90358974845977  below threshold,  95
# For time,  04/29/21 18-22-30 - 04/29/21 18-23-00  mean accepted events,  92.5633803763312  below threshold,  95
# For time,  04/29/21 18-23-00 - 04/29/21 18-23-30  mean accepted events,  93.6523504920166  below threshold,  95
# For time,  04/29/21 18-23-30 - 04/29/21 18-24-00  mean accepted events,  94.37512836593513  below threshold,  95
# For time,  04/29/21 18-24-30 - 04/29/21 18-25-00  mean accepted events,  93.5352632197297  below threshold,  95
# For time,  04/29/21 18-25-00 - 04/29/21 18-25-30  mean accepted events,  94.18162792959018  below threshold,  95
# For time,  04/29/21 18-26-00 - 04/29/21 18-26-30  mean accepted events,  94.6027965690756  below threshold,  95
# For time,  04/29/21 19-43-40 - 04/29/21 19-44-10  mean accepted events,  94.53317851817616  below threshold,  95
# For time,  04/29/21 19-44-10 - 04/29/21 19-44-40  mean accepted events,  94.69931244717236  below threshold,  95
# For time,  04/29/21 19-44-40 - 04/29/21 19-45-10  mean accepted events,  94.830403994768  below threshold,  95
# For time,  04/29/21 19-45-10 - 04/29/21 19-45-40  mean accepted events,  94.52689537674308  below threshold,  95
# For time,  04/29/21 19-45-40 - 04/29/21 19-46-10  mean accepted events,  94.83046192989572  below threshold,  95
# For time,  04/29/21 19-46-10 - 04/29/21 19-46-40  mean accepted events,  94.30086141033122  below threshold,  95
# For time,  04/29/21 19-46-40 - 04/29/21 19-47-10  mean accepted events,  94.65852517111271  below threshold,  95
# For time,  04/29/21 19-47-10 - 04/29/21 19-47-40  mean accepted events,  93.27637683810836  below threshold,  95
# For time,  04/29/21 19-47-40 - 04/29/21 19-48-10  mean accepted events,  94.43858226731733  below threshold,  95
# For time,  04/29/21 19-48-10 - 04/29/21 19-48-40  mean accepted events,  93.0951403302198  below threshold,  95
# For time,  04/29/21 19-48-40 - 04/29/21 19-49-10  mean accepted events,  93.37726945057923  below threshold,  95
# For time,  04/29/21 19-49-10 - 04/29/21 19-49-40  mean accepted events,  91.91908414979429  below threshold,  95
# For time,  04/29/21 19-49-40 - 04/29/21 19-50-10  mean accepted events,  93.39607962410994  below threshold,  95
# For time,  04/29/21 19-50-10 - 04/29/21 19-50-40  mean accepted events,  93.24643316816596  below threshold,  95
# For time,  04/29/21 19-50-40 - 04/29/21 19-51-10  mean accepted events,  91.74372321961295  below threshold,  95
# For time,  04/29/21 19-51-10 - 04/29/21 19-51-40  mean accepted events,  92.75640113533345  below threshold,  95
# For time,  04/29/21 19-51-40 - 04/29/21 19-52-10  mean accepted events,  93.48085876044797  below threshold,  95
# For time,  04/29/21 19-52-10 - 04/29/21 19-52-40  mean accepted events,  92.13022953670685  below threshold,  95
# For time,  04/29/21 19-52-40 - 04/29/21 19-53-10  mean accepted events,  92.27805433374127  below threshold,  95
# For time,  04/29/21 19-53-10 - 04/29/21 19-53-40  mean accepted events,  93.04387923912907  below threshold,  95
# For time,  04/29/21 19-53-40 - 04/29/21 19-54-10  mean accepted events,  91.96081728605182  below threshold,  95
# For time,  04/29/21 19-54-10 - 04/29/21 19-54-40  mean accepted events,  93.09411571901083  below threshold,  95
# For time,  04/29/21 19-54-40 - 04/29/21 19-55-10  mean accepted events,  94.04514943511663  below threshold,  95
# For time,  04/29/21 19-55-10 - 04/29/21 19-55-40  mean accepted events,  93.99200799200798  below threshold,  95
# For time,  04/29/21 19-55-40 - 04/29/21 19-56-10  mean accepted events,  94.37012157096551  below threshold,  95
# For time,  04/29/21 19-56-10 - 04/29/21 19-56-40  mean accepted events,  94.55661699015641  below threshold,  95
# For time,  04/29/21 20-41-45 - 04/29/21 20-42-15  mean accepted events,  94.47445669984138  below threshold,  95
# For time,  04/29/21 20-42-45 - 04/29/21 20-43-15  mean accepted events,  94.38966070534957  below threshold,  95
# doing  03-may-21_1
# 03-may-21_1 18-08-15_18-08-45 []
# doing  03-may-21_2
# doing  07-may-21
# 07-may-21 23-36-00_23-36-40 []
# For time,  05/07/21 23-32-30 - 05/07/21 23-33-00  mean accepted events,  89.4762564538761  below threshold,  95
# For time,  05/07/21 23-33-00 - 05/07/21 23-33-30  mean accepted events,  89.18929063305491  below threshold,  95
# For time,  05/07/21 23-33-30 - 05/07/21 23-34-00  mean accepted events,  89.80613420327987  below threshold,  95
# For time,  05/07/21 23-34-00 - 05/07/21 23-34-30  mean accepted events,  87.9600337998682  below threshold,  95
# For time,  05/07/21 23-34-30 - 05/07/21 23-35-00  mean accepted events,  88.11647895334916  below threshold,  95
# For time,  05/07/21 23-35-00 - 05/07/21 23-35-30  mean accepted events,  88.88748584517214  below threshold,  95
# For time,  05/07/21 23-35-30 - 05/07/21 23-36-00  mean accepted events,  88.41636059555958  below threshold,  95
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 19
#      17 averagesl_.append(averagesl)
#      18 averagesh_.append(averagesh)
# ---> 19 time1s.append(time1.datetime)
#      20 EMTs.append(EMT)
#      21 above10s.append(values)
#
# AttributeError: 'int' object has no attribute 'datetime'

# %%
#REMOVING ALL FILES FROM A OLD DEM RUN THAT SOMEHOW MADE DUPLICATES WITH A NON-STANDARD NAME AND MESSED EVERYTHING UP
# import time_interval_selection as tis
# import glob
# import os

# working_dir = '/Users/jmdunca2/do-dem/initial_dem_29apr21/'
# all_time_intervals, all_time_intervals_list = tis.find_all_intervals(working_dir, shush=True)
# for ot in range(0, len(all_time_intervals)):
#     orbittimes = all_time_intervals[ot]  
#     for tt in orbittimes:
#         timestring = viz.make_timestring(tt)
#         files = glob.glob(working_dir+'/'+timestring+'/'+'*5.6_7.2_29-apr-21_1_*')
#         for ff in files:
#             os.remove(ff)

# %%
#Make histogram of >10 MK emission in all keys/regions.
importlib.reload(ana)
res = ana.get_dem_params(all=True, plot=True, time_weighted=True, paramssaved=True, 
                         fromhome=True, keydict=all_targets, doparam='above10s')

# %%
#Make histogram of >5 MK emission in all keys/regions.
importlib.reload(ana)
res = ana.get_dem_params(all=True, plot=True, time_weighted=True, paramssaved=True, 
                         fromhome=True, keydict=all_targets, doparam='above5s')

# %%
#Make histogram of peak location in all keys/regions.
importlib.reload(ana)
res = ana.get_dem_params(all=True, plot=True, time_weighted=True, paramssaved=True, doparam='max_temp')

# %%
#Make histogram of lower power law in all keys/regions.
importlib.reload(ana)
res = ana.get_dem_params(all=True, plot=True, time_weighted=True, paramssaved=True, doparam='low_powers')

# %%
#Make histogram of upper power law in all keys/regions.
importlib.reload(ana)
res = ana.get_dem_params(all=True, plot=True, time_weighted=True, paramssaved=True, doparam='hi_powers')

# %%
#Make histograms of peak location individually for all keys/regions.
importlib.reload(ana)
importlib.reload(viz)

for key in keys:
    res = ana.get_dem_params(key=key, all=False, plot=True, time_weighted=True, paramssaved=True, doparam='max_temp')

# %%
#Make histograms of lower power laws individually for all keys/regions.
importlib.reload(ana)
importlib.reload(viz)

for key in keys:
    res = ana.get_dem_params(key=key, all=False, plot=True, time_weighted=True, paramssaved=False, doparam='low_powers')

# %%
#Make histograms of upper power laws individually for all keys/regions.
importlib.reload(ana)
importlib.reload(viz)

for key in keys:
    res = ana.get_dem_params(key=key, all=False, plot=True, time_weighted=True, paramssaved=True, doparam='hi_powers')
# Out:
# doing  27-jul-16_1

# %%
#Plotting total EM > 10 MK vs active region type

importlib.reload(ana)
importlib.reload(viz)
averages_=[]
averagesl_=[]
averagesh_=[]
time1s=[]
EMTs=[]
above10s=[]
labels=[]
hale=[]

for ind in range(0, len(keys)):
    key=keys[ind]
    print(key)
    ARDict = all_targets[key] 
    res_files, tworegions = ana.get_key_resultfiles(key, withparams=True)
    if tworegions:
        for j in range(0,2):
            label = ARDict['NOAA_ARID'][j]+'-'+key
            resfiles = res_files[j]
            res = ana.extract_and_plot_param_histograms(resfiles, key=key, plot=False, doparam='above10s',
                                                        time_weighted=True, seconds_per=5, 
                                                        plotlabel=label, show=False)
            values, averages, averagesl, averagesh, time1, EMT = res
            averages_.append(averages)
            averagesl_.append(averagesl)
            averagesh_.append(averagesh)
            time1s.append(time1.datetime)
            EMTs.append(EMT)
            above10s.append(values)
            labels.append(label)
            hale.append(ARDict['hale_class'][j])

    else:
        label = ARDict['NOAA_ARID'][0]+'-'+key
        resfiles = res_files
        res = ana.extract_and_plot_param_histograms(resfiles, key=key, plot=False, doparam='above10s',
                                                    time_weighted=True, seconds_per=5, 
                                                    plotlabel=label, show=False)
        values, averages, averagesl, averagesh, time1, EMT = res
        averages_.append(averages)
        averagesl_.append(averagesl)
        averagesh_.append(averagesh)
        time1s.append(time1.datetime)
        EMTs.append(EMT)
        above10s.append(values)
        labels.append(label)
        hale.append(ARDict['hale_class'][0])

helperx = []
counta=1
countb=1
countbgd=1
counto=1
for i in range(0, len(hale)):
    if hale[i] == 'alpha':
        helperx.append(0+counta)
        counta+=1
    elif hale[i] == 'beta':
        helperx.append(20+countb)
        countb+=1
    elif hale[i] == 'beta-gamma-delta':
        helperx.append(40+countbgd)
        countbgd+=1
    else:
        helperx.append(60+counto)
        counto+=1

averagesl_ = np.array(averagesl_)
averagesh_ = np.array(averagesh_)
averages_ = np.array(averages_)

fig, axes = plt.subplots(2, 1, figsize=(10,6), tight_layout = {'pad': 1})

labels=['All Times Mean', 'Flare Times Mean', 'Non-flare Times Mean']
colors = ['blue', 'green', 'red']

for ind in range(0,2):
    yerr= np.array([(averages_[:,ind]-averagesl_[:,ind]), (averagesh_[:,ind]-averages_[:,ind])])
    axes[ind].errorbar(helperx, averages_[:,ind], yerr=yerr, linestyle='', marker='x', label=labels[ind], color=colors[ind]) #, averagesh_[:,2]])
    if ind==1:
        yerr= np.array([(averages_[:,ind+1]-averagesl_[:,ind+1]), (averagesh_[:,ind+1]-averages_[:,ind+1])])
        axes[ind].errorbar(helperx, averages_[:,ind+1], yerr=yerr, linestyle='', marker='x', label=labels[ind+1], color=colors[ind+1])
        
    axes[ind].set_yscale('log')
    axes[ind].set_ylim([1e16,3e23])
    axes[ind].set_title(labels[ind])
    comp_band=[1.8e22, 1.5e23, 'Ishikawa et al. (2017)']
    axes[ind].axhspan(comp_band[0], comp_band[1], color='brown', alpha=0.25, label=comp_band[2])
    axes[ind].set_ylabel('Mean EM >10 MK')
    axes[ind].axvline(20, color='black', linestyle=':')
    axes[ind].axvline(40, color='black', linestyle=':')
    axes[ind].axvline(60, color='black', linestyle=':')
    axes[ind].set_xticks([5, 25, 45, 65], ['alpha', 'beta', 'beta-gamma-delta', 'other'])
    axes[ind].legend()

plt.savefig('mean_EM_over10_by_region_type.png')

# %%
#Plotting other parameters (peak temp, low, high powers) vs active region type. 

importlib.reload(ana)
importlib.reload(viz)


# doparam='max_temp'
# comp_band=[6.505, 6.6, 'Warren (2012) Peaks']
# comp_band2=[6.301, 6.415, 'Duncan (2024) Peaks']
# savetitle='mean_peak_temp_by_region_type.png'
# theylim=[6.1,6.55]
# theylabel='log(T)'

doparam='low_powers'
comp_band=[2, 5, 'Bradshaw (2012) Indices']
comp_band2=[1.9, 2.3, 'Duncan (2024) Indices']
savetitle='mean_low_power_by_region_type.png'
savetitle2='mean_low_power_by_region_location.png'
theylim=[0,4]
theylabel='Index'

# doparam='hi_powers'
# comp_band=[-10, -7, 'Barnes (2016)a Indices']
# comp_band2=[-12, -4, 'Duncan (2024) Indices']
# savetitle='mean_hi_power_by_region_type.png'
# savetitle2='mean_hi_power_by_location.png'
# theylim=[-15,0]
# theylabel='Index'


averages_=[]
time1s=[]
stdvs_=[]
reglabels=[]
hale=[]
loc=[]
#refkeys=[]

for ind in range(0, len(keys)):
    key=keys[ind]
    print(key)
    ARDict = all_targets[key] 
    res_files, tworegions = ana.get_key_resultfiles(key, withparams=True)
    if tworegions:
        for j in range(0,2):
            label = ARDict['NOAA_ARID'][j]+'-'+key
            resfiles = res_files[j]
            res = ana.extract_and_plot_param_histograms(resfiles, key=key, plot=False, doparam=doparam,
                                                        time_weighted=True, seconds_per=5, 
                                                        plotlabel=label, show=False)
            values, averages, time1, EMT = res
            stdvs = [np.std(values[0]), np.std(values[1]), np.std(values[2])]
            averages_.append(averages)
            #print(averages)
            #print(stdvs)
            stdvs_.append(stdvs)
            time1s.append(time1.datetime)
            reglabels.append(label)
            hale.append(ARDict['hale_class'][j])
            loc.append(ARDict['loc'][j])
            #refkeys.append(key)

    else:
        label = ARDict['NOAA_ARID'][0]+'-'+key
        resfiles = res_files
        res = ana.extract_and_plot_param_histograms(resfiles, key=key, plot=False, doparam=doparam,
                                                    time_weighted=True, seconds_per=5, 
                                                    plotlabel=label, show=False)
        values, averages, time1, EMT = res
        stdvs = [np.std(values[0]), np.std(values[1]), np.std(values[2])]
        averages_.append(averages)
        stdvs_.append(stdvs)
        time1s.append(time1.datetime)
        reglabels.append(label)
        hale.append(ARDict['hale_class'][0])
        loc.append(ARDict['loc'][0])
        #refkeys.append(key)

helperx = []
counta=1
countb=1
countbgd=1
counto=1
for i in range(0, len(hale)):
    if hale[i] == 'alpha':
        helperx.append(0+counta)
        counta+=1
    elif hale[i] == 'beta':
        helperx.append(20+countb)
        countb+=1
    elif hale[i] == 'beta-gamma-delta':
        helperx.append(40+countbgd)
        countbgd+=1
    else:
        helperx.append(60+counto)
        counto+=1



fig, axes = plt.subplots(2, 1, figsize=(10,6), tight_layout = {'pad': 1})

labels=['All Times Mean', 'Flare Times Mean', 'Non-flare Times Mean']
colors = ['blue', 'green', 'red']

averages_ = np.array(averages_)
stdvs_ = np.array(stdvs_)

for ind in range(0,2):
    yerr = [stdvs_[:,ind], stdvs_[:,ind]]
    axes[ind].errorbar(helperx, averages_[:,ind], yerr=yerr, linestyle='', marker='x', label=labels[ind], color=colors[ind]) #, averagesh_[:,2]])
    if ind==1:
        yerr = [stdvs_[:,ind+1], stdvs_[:,ind+1]]
        axes[ind].errorbar(helperx, averages_[:,ind+1], yerr=yerr, linestyle='', marker='x', label=labels[ind+1], color=colors[ind+1])
    
    #axes[ind].set_yscale('log')
    axes[ind].set_ylim(theylim)
    axes[ind].set_title(labels[ind])
    axes[ind].axhspan(comp_band[0], comp_band[1], color='brown', alpha=0.25, label=comp_band[2])
    axes[ind].axhspan(comp_band2[0], comp_band2[1], color='cyan', alpha=0.25, label=comp_band2[2])
    axes[ind].set_ylabel(theylabel)
    axes[ind].axvline(20, color='black', linestyle=':')
    axes[ind].axvline(40, color='black', linestyle=':')
    axes[ind].axvline(60, color='black', linestyle=':')
    axes[ind].set_xticks([5, 25, 45, 65], ['alpha', 'beta', 'beta-gamma-delta', 'other'])
    axes[ind].legend()


plt.savefig(savetitle)



helperx2 = []
#keylistl = []
#keylistd = []
countd=1
countl=1
for i in range(0, len(loc)):
    if loc[i] == 'limb':
        helperx2.append(0+countl)
        #keylistl.append(keys[i])
        countl+=1
    elif loc[i] == 'disk':
        helperx2.append(40+countd)
        #keylistd.append(keys[i])
        countd+=1

keylistl.extend(keylistd)


fig, axes = plt.subplots(2, 1, figsize=(10,6), tight_layout = {'pad': 1})

labels=['All Times Mean', 'Flare Times Mean', 'Non-flare Times Mean']
colors = ['blue', 'green', 'red']

averages_ = np.array(averages_)
stdvs_ = np.array(stdvs_)

for ind in range(0,2):
    yerr = [stdvs_[:,ind], stdvs_[:,ind]]
    axes[ind].errorbar(helperx2, averages_[:,ind], yerr=yerr, linestyle='', marker='x', label=labels[ind], color=colors[ind]) #, averagesh_[:,2]])
    if ind==1:
        yerr = [stdvs_[:,ind+1], stdvs_[:,ind+1]]
        axes[ind].errorbar(helperx2, averages_[:,ind+1], yerr=yerr, linestyle='', marker='x', label=labels[ind+1], color=colors[ind+1])
    
    #axes[ind].set_yscale('log')
    axes[ind].set_ylim(theylim)
    axes[ind].set_title(labels[ind])
    axes[ind].axhspan(comp_band[0], comp_band[1], color='brown', alpha=0.25, label=comp_band[2])
    axes[ind].axhspan(comp_band2[0], comp_band2[1], color='cyan', alpha=0.25, label=comp_band2[2])
    axes[ind].set_ylabel(theylabel)
    axes[ind].axvline(40, color='black', linestyle=':')
    axes[ind].set_xticks([5, 45], ['limb', 'disk'])
    axes[ind].legend()

#for i in range(0, len(reglabels)):
#    axes[0].annotate(reglabels[i], (helperx2[i], averages_[:,0][i]), fontsize=7)


plt.savefig(savetitle2)

# %%
#For all results, extracting certain input + output parameters for plotting 
#(NuSTAR, AIA inputs, powerlaws, peaks)

import glob

dn_ins=[]
lowpow=[]
above10z=[]

may_dn_ins=[]
may_lowpow=[]
may_peaks=[]
may_above10z=[]


apr_dn_ins=[]
apr_lowpow=[]
apr_peaks=[]
apr_above10z=[]

xrt_lowpow=[]
xrt_dn_ins=[]

peaks=[]

rfs = glob.glob('./compact_results/*withparams.pickle')
res_files = [f for f in rfs if '26-jul-16_1' not in f]
colorsyet=False
for f in res_files:
    data, timestring, time = viz.load_DEM(f)
    if '29-may-18_1' in f:
        may_dn_ins.append(np.array(data['dn_in'][0:6]+data['dn_in'][-3:]))
        may_lowpow.append(data['powerlaws'][0][0])
        may_peaks.append(data['max_temp'])
        may_above10z.append(data['above_10MK'][0])

    if '29-apr-21' in f:
        apr_dn_ins.append(np.array(data['dn_in'][0:6]+data['dn_in'][-3:]))
        apr_lowpow.append(data['powerlaws'][0][0])  
        apr_peaks.append(data['max_temp'])
        apr_above10z.append(data['above_10MK'][0])

    #if '27-jul-16' in f:
    #    continue
    
    if colorsyet==False:
        colorz = viz.comparison_colors(data)
        chanax = data['chanax']
        colorsyet=True

    if data['dn_in'][5] > 2e3:
        print(data['dn_in'][5], f)

    if data['dn_in'][-1] > 2e4:
        print(data['dn_in'][-1], f)
        continue

    # if data['dn_in'][3] > 1e3:
    #     print(data['dn_in'][3], f)

    if data['powerlaws'][0][0] < 1:
        print(data['powerlaws'][0][0], f)

    
    dn_ins.append(np.array(data['dn_in'][0:6]+data['dn_in'][-3:]))
    lowpow.append(data['powerlaws'][0][0])
    above10z.append(data['above_10MK'][0])
    if len(data['chanax']) > 9:
        xrt_dn_ins.append(np.array(data['dn_in'][0:6]+data['dn_in'][-3:]))
        xrt_lowpow.append(data['powerlaws'][0][0])

    peaks.append(data['max_temp'])

dn_ins=np.array(dn_ins)
may_dn_ins=np.array(may_dn_ins)
apr_dn_ins=np.array(apr_dn_ins)
xrt_dn_ins=np.array(xrt_dn_ins)
# Out:
# 0.8296586228053094 ./compact_results/21-17-30_21-18-00_5.6_7.2_12-sep-17_MC_DEM_result_region_0_withparams.pickle
# 22024.43241632389 ./compact_results/21-43-25_21-46-40_5.6_7.2_07-jun-20_MC_DEM_result_withparams.pickle
# 0.821541880091058 ./compact_results/21-15-30_21-16-00_5.6_7.2_12-sep-17_MC_DEM_result_region_0_withparams.pickle
# 0.7379829314440537 ./compact_results/00-57-15_01-00-15_5.6_7.2_27-jul-16_1_MC_DEM_result_region_0_withparams.pickle
# 0.8353058498779411 ./compact_results/21-31-30_21-32-00_5.6_7.2_12-sep-17_MC_DEM_result_region_0_withparams.pickle
# 0.8152415663815265 ./compact_results/21-13-30_21-14-00_5.6_7.2_12-sep-17_MC_DEM_result_region_0_withparams.pickle
# 0.832168614497403 ./compact_results/21-18-30_21-19-00_5.6_7.2_12-sep-17_MC_DEM_result_region_0_withparams.pickle
# 0.7313551901371096 ./compact_results/01-02-15_01-03-30_5.6_7.2_27-jul-16_1_MC_DEM_result_region_0_withparams.pickle
# 0.8333761301004793 ./compact_results/21-19-00_21-19-30_5.6_7.2_12-sep-17_MC_DEM_result_region_0_withparams.pickle
# 0.8395279257088829 ./compact_results/21-34-10_21-34-40_5.6_7.2_12-sep-17_MC_DEM_result_region_0_withparams.pickle
# 0.8091779194661608 ./compact_results/21-11-00_21-11-30_5.6_7.2_12-sep-17_MC_DEM_result_region_0_withparams.pickle
# 0.8166014152113105 ./compact_results/21-23-00_21-23-30_5.6_7.2_12-sep-17_MC_DEM_result_region_0_withparams.pickle
# 0.7113656998451513 ./compact_results/01-11-20_01-12-00_5.6_7.2_27-jul-16_1_MC_DEM_result_region_0_withparams.pickle
# 0.8528607304887146 ./compact_results/00-18-50_00-23-00_5.6_7.2_27-jul-16_1_MC_DEM_result_region_0_withparams.pickle
# 0.8149990264927377 ./compact_results/21-22-30_21-23-00_5.6_7.2_12-sep-17_MC_DEM_result_region_0_withparams.pickle
# 0.849794136680876 ./compact_results/21-37-45_21-38-15_5.6_7.2_12-sep-17_MC_DEM_result_region_0_withparams.pickle
# 0.8062251879595521 ./compact_results/21-10-30_21-11-00_5.6_7.2_12-sep-17_MC_DEM_result_region_0_withparams.pickle
# 0.8352852625852836 ./compact_results/21-30-00_21-30-30_5.6_7.2_12-sep-17_MC_DEM_result_region_0_withparams.pickle
# 0.7196512477717805 ./compact_results/01-05-40_01-06-40_5.6_7.2_27-jul-16_1_MC_DEM_result_region_0_withparams.pickle
# 0.8461798606908284 ./compact_results/21-35-45_21-36-15_5.6_7.2_12-sep-17_MC_DEM_result_region_0_withparams.pickle
# 0.
30_5.6_7.2_12-sep-17_MC_DEM_result_region_0_withparams.pickle
# 21538.796895593543 ./compact_results/21-42-25_21-42-55_5.6_7.2_07-jun-20_MC_DEM_result_withparams.pickle
# 0.8404863251224544 ./compact_results/21-35-10_21-35-45_5.6_7.2_12-sep-17_MC_DEM_result_region_0_withparams.pickle
# 0.7968140209250043 ./compact_results/20-57-30_20-58-00_5.6_7.2_12-sep-17_MC_DEM_result_region_0_withparams.pickle
# 0.7355841117797722 ./compact_results/00-54-25_00-55-50_5.6_7.2_27-jul-16_1_MC_DEM_result_region_0_withparams.pickle
# 0.7954764626670862 ./compact_results/21-02-30_21-03-00_5.6_7.2_12-sep-17_MC_DEM_result_region_0_withparams.pickle
# 0.8336511948494423 ./compact_results/21-30-30_21-31-00_5.6_7.2_12-sep-17_MC_DEM_result_region_0_withparams.pickle
# 0.8056511569361245 ./compact_results/21-10-00_21-10-30_5.6_7.2_12-sep-17_MC_DEM_result_region_0_withparams.pickle
# 0.4606563202150987 ./compact_results/00-17-25_00-20-10_5.6_7.2_13-sep-17_MC_DEM_result_region_1_withparams.pickle
# 0.8159389893674944 ./compact_results/21-22-00_21-22-30_5.6_7.2_12-sep-17_MC_DEM_result_region_0_withparams.pickle

# %%
len(dn_ins)
# Out:
# 2767

# %%
#Plot peaks vs DEM inputs

fig, axes = plt.subplots(3, 3, figsize=(15,15), tight_layout = {'pad': 1})


for i in range(0, len(chanax)):
    ax=axes[i//3, np.mod(i, 3)]

    ax.scatter(dn_ins[:,i], peaks, marker='x', color=colorz[i], label=chanax[i])
    ax.scatter(may_dn_ins[:,i], may_peaks, marker='x', color='blue', label=chanax[i]+' 29-may-2018')
    ax.scatter(apr_dn_ins[:,i], apr_peaks, marker='x', color='red', label=chanax[i]+' 29-apr-2021')
    #ax.scatter(xrt_dn_ins[:,i], xrt_lowpow, marker='x', color='red', label=chanax[i]+' xrt included')
    
    m, b = np.polyfit(dn_ins[:,i], peaks, 1)
    fity = dn_ins[:,i]*m + b
    ax.plot(dn_ins[:,i], fity, linestyle='dotted', color='black', label='linear fit, slope: '+str(round(m,3)))
    ax.set_ylabel('Peak Temp')
    if i < 6:
        ax.set_xlabel('DN/s/px')
    else:
        ax.set_xlabel('cts/s')
    #ax.set_xscale('log')
    ax.legend()

plt.savefig('compare_inputs_peaks.png')

# %%
#Plot above10z vs DEM inputs

fig, axes = plt.subplots(3, 3, figsize=(15,15), tight_layout = {'pad': 1})


for i in range(0, len(chanax)):
    ax=axes[i//3, np.mod(i, 3)]

    ax.scatter(dn_ins[:,i], above10z, marker='x', color=colorz[i], label=chanax[i])
    ax.scatter(may_dn_ins[:,i], may_above10z, marker='x', color='blue', label=chanax[i]+' 29-may-2018')
    ax.scatter(apr_dn_ins[:,i], apr_above10z, marker='x', color='red', label=chanax[i]+' 29-apr-2021')
    #ax.scatter(xrt_dn_ins[:,i], xrt_lowpow, marker='x', color='red', label=chanax[i]+' xrt included')
    
    m, b = np.polyfit(dn_ins[:,i], above10z, 1)
    fity = dn_ins[:,i]*m + b
    ax.plot(dn_ins[:,i], fity, linestyle='dotted', color='black', label='linear fit, slope: '+str(round(m,3)))
    ax.set_ylabel('EM > 10 MK')
    if i < 6:
        ax.set_xlabel('DN/s/px')
    else:
        ax.set_xlabel('cts/s')
    #ax.set_xscale('log')
    ax.legend()

plt.savefig('compare_inputs_above10MK.png')

# %%
#Plot lower powerlaw vs DEM inputs

fig, axes = plt.subplots(3, 3, figsize=(15,15), tight_layout = {'pad': 1})


for i in range(0, len(chanax)):
    ax=axes[i//3, np.mod(i, 3)]
    if i in [4,5]:
        print(np.max(dn_ins[:,i]), np.mean(dn_ins[:,i]))
    ax.scatter(dn_ins[:,i], lowpow, marker='x', color=colorz[i], label=chanax[i])
    ax.scatter(may_dn_ins[:,i], may_lowpow, marker='x', color='blue', label=chanax[i]+' 29-may-2018')
    ax.scatter(apr_dn_ins[:,i], apr_lowpow, marker='x', color='red', label=chanax[i]+' 29-apr-2021')
    #ax.scatter(xrt_dn_ins[:,i], xrt_lowpow, marker='x', color='red', label=chanax[i]+' xrt included')
    
    m, b = np.polyfit(dn_ins[:,i], lowpow, 1)
    fity = dn_ins[:,i]*m + b
    ax.plot(dn_ins[:,i], fity, linestyle='dotted', color='black', label='linear fit, slope: '+str(round(m,3)))
    ax.set_ylabel('Lower Power Law')
    if i < 6:
        ax.set_xlabel('DN/s/px')
    else:
        ax.set_xlabel('cts/s')
    #ax.set_xscale('log')
    ax.legend()

plt.savefig('compare_inputs_lower_powerlaw.png')
# Out:
# 529.7138335562405 252.25091137608848
# 26.692556528122655 15.900512252690655

# %%
#Plot peaks vs lower power law (note: temp bounds for powerlaw were fixed). 

fig, axes = plt.subplots(1,1, figsize=(5,5), tight_layout = {'pad': 1})
axes.scatter(peaks, lowpow, marker='x', color='violet')
axes.scatter(may_peaks, may_lowpow, marker='x', color='blue')
axes.scatter(apr_peaks, apr_lowpow, marker='x', color='red')
m, b = np.polyfit(peaks, lowpow, 1)
fity = np.array(peaks)*m + b
axes.plot(peaks, fity, linestyle='dotted', color='black', label='linear fit, slope: '+str(round(m,3)))
axes.legend()

# %%
#Plot lower power law vs. difference between two AIA channels divided by their respective temp. response

fig, axes = plt.subplots(1,2, figsize=(10,5), tight_layout = {'pad': 1})

the_sum = (dn_ins[:,3]/np.max(data['trmatrix'][:,3]))-(dn_ins[:,2]/np.max(data['trmatrix'][:,2]))
the_sum2 = (dn_ins[:,4]/np.max(data['trmatrix'][:,4]))-(dn_ins[:,2]/np.max(data['trmatrix'][:,2]))
axes[0].scatter(the_sum, lowpow, marker='x', color='slategray')
m, b = np.polyfit(the_sum, lowpow, 1)
fity = the_sum*m + b
axes[0].plot(the_sum, fity, linestyle='dotted', color='black', label='linear fit, slope: '+str(round(m,3)))

axes[1].scatter(the_sum2, lowpow, marker='x', color='gray')
axes[0].legend()
axes[1].legend()

# %%
importlib.reload(ana)

fig, axes = plt.subplots(2, 1, figsize=(15,10), tight_layout = {'pad': 1})

paramy = 'above_5MK'
paramx = 'EMT_thresh_5'

flare=True

yindex = 0

options = ['limb', 'disk']
optionnumbers = np.zeros(len(options))
caselabels = [[o] for o in options]

#flare_res = ana.get_saved_flares(add_stdv_flares=True)
flare_res =[]


for ind in range(0, len(keys)):
    key=keys[ind]
    #print(key)
    ARDict = all_targets[key] 
    res_files, tworegions = ana.get_key_resultfiles(key, withparams=True)
    #print(ARDict['NOAA_ARID'])
    if tworegions:
        for j in range(0,2):
            discriminator = ARDict['loc'][j]
            #print(loc)
            label = ARDict['NOAA_ARID'][j]+'-'+key
            resfiles = res_files[j]
            res = ana.plot_with_discriminator(axes, resfiles, discriminator, options, label, 
                                paramx, paramy, optionnumbers, caselabels,
                               startstop=flare_res, yindex=yindex, flare=flare, update_flarecheck=False)
            optionnumbers, caselabels = res

    else:
        discriminator = ARDict['loc'][0]
        #print(loc)
        label = ARDict['NOAA_ARID'][0]+'-'+key
        resfiles = res_files
        res = ana.plot_with_discriminator(axes, resfiles, discriminator, options, label, 
                                paramx, paramy, optionnumbers, caselabels,
                               startstop=flare_res, yindex=yindex, flare=flare, update_flarecheck=False)
        optionnumbers, caselabels = res
        

for ax in axes:
    ax.set_xlim([5.1, 8])
    ax.set_ylim([1, 1.2e25])
    #ax.set_xscale('log')
    ax.legend()

# %%
17+14

# %%
importlib.reload(ana)

fig, axes = plt.subplots(2, 1, figsize=(15,10), tight_layout = {'pad': 1})

paramy = 'above_5MK'
paramx = 'EMT_thresh_5'

flare=False

yindex = 0

options = ['limb', 'disk']
optionnumbers = np.zeros(len(options))
caselabels = [[o] for o in options]

flare_res = ana.get_saved_flares(add_stdv_flares=True)



for ind in range(0, len(keys)):
    key=keys[ind]
    #print(key)
    ARDict = all_targets[key] 
    res_files, tworegions = ana.get_key_resultfiles(key, withparams=True)
    #print(ARDict['NOAA_ARID'])
    if tworegions:
        for j in range(0,2):
            discriminator = ARDict['loc'][j]
            #print(loc)
            label = ARDict['NOAA_ARID'][j]+'-'+key
            resfiles = res_files[j]
            res = ana.plot_with_discriminator(axes, resfiles, discriminator, options, label, 
                                paramx, paramy, optionnumbers, caselabels,
                               startstop=flare_res, yindex=yindex, flare=flare, update_flarecheck=False)
            optionnumbers, caselabels = res

    else:
        discriminator = ARDict['loc'][0]
        #print(loc)
        label = ARDict['NOAA_ARID'][0]+'-'+key
        resfiles = res_files
        res = ana.plot_with_discriminator(axes, resfiles, discriminator, options, label, 
                                paramx, paramy, optionnumbers, caselabels,
                               startstop=flare_res, yindex=yindex, flare=flare, update_flarecheck=False)
        optionnumbers, caselabels = res
        

for ax in axes:
    ax.set_xlim([5.1, 8])
    ax.set_ylim([1, 1.2e25])
    #ax.set_xscale('log')
    ax.legend()

# %%
importlib.reload(ana)

paramy = 'max'
paramx = 'max_temp'

yindex = []


update_flarecheck=False
flare=False
flare_res = ana.get_saved_flares(add_stdv_flares=True)
#flare_res = []


discriminator_key = 'hale_class'
options = ['alpha', 'beta', 'beta-gamma-delta', 'other']
optionnumbers = np.zeros(len(options))
caselabels = [[o] for o in options]

fig, axes = plt.subplots(len(options), 1, figsize=(15,4*len(options)), tight_layout = {'pad': 1})

for ind in range(0, len(keys)):
    key=keys[ind]
    #print(key)
    ARDict = all_targets[key] 
    res_files, tworegions = ana.get_key_resultfiles(key, withparams=True)
    #print(ARDict['NOAA_ARID'])
    if tworegions:
        for j in range(0,2):
            discriminator = ARDict[discriminator_key][j]
            #print(loc)
            label = ARDict['NOAA_ARID'][j]+'-'+key
            resfiles = res_files[j]
            res = ana.plot_with_discriminator(axes, resfiles, discriminator, options, label, 
                                paramx, paramy, optionnumbers, caselabels,
                               startstop=flare_res, yindex=yindex, flare=flare, update_flarecheck=update_flarecheck)
            optionnumbers, caselabels = res

    else:
        discriminator = ARDict[discriminator_key][0]
        #print(loc)
        label = ARDict['NOAA_ARID'][0]+'-'+key
        resfiles = res_files
        res = ana.plot_with_discriminator(axes, resfiles, discriminator, options, label, 
                                paramx, paramy, optionnumbers, caselabels,
                                startstop=flare_res, yindex=yindex, flare=flare, update_flarecheck=update_flarecheck)
        optionnumbers, caselabels = res
        

for ax in axes:
    ax.set_xlim([6.1, 6.5])
    ax.set_ylim([4e25, 1e27])
    ax.set_yscale('log')
    ax.legend()
    ax.set_ylabel(paramy)
    ax.set_xlabel(paramx)



plt.savefig('all_intervals_max_v_maxtemp_by_hale_class_nonflares.png')

# %%
importlib.reload(ana)

paramy = 'above_peak'
paramx = 'below_peak'

yindex = []


update_flarecheck=False
flare=False
#Set to check for flares vs not
flare_res = ana.get_saved_flares(add_stdv_flares=True)
#Set to not care (plot all)
#flare_res = []


discriminator_key = 'hale_class'
options = ['alpha', 'beta', 'beta-gamma-delta', 'other']
optionnumbers = np.zeros(len(options))
caselabels = [[o] for o in options]

fig, axes = plt.subplots(len(options), 1, figsize=(8,4*len(options)), tight_layout = {'pad': 1})

for ind in range(0, len(keys)):
    key=keys[ind]
    #print(key)
    ARDict = all_targets[key] 
    res_files, tworegions = ana.get_key_resultfiles(key, withparams=True)
    #print(ARDict['NOAA_ARID'])
    if tworegions:
        for j in range(0,2):
            discriminator = ARDict[discriminator_key][j]
            #print(loc)
            label = ARDict['NOAA_ARID'][j]+'-'+key
            resfiles = res_files[j]
            res = ana.plot_with_discriminator(axes, resfiles, discriminator, options, label, 
                                paramx, paramy, optionnumbers, caselabels,
                               startstop=flare_res, yindex=yindex, flare=flare, update_flarecheck=update_flarecheck)
            optionnumbers, caselabels = res

    else:
        discriminator = ARDict[discriminator_key][0]
        #print(loc)
        label = ARDict['NOAA_ARID'][0]+'-'+key
        resfiles = res_files
        res = ana.plot_with_discriminator(axes, resfiles, discriminator, options, label, 
                                paramx, paramy, optionnumbers, caselabels,
                                startstop=flare_res, yindex=yindex, flare=flare, update_flarecheck=update_flarecheck)
        optionnumbers, caselabels = res
        

for ax in axes:
    ax.set_xlim([1e25, 1.5e26])
    ax.set_ylim([1e25, 1.5e26])
    #ax.set_yscale('log')
    ax.legend()
    ax.plot([1e25, 1.5e26], [1e25, 1.5e26], linestyle='dashed')
    ax.set_ylabel(paramy)
    ax.set_xlabel(paramx)


plt.savefig('all_intervals_above_v_below_by_hale_class_nonflares.png')

# %%
        data['max'] = max1
        data['max_temp'] = m1
        data['above_5MK'] = above5_
        data['above_7MK'] = above7_
        data['above_10MK'] = above10_
        data['above_peak'] = above_peak
        data['below_peak'] = below_peak
        data['powerlaws'] = powerlaws
        data['EMT_all'] = EMT_all
        data['EMT_thresh_5'] = EMT_thresh

# %%
limbs, limbtimes = [], []
disks, disktimes = [], []
for l in range(0, len(locs)):
    if locs[l]=='limb':
        limbs.append(averages_[l])
        limbtimes.append(time1s[l])
    if locs[l]=='disk':
        disks.append(averages_[l])
        disktimes.append(time1s[l]) 



    
fig, ax = plt.subplots(figsize=(15,6), tight_layout = {'pad': 1})   

ax.scatter(limbtimes, np.array(limbs)[:,0],label='limb regions')
ax.scatter(disktimes, np.array(disks)[:,0], label='disk regions')
ax.set_yscale('log')
ax.legend()

# %%
from matplotlib import pyplot as plt
fig, axes = plt.subplots(figsize=(15,6), tight_layout = {'pad': 1})

plt.scatter(time1s, np.array(averages_)[:,0], label='all')
plt.scatter(time1s, np.array(averages_)[:,1], label='flares')
plt.scatter(time1s, np.array(averages_)[:,2], label='non-flares')
plt.title('Time-averaged total EM >10 MK')
plt.yscale('log')
plt.legend()

# %%
# key = '03-may-21_1'

# with open('all_targets.pickle', 'rb') as f:
#     data = pickle.load(f)

# ARDict = data[key]

# id_dirs = ARDict['datapaths']
# obsids = ARDict['obsids']
# working_dir = ARDict['working_dir']

# %%
importlib.reload(ana)

all_allnewwindows = []

for k in keys:
    print(k)
    method = all_targets[k]['method']
    if k == '07-may-21':
        continue
    all_allnewwindows.extend(ana.do_stdv_analysis(k, method=method, show=False))


data = {'stdv_flares': all_allnewwindows}

with open('stdv_flares.pickle', 'wb') as f:
     # Pickle the 'data' dictionary using the highest protocol available.
     pickle.dump(data, f, pickle.HIGHEST_PROTOCOL)
# Out:
# 01-sep-15
# /Users/jmdunca2/nustar/sep-2015/20102002001/
#
# Number of Windows (>= 1 channel):  3
# Number of Windows (>= 3 channels):  1
# /Users/jmdunca2/nustar/sep-2015/20102003001/
#
# Number of Windows (>= 1 channel):  5
# Number of Windows (>= 3 channels):  3
# /Users/jmdunca2/nustar/sep-2015/20102004001/
#
# Number of Windows (>= 1 channel):  7
# Number of Windows (>= 3 channels):  1
# 02-sep-15
# /Users/jmdunca2/nustar/sep-2015/20102005001/
#
# Number of Windows (>= 1 channel):  10
# Number of Windows (>= 3 channels):  2
# /Users/jmdunca2/nustar/sep-2015/20102006001/
#
# Number of Windows (>= 1 channel):  5
# Number of Windows (>= 3 channels):  2
# /Users/jmdunca2/nustar/sep-2015/20102007001/
#
# Number of Windows (>= 1 channel):  23
# Number of Windows (>= 3 channels):  3
# /Users/jmdunca2/nustar/sep-2015/20102008001/
#
# Number of Windows (>= 1 channel):  6
# Number of Windows (>= 3 channels):  3
# /Users/jmdunca2/nustar/sep-2015/20102005001/
#
# Number of Windows (>= 1 channel):  10
# Number of Windows (>= 3 channels):  2
# /Users/jmdunca2/nustar/sep-2015/20102006001/
#
# Number of Windows (>= 1 channel):  5
# Number of Windows (>= 3 channels):  2
# /Users/jmdunca2/nustar/sep-2015/20102007001/
#
# Number of Windows (>= 1 channel):  23
# Number of Windows (>= 3 channels):  3
# /Users/jmdunca2/nustar/sep-2015/20102008001/
#
# Number of Windows (>= 1 channel):  6
# Number of Windows (>= 3 channels):  3
# 19-feb-16
# /Users/jmdunca2/nustar/feb-2016/20102011001/
#
# Number of Windows (>= 1 channel):  15
# Number of Windows (>= 3 channels):  3
# /Users/jmdunca2/nustar/feb-2016/20102012001/
#
# Number of Windows (>= 1 channel):  20
# Number of Windows (>= 3 channels):  2
# /Users/jmdunca2/nustar/feb-2016/20102013001/
#
# Number of Windows (>= 1 channel):  2
# Number of Windows (>= 3 channels):  1
# /Users/jmdunca2/nustar/feb-2016/20102014001/
#
# Number of Windows (>= 1 channel):  17
# Number of Windows (>= 3 channels):  1
# 22-apr-16_2
# /Users/jmdunca2/nustar/apr-2016/20101017001/
#
# Number of Windows (>= 1 channel):  32
# Number of Windows (>= 3 channels):  1
# /Users/jmdunca2/nustar/apr-2016/20101018001/
#
# Number of Windows (>= 1 channel):  38
# Number of Windows (>= 3 channels):  1
# /Users/jmdunca2/nustar/apr-2016/20101019001/
#
# Number of Windows (>= 1 channel):  4
# Number of Windows (>= 3 channels):  2
# /Users/jmdunca2/nustar/apr-2016/20101020001/
#
# Number of Windows (>= 1 channel):  2
# Number of Windows (>= 3 channels):  1
# 26-jul-16_1
# /Users/jmdunca2/nustar/jul-2016/20201001001/
#
# Number of Windows (>= 1 channel):  7
# Number of Windows (>= 3 channels):  1
# /Users/jmdunca2/nustar/jul-2016/20201002001/
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Number of Windows (>= 1 channel):  52
# Number of Windows (>= 3 channels):  0
# /Users/jmdunca2/nustar/jul-2016/20201003001/
#
# Number of Windows (>= 1 channel):  16
# Number of Windows (>= 3 channels):  2
# /Users/jmdunca2/nustar/jul-2016/20201001001/
#
# Number of Windows (>= 1 channel):  7
# Number of Windows (>= 3 channels):  1
# /Users/jmdunca2/nustar/jul-2016/20201002001/
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Number of Windows (>= 1 channel):  52
# Number of Windows (>= 3 channels):  0
# 27-jul-16_1
# /Users/jmdunca2/nustar/jul-2016/20201004001/
#
# Number of Windows (>= 1 channel):  13
# Number of Windows (>= 3 channels):  1
# /Users/jmdunca2/nustar/jul-2016/20201004001/
#
# Number of Windows (>= 1 channel):  13
# Number of Windows (>= 3 channels):  1
# 26-jul-16_2
# /Users/jmdunca2/nustar/jul-2016/20201006001/
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Number of Windows (>= 1 channel):  4
# Number of Windows (>= 3 channels):  0
# 11-sep-17
# /Users/jmdunca2/nustar/sep-2017/80310211001/
#
# Number of Windows (>= 1 channel):  22
# Number of Windows (>= 3 channels):  2
# /Users/jmdunca2/nustar/sep-2017/80310212001/
#
# Number of Windows (>= 1 channel):  38
# Number of Windows (>= 3 channels):  3
# /Users/jmdunca2/nustar/sep-2017/80310213001/
#
# Number of Windows (>= 1 channel):  33
# Number of Windows (>= 3 channels):  3
# /Users/jmdunca2/nustar/sep-2017/80310214001/
#
# Number of Windows (>= 1 channel):  3
# Number of Windows (>= 3 channels):  1
# 12-sep-17
# /Users/jmdunca2/nustar/sep-2017/80310229001/
#
# Number of Windows (>= 1 channel):  24
# Number of Windows (>= 3 channels):  3
# /Users/jmdunca2/nustar/sep-2017/80310230001/
#
# Number of Windows (>= 1 channel):  35
# Number of Windows (>= 3 channels):  3
# /Users/jmdunca2/nustar/sep-2017/80310229001/
#
# Number of Windows (>= 1 channel):  24
# Number of Windows (>= 3 channels):  3
# /Users/jmdunca2/nustar/sep-2017/80310230001/
#
# Number of Windows (>= 1 channel):  35
# Number of Windows (>= 3 channels):  3
# 13-sep-17
# /Users/jmdunca2/nustar/sep-2017/80310231001/
#
# Number of Windows (>= 1 channel):  27
# Number of Windows (>= 3 channels):  3
# /Users/jmdunca2/nustar/sep-2017/80310232001/
#
# Number of Windows (>= 1 channel):  1
# Number of Windows (>= 3 channels):  1
# /Users/jmdunca2/nustar/sep-2017/80310231001/
#
# Number of Windows (>= 1 channel):  27
# Number of Windows (>= 3 channels):  3
# /Users/jmdunca2/nustar/sep-2017/80310232001/
#
# Number of Windows (>= 1 channel):  1
# Number of Windows (>= 3 channels):  1
# 10-oct-17
# /Users/jmdunca2/nustar/oct-2017/90311211001/
#
# Number of Windows (>= 1 channel):  1
# Number of Windows (>= 3 channels):  1
# /Users/jmdunca2/nustar/oct-2017/90311212001/
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Number of Windows (>= 1 channel):  29
# Number of Windows (>= 3 channels):  0
# /Users/jmdunca2/nustar/oct-2017/90311213001/
#
# Number of Windows (>= 1 channel):  49
# Number of Windows (>= 3 channels):  5
# /Users/jmdunca2/nustar/oct-2017/90311211001/
#
# Number of Windows (>= 1 channel):  1
# Number of Windows (>= 3 channels):  1
# /Users/jmdunca2/nustar/oct-2017/90311212001/
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Number of Windows (>= 1 channel):  29
# Number of Windows (>= 3 channels):  0
# /Users/jmdunca2/nustar/oct-2017/90311213001/
#
# Number of Windows (>= 1 channel):  49
# Number of Windows (>= 3 channels):  5
# 29-may-18_1
# /Users/jmdunca2/nustar/may-2018/80410201001/
#
# Number of Windows (>= 1 channel):  9
# Number of Windows (>= 3 channels):  1
# /Users/jmdunca2/nustar/may-2018/80410202001/
#
# Number of Windows (>= 1 channel):  5
# Number of Windows (>= 3 channels):  1
# /Users/jmdunca2/nustar/may-2018/80410203001/
#
# Number of Windows (>= 1 channel):  3
# Number of Windows (>= 3 channels):  1
# /Users/jmdunca2/nustar/may-2018/80410204001/
#
# Number of Windows (>= 1 channel):  25
# Number of Windows (>= 3 channels):  1
# /Users/jmdunca2/nustar/may-2018/80410205001/
#
# Number of Windows (>= 1 channel):  21
# Number of Windows (>= 3 channels):  3
# 29-may-18_2
# /Users/jmdunca2/nustar/may-2018/80410206001/
#
# Number of Windows (>= 1 channel):  7
# Number of Windows (>= 3 channels):  1
# 09-sep-18
# /Users/jmdunca2/nustar/sep-2018/80414201001/
#
# Number of Windows (>= 1 channel):  10
# Number of Windows (>= 3 channels):  2
# /Users/jmdunca2/nustar/sep-2018/80414202001/
#
# Number of Windows (>= 1 channel):  1
# Number of Windows (>= 3 channels):  1
# /Users/jmdunca2/nustar/sep-2018/80414203001/
#
# Number of Windows (>= 1 channel):  16
# Number of Windows (>= 3 channels):  2
# 10-sep-18
# /Users/jmdunca2/nustar/sep-2018/80415201001/
#
# Number of Windows (>= 1 channel):  12
# Number of Windows (>= 3 channels):  2
# /Users/jmdunca2/nustar/sep-2018/80415202001/
#
# Number of Windows (>= 1 channel):  1
# Number of Windows (>= 3 channels):  1
# /Users/jmdunca2/nustar/sep-2018/80415203001/
#
# Number of Windows (>= 1 channel):  17
# Number of Windows (>= 3 channels):  1
# 12-apr-19
# /Users/jmdunca2/nustar/apr-2019/80416201001/
#
# Number of Windows (>= 1 channel):  19
# Number of Windows (>= 3 channels):  2
# /Users/jmdunca2/nustar/apr-2019/80416202001/
#
# Number of Windows (>= 1 channel):  3
# Number of Windows (>= 3 channels):  1
# /Users/jmdunca2/nustar/apr-2019/80416203001/
#
# Number of Windows (>= 1 channel):  4
# Number of Windows (>= 3 channels):  2
# /Users/jmdunca2/nustar/apr-2019/80416204001/
#
# Number of Windows (>= 1 channel):  5
# Number of Windows (>= 3 channels):  1
# /Users/jmdunca2/nustar/apr-2019/80416205001/
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Number of Windows (>= 1 channel):  18
# Number of Windows (>= 3 channels):  0
# 13-apr-19
# /Users/jmdunca2/nustar/apr-2019/80416208001/
#
# Number of Windows (>= 1 channel):  2
# Number of Windows (>= 3 channels):  1
# /Users/jmdunca2/nustar/apr-2019/80416209001/
#
# Number of Windows (>= 1 channel):  7
# Number of Windows (>= 3 channels):  4
# /Users/jmdunca2/nustar/apr-2019/80416210001/
#
# Number of Windows (>= 1 channel):  5
# Number of Windows (>= 3 channels):  2
# /Users/jmdunca2/nustar/apr-2019/80416211001/
#
# Number of Windows (>= 1 channel):  3
# Number of Windows (>= 3 channels):  1
# /Users/jmdunca2/nustar/apr-2019/80416212001/
#
# Number of Windows (>= 1 channel):  17
# Number of Windows (>= 3 channels):  2
# /Users/jmdunca2/nustar/apr-2019/80416213001/
#
# Number of Windows (>= 1 channel):  5
# Number of Windows (>= 3 channels):  4
# 29-jan-20
# /Users/jmdunca2/nustar/jan-2020/20513002001/
#
# Number of Windows (>= 1 channel):  8
# Number of Windows (>= 3 channels):  1
# /Users/jmdunca2/nustar/jan-2020/20513005001/
#
# Number of Windows (>= 1 channel):  9
# Number of Windows (>= 3 channels):  2
# /Users/jmdunca2/nustar/jan-2020/20513006001/
#
# Number of Windows (>= 1 channel):  3
# Number of Windows (>= 3 channels):  1
# /Users/jmdunca2/nustar/jan-2020/20513007001/
#
# Number of Windows (>= 1 channel):  7
# Number of Windows (>= 3 channels):  2
# /Users/jmdunca2/nustar/jan-2020/20513008001/
#
# Number of Windows (>= 1 channel):  16
# Number of Windows (>= 3 channels):  1
# 06-jun-20
# /Users/jmdunca2/nustar/jun-2020/20611002001/
#
# Number of Windows (>= 1 channel):  4
# Number of Windows (>= 3 channels):  1
# /Users/jmdunca2/nustar/jun-2020/20611003001/
#
# Number of Windows (>= 1 channel):  10
# Number of Windows (>= 3 channels):  4
# 07-jun-20
# /Users/jmdunca2/nustar/jun-2020/20611005001/
#
# Number of Windows (>= 1 channel):  4
# Number of Windows (>= 3 channels):  2
# /Users/jmdunca2/nustar/jun-2020/20611006001/
#
# Number of Windows (>= 1 channel):  14
# Number of Windows (>= 3 channels):  3
# 08-jun-20
# /Users/jmdunca2/nustar/jun-2020/20611008001/
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Number of Windows (>= 1 channel):  20
# Number of Windows (>= 3 channels):  0
# /Users/jmdunca2/nustar/jun-2020/20611009001/
#
# Number of Windows (>= 1 channel):  8
# Number of Windows (>= 3 channels):  3
# 09-jun-20
# /Users/jmdunca2/nustar/jun-2020/20611010001/
#
# Number of Windows (>= 1 channel):  29
# Number of Windows (>= 3 channels):  2
# 08-jan-21
# /Users/jmdunca2/nustar/jan-2021/20612001001/
#
# Number of Windows (>= 1 channel):  32
# Number of Windows (>= 3 channels):  1
# 20-jan-21
# /Users/jmdunca2/nustar/jan-2021/20614002001/
#
# Number of Windows (>= 1 channel):  2
# Number of Windows (>= 3 channels):  1
# /Users/jmdunca2/nustar/jan-2021/20614003001/
#
# Number of Windows (>= 1 channel):  4
# Number of Windows (>= 3 channels):  2
# 29-apr-21
# /Users/jmdunca2/nustar/apr-2021/20615001001/
#
# Number of Windows (>= 1 channel):  4
# Number of Windows (>= 3 channels):  4
# /Users/jmdunca2/nustar/apr-2021/20615002001/
#
# Number of Windows (>= 1 channel):  5
# Number of Windows (>= 3 channels):  1
# /Users/jmdunca2/nustar/apr-2021/20615003001/
#
# Number of Windows (>= 1 channel):  10
# Number of Windows (>= 3 channels):  2
# /Users/jmdunca2/nustar/apr-2021/20615004001/
#
# Number of Windows (>= 1 channel):  6
# Number of Windows (>= 3 channels):  2
# /Users/jmdunca2/nustar/apr-2021/20615005001/
#
# Number of Windows (>= 1 channel):  9
# Number of Windows (>= 3 channels):  3
# 03-may-21_1
# /Users/jmdunca2/nustar/may-2021/20616001001/
#
# Number of Windows (>= 1 channel):  7
# Number of Windows (>= 3 channels):  4
# /Users/jmdunca2/nustar/may-2021/20616002001/
#
# Number of Windows (>= 1 channel):  2
# Number of Windows (>= 3 channels):  1
# 03-may-21_2
# /Users/jmdunca2/nustar/may-2021/20616003001/
#
# Number of Windows (>= 1 channel):  12
# Number of Windows (>= 3 channels):  1
# /Users/jmdunca2/nustar/may-2021/20616004001/
#
# Number of Windows (>= 1 channel):  37
# Number of Windows (>= 3 channels):  3
# /Users/jmdunca2/nustar/may-2021/20616005001/
#
# Number of Windows (>= 1 channel):  4
# Number of Windows (>= 3 channels):  1
# 07-may-21
# 20-jul-21
# /Users/jmdunca2/nustar/jul-2021/80710201001/
#
# Number of Windows (>= 1 channel):  8
# Number of Windows (>= 3 channels):  1
# /Users/jmdunca2/nustar/jul-2021/80710202001/
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Number of Windows (>= 1 channel):  6
# Number of Windows (>= 3 channels):  0
# /Users/jmdunca2/nustar/jul-2021/80710203001/
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Number of Windows (>= 1 channel):  12
# Number of Windows (>= 3 channels):  0
# /Users/jmdunca2/nustar/jul-2021/80710204001/
#
# Number of Windows (>= 1 channel):  1
# Number of Windows (>= 3 channels):  1
# /Users/jmdunca2/nustar/jul-2021/80710205001/
#
# Number of Windows (>= 1 channel):  4
# Number of Windows (>= 3 channels):  3
# /Users/jmdunca2/nustar/jul-2021/80710206001/
#
# Number of Windows (>= 1 channel):  12
# Number of Windows (>= 3 channels):  3
# /Users/jmdunca2/nustar/jul-2021/80710207001/
#
# Number of Windows (>= 1 channel):  7
# Number of Windows (>= 3 channels):  1
# /Users/jmdunca2/nustar/jul-2021/80710208001/
#
# Number of Windows (>= 1 channel):  25
# Number of Windows (>= 3 channels):  1
# /Users/jmdunca2/nustar/jul-2021/80710201001/
#
# Number of Windows (>= 1 channel):  8
# Number of Windows (>= 3 channels):  1
# /Users/jmdunca2/nustar/jul-2021/80710202001/
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Number of Windows (>= 1 channel):  6
# Number of Windows (>= 3 channels):  0
# /Users/jmdunca2/nustar/jul-2021/80710203001/
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Number of Windows (>= 1 channel):  12
# Number of Windows (>= 3 channels):  0
# /Users/jmdunca2/nustar/jul-2021/80710204001/
#
# Number of Windows (>= 1 channel):  1
# Number of Windows (>= 3 channels):  1
# /Users/jmdunca2/nustar/jul-2021/80710205001/
#
# Number of Windows (>= 1 channel):  4
# Number of Windows (>= 3 channels):  3
# /Users/jmdunca2/nustar/jul-2021/80710206001/
#
# Number of Windows (>= 1 channel):  12
# Number of Windows (>= 3 channels):  3
# /Users/jmdunca2/nustar/jul-2021/80710207001/
#
# Number of Windows (>= 1 channel):  7
# Number of Windows (>= 3 channels):  1
# /Users/jmdunca2/nustar/jul-2021/80710208001/
#
# Number of Windows (>= 1 channel):  25
# Number of Windows (>= 3 channels):  1
# 30-jul-21_1
# /Users/jmdunca2/nustar/jul-2021/90710201001/
#
# Number of Windows (>= 1 channel):  29
# Number of Windows (>= 3 channels):  2
# /Users/jmdunca2/nustar/jul-2021/90710203001/
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Number of Windows (>= 1 channel):  53
# Number of Windows (>= 3 channels):  0
# /Users/jmdunca2/nustar/jul-2021/90710201001/
#
# Number of Windows (>= 1 channel):  29
# Number of Windows (>= 3 channels):  2
# /Users/jmdunca2/nustar/jul-2021/90710203001/
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# Number of Windows (>= 1 channel):  53
# Number of Windows (>= 3 channels):  0
# 30-jul-21_2
# /Users/jmdunca2/nustar/jul-2021/90710202001/
#
# Number of Windows (>= 1 channel):  62
# Number of Windows (>= 3 channels):  1

# %%
keys
# Out:
# ['01-sep-15',
#  '02-sep-15',
#  '19-feb-16',
#  '22-apr-16_2',
#  '26-jul-16_1',
#  '27-jul-16_1',
#  '26-jul-16_2',
#  '11-sep-17',
#  '12-sep-17',
#  '13-sep-17',
#  '10-oct-17',
#  '29-may-18_1',
#  '29-may-18_2',
#  '09-sep-18',
#  '10-sep-18',
#  '12-apr-19',
#  '13-apr-19',
#  '29-jan-20',
#  '06-jun-20',
#  '07-jun-20',
#  '08-jun-20',
#  '09-jun-20',
#  '08-jan-21',
#  '20-jan-21',
#  '29-apr-21',
#  '03-may-21_1',
#  '03-may-21_2',
#  '07-may-21',
#  '20-jul-21',
#  '30-jul-21_1',
#  '30-jul-21_2']

# %%
import glob
import nustar_utilities as nuutil
import nustar_dem_prep as nu
import datetime
#import initial_analysis as ia

#Set path to obsid directory - initial pipeline should have been run already.
ind=1
datapath=id_dirs[ind]
obsid=obsids[ind]

evt_data, hdr = nu.return_submap(datapath=datapath, fpm='A', return_evt_hdr=True)
time0, time1 = [nuutil.convert_nustar_time(hdr['TSTART']), nuutil.convert_nustar_time(hdr['TSTOP'])]
timerange = [time0.tt.datetime, time1.tt.datetime]
from datetime import timezone

#Comment second line if you're not using this same example nustar orbit
#Edit it to include only the desired time interval (default- all times in file) once you've run this once
#timerange=[]
#timerange=[datetime.datetime(2018, 5, 29, 16, 00), datetime.datetime(2018, 5, 29, 16, 55)]
timerange = [t.replace(tzinfo=timezone.utc) for t in timerange]

evtA = glob.glob(datapath+'/event_cl/*A06_cl.evt')
evtB = glob.glob(datapath+'/event_cl/*B06_cl.evt')
hkA  = glob.glob(datapath+'/hk/*A_fpm.hk')
hkB  = glob.glob(datapath+'/hk/*B_fpm.hk')

import lightcurves as lc


importlib.reload(lc)
lc.prepare_nustar_lightcurves(evtA, evtB, hkA, hkB, timebin=15, erange=[2.,4.], 
                              livetime_corr=False, save_dir=working_dir)
lc.prepare_nustar_lightcurves(evtA, evtB, hkA, hkB, timebin=15, erange=[4.,6.], 
                              livetime_corr=False, save_dir=working_dir)
lc.prepare_nustar_lightcurves(evtA, evtB, hkA, hkB, timebin=15, erange=[6.,10.], 
                              livetime_corr=False, save_dir=working_dir)

#lc.plot_nustar_lightcurves(eranges = [[2.,4.],[4.,6.],[6.,10.]],
#                           timerange=timerange, save_dir=working_dir)

importlib.reload(lc)
newwindows = lc.plot_with_stdv(aia_inputs=[], fexviii=False, nustar_inputs=[[2.,4.],[4.,6.],[6.,10.]], 
                   goes_inputs=[], smooth=24, 
                   plot_each=True, plot_logic=True, remove_fexviii_max=False, 
                   analyze_transients=True, transient_number=2,
                   timerange=timerange,
                  excluded_range=[], save_dir=working_dir, savestring=key+'_'+obsid)

# %%
import pickle
import numpy as np

aia_file = '/Users/jmdunca2/do-dem/initial_dem_6jun20/all_aia_dicts_06-jun-20_post/orbit_20611003001/20-59-25_20-59-55_aia_prep.pickle'
with open(aia_file, 'rb') as f:
    aia_dat = pickle.load(f)

np.isnan(aia_dat['aia_dn_s_px']).any()
