# %% [markdown]
# For a multi-orbit observation of a particular active region, how does the amount of NuSTAR emission contained in a standard-size region (as chosen during the standard time interval selection - or correlator-trimmed time interval selection – change over time? How does the former change as a function of when event energies we are looking at?

# %%
import matplotlib.pyplot as plt
import numpy as np
import glob
from astropy.io import fits
from astropy import units as u
import importlib
import pathlib

#Path to top-level do-dem directory - edit for your system.
path_to_dodem = '/Users/jmdunca2/do-dem/'
from sys import path as sys_path
sys_path.append(path_to_dodem+'/dodem/')

import nustar_dem_prep as nu
import initial_analysis as ia
import orbit_auto as oa

# %% [markdown]
# Pick your obsid directories, and make some decisions about time.

# %%
#Select your working directory – where you have saved files listing the time intervals for this observation
working_dir='./initial_dem_may18/'

importlib.reload(oa)

all_time_intervals, all_time_intervals_list = oa.find_all_intervals(working_dir, shush=True)

allpercentsA, allpercentsB = oa.check_region_emission(all_time_intervals, working_dir, grade='0_4', plot=True, efilter=[2.5,3.5])
allpercentsA, allpercentsB = oa.check_region_emission(all_time_intervals, working_dir, grade='0_4', plot=True, efilter=[3.5,6.])
allpercentsA, allpercentsB = oa.check_region_emission(all_time_intervals, working_dir, grade='0_4', plot=True, efilter=[6.,10.])
# Out:
# Bins >5% above mean: 0  out of  322
# Bins >5% below mean: 1  out of  322
#
# Mean emision included:  90.31 %
# Minimum emision included:  84.22 %
# Maximum emision included:  92.66 %
# STDV:  1.15 %
# 2018-05-29 21:06:20
# Bins >5% above mean: 0  out of  322
# Bins >5% below mean: 0  out of  322
#
# Mean emision included:  93.55 %
# Minimum emision included:  89.24 %
# Maximum emision included:  96.12 %
# STDV:  0.97 %
# 2018-05-29 21:06:20
# Bins >5% above mean: 0  out of  322
# Bins >5% below mean: 32  out of  322
#
# Mean emision included:  96.42 %
# Minimum emision included:  76.92 %
# Maximum emision included:  100.0 %
# STDV:  4.12 %
# 2018-05-29 18:03:05

# %%
#Select your working directory – where you have saved files listing the time intervals for this observation
working_dir='./initial_dem_apr21/'

importlib.reload(oa)

all_time_intervals, all_time_intervals_list = oa.find_all_intervals(working_dir, shush=True)

allpercentsA, allpercentsB = oa.check_region_emission(all_time_intervals, working_dir, grade='0_4', plot=True, efilter=[2.5,3.5])
allpercentsA, allpercentsB = oa.check_region_emission(all_time_intervals, working_dir, grade='0_4', plot=True, efilter=[3.5,6.])
allpercentsA, allpercentsB = oa.check_region_emission(all_time_intervals, working_dir, grade='0_4', plot=True, efilter=[6.,10.])
# Out:
# Bins >5% above mean: 0  out of  514
# Bins >5% below mean: 0  out of  514
#
# Mean emision included:  90.56 %
# Minimum emision included:  87.61 %
# Maximum emision included:  92.82 %
# STDV:  0.93 %
# 2021-04-29 16:42:20
# Bins >5% above mean: 0  out of  514
# Bins >5% below mean: 0  out of  514
#
# Mean emision included:  93.49 %
# Minimum emision included:  89.43 %
# Maximum emision included:  95.82 %
# STDV:  1.06 %
# 2021-04-29 21:27:35
# Bins >5% above mean: 0  out of  514
# Bins >5% below mean: 52  out of  514
#
# Mean emision included:  95.62 %
# Minimum emision included:  66.67 %
# Maximum emision included:  100.0 %
# STDV:  4.57 %
# 2021-04-29 15:42:35

# %% [markdown]
# The below is failing because for the first sub-orbit, there is not a single good time interval found.

# %%
#Select your working directory – where you have saved files listing the time intervals for this observation
working_dir='./initial_dem_jul21/'

importlib.reload(oa)

all_time_intervals, all_time_intervals_list = oa.find_all_intervals(working_dir, shush=False)

allpercentsA, allpercentsB = oa.check_region_emission(all_time_intervals, working_dir, grade='0_4', plot=True, efilter=[2.5,3.5])
allpercentsA, allpercentsB = oa.check_region_emission(all_time_intervals, working_dir, grade='0_4', plot=True, efilter=[3.5,6.])
allpercentsA, allpercentsB = oa.check_region_emission(all_time_intervals, working_dir, grade='0_4', plot=True, efilter=[6.,10.])
# Out:
# 0 - 0 18-33-10 18-43-10
#
# 1 - 0 19-48-55 20-00-50
#
# 2 - 0 22-03-10 22-18-20
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 8
#       4 importlib.reload(oa)
#       6 all_time_intervals, all_time_intervals_list = oa.find_all_intervals(working_dir, shush=False)
# ----> 8 allpercentsA, allpercentsB = oa.check_region_emission(all_time_intervals, working_dir, grade='0_4', plot=True, efilter=[2.5,3.5])
#       9 allpercentsA, allpercentsB = oa.check_region_emission(all_time_intervals, working_dir, grade='0_4', plot=True, efilter=[3.5,6.])
#      10 allpercentsA, allpercentsB = oa.check_region_emission(all_time_intervals, working_dir, grade='0_4', plot=True, efilter=[6.,10.])
#
# File ~/do-dem//dodem/orbit_auto.py:360, in check_region_emission(all_time_intervals, working_dir, grade, plot, efilter)
#     358 times.append(tt[1].datetime)
#     359 if once==0:
# ...
