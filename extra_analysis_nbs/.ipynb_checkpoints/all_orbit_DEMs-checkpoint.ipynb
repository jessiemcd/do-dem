# %% [markdown]
# An example notebook to do DEMs for all the time intervals you've previously selected within a given orbit (or other time period).  See the time_interval_selection notebook for how to do this time interval selection – which will result in a .pickle file containing a dictionary with the saved intervals.
#
# First, edit the paths in the following cell to point to the correct locations on your system. Also – for this example, we will be using the demreg DEM method. This is available at: https://github.com/ianan/demreg/tree/master
# You will need to edit the path to demreg in dodem.py (if you don't, an error will come up that will point to the line).
#
# If you don't want to deal with the aia error tables yet, you can always ignore that line and
# set real_aia_err=False in the dem call at the end of the notebook to use a flat uncertainty.

# %%
#AIA Error table - set path to location in your system.
errortab='/Users/jessieduncan/ssw/sdo/aia/response/aia_V3_error_table.txt'

#Sunpy data directory (or wherever else you store your downloaded AIA data)
sunpy_dir='/Users/jessieduncan/sunpy/data/'

#Path to top-level do-dem directory - edit for your system.
path_to_dodem = '/Users/jessieduncan/do-dem/'
from sys import path as sys_path
sys_path.append(path_to_dodem+'/dodem/')

#do-dem
import lightcurves as lc
import region_fitting as rf
import nustar_dem_prep as nu
import dodem
import time_interval_selection as tis
import visualize_dem_results as viz

#Basics
import numpy as np
import importlib
import matplotlib.pyplot as plt
from astropy import units as u

#Time
import matplotlib.dates as mdates
import astropy.time
import datetime

#File wrangling
import glob
import pickle
import os
import pathlib
os.getcwd()

# %% [markdown]
# First, let's take a look at the NuSTAR lightcurves.

# %%
#Name your working directory
working_dir='./initial_dem/'

#Make a new working directory for prepped data/etc if it doesn't yet exist
save_path = pathlib.Path(working_dir)
if not save_path.exists():
    save_path.mkdir()

#Set path to obsid directory - initial pipeline should have been run already.
datapath='/Users/jessieduncan/nustar/may-2018/5_29pixpos/80410205001/'
obsid='80410205001'
gtifile=datapath+'event_cl/nu'+obsid+'A06_gti.fits'

#Comment second line if you're not using this same example nustar orbit
#Edit it to include only the desired time interval (default- all times in file) once you've run this once
timerange=[]
timerange=[datetime.datetime(2018, 5, 29, 22, 22), datetime.datetime(2018, 5, 29, 23, 20)]

time_intervals = tis.get_saved_intervals(timerange, lctype='corr54', erange=[6.,10],       
                                         countmin=10, custom_file=[])

#Print resulting intervals
count=0    
for t in time_intervals:
    print(count, t[0].strftime('%H-%M-%S'), t[1].strftime('%H-%M-%S'))
    count+=1

# %% [markdown]
# Setting DEM basics:

# %%
#What instruments are you using?
#---------------------------------
aia=True
#---------------------------------
eis=False
#---------------------------------
xrt=False
xrt_path=working_dir+'/XRT_for_DEM/'

plot=False
#Here is the exposure time limits dictionary for each XRT filter combination:
exposure_dict={'Be_thin': [1*u.s, 10*u.s],
                'Be_med': [],
              'Al_poly': [0.1*u.s, 1*u.s]}
#---------------------------------
nustar=True
#If nustar is being used, here are the chosen energy ranges:
nuenergies=[[2.5,3.5],[3.5,6.], [6.,10.]]
#---------------------------------

#---------------------------------
#---------------------------------
#What temperature range would you like to use? (units: log(T))
minT=5.6
maxT=7.2

#Would you prefer to plot temperatures in MK, or the default (logT)
plotMK=False
#---------------------------------
#---------------------------------

name='initial_dem'

# %% [markdown]
# By following the process in time_interval_selection, you have already made NuSTAR spectral data products for each of these intervals (at least for FPMA). We have output region files for each time interval, which were used to make the NuSTAR data products via one of two methods:
# - circle with input radius, center at the COM of the NuSTAR emission
# OR
# - circle with input radius, location optimized to contain the maximal amount of NuSTAR emission.
#
# In either case, given NuSTAR's pointing uncertainty, these regions may not be optimal for AIA and XRT.
#
# Here, we will run the DEM code with the just_prep flag set, and the plot commands set true for AIA (and XRT if set True in the cell above). You can then check how well the NuSTAR region works for the other instruments, and define a shift to the location of the circle if needed.
#
# If desired, you can check this with a few time intervals to make sure the shift is appropriate over the whole time interval (edit the first line).

# %%
time_interval = time_intervals[0]
timestring = time_interval[0].strftime('%H-%M-%S')
stopstring = time_interval[1].strftime('%H-%M-%S')
timestring=timestring+'_'+stopstring
    
regfile=working_dir+timestring+'/nu'+obsid+'A06_0_4_p_cl_sunpos_COM_region.reg'
offset, rad = rf.read_regfile(regfile, time_interval[0], time_interval[1], 'hourangle')
print(offset)
print(rad)

xx = offset[0].value
yy = offset[1].value

#Set broad box for plotting (using region object)
bl=[(xx-200)*u.arcsec, (yy-200)*u.arcsec]
tr=[(xx+200)*u.arcsec,(yy+200)*u.arcsec]
print(tr[0]-bl[0], tr[1]-bl[1])

#Make region dictionary 
region_input = {'center': (xx,  yy)*u.arcsec,
                  'radius': rad}



#Run DEM code (just_prep set, stop before actual DEM)
res = dodem.dodem(time_interval, bl, tr, xrt=xrt, aia=aia, nustar=nustar, name=name,
                                    plotMK=plotMK, minT=minT, maxT=maxT,
                                    plotresp=False, working_directory=working_dir,
                                    default_err=0.2, path_to_dodem=path_to_dodem,
                                    just_prep=True,
                                    
                                    #nustar related 
                                    combine_fpm=True, nuenergies=nuenergies, make_nustar=True, 
                                    datapath=datapath, gtifile=gtifile,
                                    COM_nustar_region=True, nuclobber=False, edit_regfile=True,
                                    adjacent_grades=True, pile_up_corr=True,
            
                                    #aia related
                                    aiamethod='Auto', real_aia_err=True,
                                    input_aia_region="circle", input_aia_region_dict=region_input,
                                       sunpy_dir=sunpy_dir, errortab=errortab,
                                       plot_aia=aia,
                                   
                                    #xrt-related
                                    xrtmethod='Average', real_xrt_err=True, xrt_path=xrt_path,
                                    xrt_exposure_dict=exposure_dict,
                                    input_xrt_region="circle", input_xrt_region_dict=region_input,
                                       plot_xrt=xrt)

# %%
#Add shift to region and run again to check result:
region_input = {'center': (xx-45,  yy+25)*u.arcsec,
                  'radius': rad}
print(region_input['center'])
#Run DEM code (just_prep set, stop before actual DEM)
res = dodem.dodem(time_interval, bl, tr, xrt=xrt, aia=aia, nustar=nustar, name=name,
                                    plotMK=plotMK, minT=minT, maxT=maxT,
                                    plotresp=False, working_directory=working_dir,
                                    default_err=0.2, path_to_dodem=path_to_dodem,
                                    just_prep=True,
                                    
                                    #nustar related 
                                    combine_fpm=True, nuenergies=nuenergies, make_nustar=True, 
                                    datapath=datapath, gtifile=gtifile,
                                    COM_nustar_region=True, nuclobber=False, edit_regfile=True,
                                    adjacent_grades=True, pile_up_corr=True,
            
                                    #aia related
                                    aiamethod='Auto', real_aia_err=True,
                                    input_aia_region="circle", input_aia_region_dict=region_input,
                                       sunpy_dir=sunpy_dir, errortab=errortab,
                                       plot_aia=aia,
                                   
                                    #xrt-related
                                    xrtmethod='Average', real_xrt_err=True, xrt_path=xrt_path,
                                    xrt_exposure_dict=exposure_dict,
                                    input_xrt_region="circle", input_xrt_region_dict=region_input,
                                       plot_xrt=xrt)

# %% [markdown]
# Now that we have an adjusted region for AIA (and/or XRT), let's run the DEMs for the whole time interval.
# This can be sloooow, for a few reasons:
# - If your observation has decent statistics, it's possible you haven't made the FPMB spectral data products for all (or some) intervals yet – as if more than your minimum count target was found in FPMA for a given interval, FPMB isn't checked. Making the NuSTAR spectral data products takes a while.
# - If you've never looked at this orbit before (or with these time intervals), you'll need to download AIA data as well as prep it. This is interminable, especially since the JSOC will throttle you for trying to download a lot of data.
#
# Once you run the DEM once, repeating it to change something about the DEM process is much quicker – it took ~4 hours to run this example the first time, and ~22 minutes thereafter.

# %%
for t in time_intervals:
    dodem.dodem(t, bl, tr, xrt=xrt, aia=aia, nustar=nustar, name=name,
                                    plotMK=plotMK, minT=minT, maxT=maxT,
                                    plotresp=False, working_directory=working_dir,
                                    default_err=0.2, path_to_dodem=path_to_dodem,
                
                                    #demreg related
                                    rgt_fact=1.2, max_iter=30,
                                    reg_tweak=1, gloci=1, mc_in=True, mc_rounds=100,
                                    
                                    #nustar related 
                                    combine_fpm=True, nuenergies=nuenergies, make_nustar=True, 
                                    datapath=datapath, gtifile=gtifile,
                                    COM_nustar_region=True, nuclobber=False, edit_regfile=True,
                                    adjacent_grades=True, pile_up_corr=True,
            
                                    #aia related
                                    aiamethod='Auto', real_aia_err=True,
                                    input_aia_region="circle", input_aia_region_dict=region_input,
                                       sunpy_dir=sunpy_dir, errortab=errortab,
                                       plot_aia=False,
                                   
                                    #xrt-related
                                    xrtmethod='Average', real_xrt_err=True, xrt_path=xrt_path,
                                    xrt_exposure_dict=exposure_dict,
                                    input_xrt_region="circle", input_xrt_region_dict=region_input,
                                       plot_xrt=False)
# Out:
# Max NuSTAR Energy:  7.71999979019165
# ARF File:  ['./initial_dem/22-29-00_22-30-00/nu80410205001B06_0_p_sr.arf']
# RMF File:  ['./initial_dem/22-29-00_22-30-00/nu80410205001B06_0_p_sr.rmf']
# PHA File:  ['./initial_dem/22-29-00_22-30-00/nu80410205001B06_0_p_sr.pha']
# Using grades 0-4 NuSTAR events.
# ARF File:  ['./initial_dem/22-29-00_22-30-00/nu80410205001B06_0_4_p_sr.arf']
# RMF File:  ['./initial_dem/22-29-00_22-30-00/nu80410205001B06_0_4_p_sr.rmf']
# PHA File:  ['./initial_dem/22-29-00_22-30-00/nu80410205001B06_0_4_p_sr.pha']
# ARF File:  ['./initial_dem/22-29-00_22-30-00/nu80410205001B06_21_24_p_sr.arf']
# RMF File:  ['./initial_dem/22-29-00_22-30-00/nu80410205001B06_21_24_p_sr.rmf']
# PHA File:  ['./initial_dem/22-29-00_22-30-00/nu80410205001B06_21_24_p_sr.pha']
#
# Max NuSTAR Energy:  7.079999923706055
#
# A94 :     2.95   1.51  51 %
# A131 :     24.15   4.28  18 %
# A171 :     647.02   67.46  10 %
# A193 :     755.15   77.90  10 %
# A211 :     275.58   29.05  11 %
# A335 :     19.96   2.86  14 %
# 2.5-3.5keV A+B :     6142.07   1231.45  20 %
# 3.5-6.0keV A+B :     816.56   166.32  20 %
# 6.0-10.0keV A+B :     12.49   4.63  37 %
#
# Doing 100 iterations of DEMReg with input varied within uncertainty!
#
# WARNING: ITERATION  60  HAS 0 or NEGATIVE-DEM TEMP. BINS!!!
# Not saving this iteration!!
#
#
# WARNING: ITERATION  27  HAS 0 or NEGATIVE-DEM TEMP. BINS!!!
# Not saving this iteration!!
#
# Start Time:  2018-05-29 22:30:00
# Stop Time:  2018-05-29 22:31:40
# You provided both a region box and a specific region.
# Bounding box will be used only for initial data prep (will save submap instead of full disk);
# specific region will be used for DEM
#
# Adding 10% error in quadrature with aiapy.estimate_error output.
#
# ARF File:  ['./initial_dem/22-30-00_22-31-40/nu80410205001A06_0_p_sr.arf']
# RMF File:  ['./initial_dem/22-30-00_22-31-40/nu80410205001A06_0_p_sr.rmf']
# PHA File:  ['./initial_dem/22-30-00_22-31-40/nu80410205001A06_0_p_sr.pha']
# Using grades 0-4 NuSTAR events.
# ARF File:  ['./initial_dem/22-30-00_22-31-40/nu80410205001A06_0_4_p_sr.arf']
# RMF File:  ['./initial_dem/22-30-00_22-31-40/nu80410205001A06_0_4_p_sr.rmf']
# PHA File:  ['./initial_dem/22-30-00_22-31-40/nu80410205001A06_0_4_p_sr.pha']
# ARF File:  ['./initial_dem/22-30-00_22-31-40/nu80410205001A06_21_24_p_sr.arf']
# RMF File:  ['./initial_dem/22-30-00_22-31-40/nu80410205001A06_21_24_p_sr.rmf']
# PHA File:  ['./initial_dem/22-30-00_22-31-40/nu80410205001A06_21_24_p_sr.pha']
#
# Max NuSTAR Energy:  8.319999694824219
# ARF File:  ['./initial_dem/22-30-00_22-31-40/nu80410205001B06_0_p_sr.arf']
# RMF File:  ['./initial_dem/22-30-00_22-31-40/nu80410205001B06_0_p_sr.rmf']
# PHA File:  ['./initial_dem/22-30-00_22-31-40/nu80410205001B06_0_p_sr.pha']
# Using grades 0-4 NuSTAR events.
# ARF File:  ['./initial_dem/22-30-00_22-31-40/nu80410205001B06_0_4_p_sr.arf']
# RMF File:  ['./initial_dem/22-30-00_22-31-40/nu80410205001B06_0_4_p_sr.rmf']
# PHA File:  ['./initial_dem/22-30-00_22-31-40/nu80410205001B06_0_4_p_sr.pha']
# ARF File:  ['./initial_dem/22-30-00_22-31-40/nu80410205001B06_21_24_p_sr.arf']
# RMF File:  ['./initial_dem/22-30-00_22-31-40/nu80410205001B06_21_24_p_sr.rmf']
# PHA File:  ['./initial_dem/22-30-00_22-31-40/nu80410205001B06_21_24_p_sr.pha']
#
# Max NuSTAR Energy:  7.159999847412109
#
# A94 :     2.94   1.50  51 %
# A131 :     24.15   4.28  18 %
# A171 :     647.05   67.47  10 %
# A193 :     753.84   77.77  10 %
# A211 :     275.15   29.01  11 %
# A335 :     19.91   2.86  14 %
# 2.5-3.5keV A+B :     5891.98   1180.16  20 %
# 3.5-6.0keV A+B :     692.12   140.18  20 %
# 6.0-10.0keV A+B :     5.59   2.25  40 %
#
# Doing 100 iterations of DEMReg with input varied within uncertainty!
#
# WARNING: ITERATION  18  HAS 0 or NEGATIVE-DEM TEMP. BINS!!!
# Not saving this iteration!!
#
#
# WARNING: ITERATION  16  HAS 0 or NEGATIVE-DEM TEMP. BINS!!!
# Not saving this iteration!!
#
# Start Time:  2018-05-29 22:31:40
# Stop Time:  2018-05-29 22:33:00
# You provided both a region box and a specific region.
# Bounding box will be used only for initial data prep (will save submap instead of full disk);
# specific region will be used for DEM
#
# Adding 10% error in quadrature with aiapy.estimate_error output.
#
# ARF File:  ['./initial_dem/22-31-40_22-33-00/nu80410205001A06_0_p_sr.arf']
# RMF File:  ['./initial_dem/22-31-40_22-33-00/nu80410205001A06_0_p_sr.rmf']
# PHA File:  ['./initial_dem/22-31-40_22-33-00/nu80410205001A06_0_p_sr.pha']
# Using grades 0-4 NuSTAR events.
# ARF File:  ['./initial_dem/22-31-40_22-33-00/nu80410205001A06_0_4_p_sr.arf']
# RMF File:  ['./initial_dem/22-31-40_22-33-00/nu80410205001A06_0_4_p_sr.rmf']
# PHA File:  ['./initial_dem/22-31-40_22-33-00/nu80410205001A06_0_4_p_sr.pha']
# ARF File:  ['./initial_dem/22-31-40_22-33-00/nu80410205001A06_21_24_p_sr.arf']
# RMF File:  ['./initial_dem/22-31-40_22-33-00/nu80410205001A06_21_24_p_sr.rmf']
# PHA File:  ['./initial_dem/22-31-40_22-33-00/nu80410205001A06_21_24_p_sr.pha']
#
# Max NuSTAR Energy:  6.599999904632568
# ARF File:  ['./initial_dem/22-31-40_22-33-00/nu80410205001B06_0_p_sr.arf']
# RMF File:  ['./initial_dem/22-31-40_22-33-00/nu80410205001B06_0_p_sr.rmf']
# PHA File:  ['./initial_dem/22-31-40_22-33-00/nu80410205001B06_0_p_sr.pha']
# Using grades 0-4 NuSTAR events.
# ARF File:  ['./initial_dem/22-31-40_22-33-00/nu80410205001B06_0_4_p_sr.arf']
# RMF File:  ['./initial_dem/22-31-40_22-33-00/nu80410205001B06_0_4_p_sr.rmf']
# PHA File:  ['./initial_dem/22-31-40_22-33-00/nu80410205001B06_0_4_p_sr.pha']
# ARF File:  ['./initial_dem/22-31-40_22-33-00/nu80410205001B06_21_24_p_sr.arf']
# RMF File:  ['./initial_dem/22-31-40_22-33-00/nu80410205001B06_21_24_p_sr.rmf']
# PHA File:  ['./initial_dem/22-31-40_22-33-00/nu80410205001B06_21_24_p_sr.pha']
#
# Max NuSTAR Energy:  7.919999599456787
#
# A94 :     2.94   1.50  51 %
# A131 :     24.17   4.28  18 %
# A171 :     646.87   67.45  10 %
# A193 :     752.96   77.68  10 %
# A211 :     274.81   28.97  11 %
# A335 :     19.89   2.86  14 %
# 2.5-3.5keV A+B :     5697.40   1141.63  20 %
# 3.5-6.0keV A+B :     597.63   121.66  20 %
# 6.0-10.0keV A+B :     5.91   2.38  40 %
#
# Doing 100 iterations of DEMReg with input varied within uncertainty!
#
# WARNING: ITERATION  93  HAS 0 or NEGATIVE-DEM TEMP. BINS!!!
# Not saving this iteration!!
#
#
# WARNING: ITERATION  28  HAS 0 or NEGATIVE-DEM TEMP. BINS!!!
# Not saving this iteration!!
#
# Start Time:  2018-05-29 22:33:00
# Stop Time:  2018-05-29 22:35:40
# You provided both a region box and a specific region.
# Bounding box will be used only for initial data prep (will save submap instead of full disk);
# specific region will be used for DEM
#
# Adding 10% error in quadrature with aiapy.estimate_error output.
#
# ARF File:  ['./initial_dem/22-33-00_22-35-40/nu80410205001A06_0_p_sr.arf']
# RMF File:  ['./initial_dem/22-33-00_22-35-40/nu80410205001A06_0_p_sr.rmf']
# PHA File:  ['./initial_dem/22-33-00_22-35-40/nu80410205001A06_0_p_sr.pha']
# Using grades 0-4 NuSTAR events.
# ARF File:  ['./initial_dem/22-33-00_22-35-40/nu80410205001A06_0_4_p_sr.arf']
# RMF File:  ['./initial_dem/22-33-00_22-35-40/nu80410205001A06_0_4_p_sr.rmf']
# PHA File:  ['./initial_dem/22-33-00_22-35-40/nu80410205001A06_0_4_p_sr.pha']
# ARF File:  ['./initial_dem/22-33-00_22-35-40/nu80410205001A06_21_24_p_sr.arf']
# RMF File:  ['./initial_dem/22-33-00_22-35-40/nu80410205001A06_21_24_p_sr.rmf']
# PHA File:  ['./initial_dem/22-33-00_22-35-40/nu80410205001A06_21_24_p_sr.pha']
#
# Max NuSTAR Energy:  6.679999828338623
# ARF File:  ['./initial_dem/22-33-00_22-35-40/nu80410205001B06_0_p_sr.arf']
# RMF File:  ['./initial_dem/22-33-00_22-35-40/nu80410205001B06_0_p_sr.rmf']
# PHA File:  ['./initial_dem/22-33-00_22-35-40/nu80410205001B06_0_p_sr.pha']
# Using grades 0-4 NuSTAR events.
# ARF File:  ['./initial_dem/22-33-00_22-35-40/nu80410205001B06_0_4_p_sr.arf']
# RMF File:  ['./initial_dem/22-33-00_22-35-40/nu80410205001B06_0_4_p_sr.rmf']
# PHA File:  ['./initial_dem/22-33-00_22-35-40/nu80410205001B06_0_4_p_sr.pha']
# ARF File:  ['./initial_dem/22-33-00_22-35-40/nu80410205001B06_21_24_p_sr.arf']
# RMF File:  ['./initial_dem/22-33-00_22-35-40/nu80410205001B06_21_24_p_sr.rmf']
# PHA File:  ['./initial_dem/22-33-00_22-35-40/nu80410205001B06_21_24_p_sr.pha']
#
# Max NuSTAR Energy:  20.479999542236328
# Warning: there is at least one NuSTAR event of higher energy than your highest energy range
# Highest energy range: [6.0, 10.0]
# Total Above:  1
# Above Energies:  [20.47999954]
#
# A94 :     2.94   1.50  51 %
# A131 :     24.24   4.29  18 %
# A171 :     648.40   67.60  10 %
# A193 :     752.22   77.61  10 %
# A211 :     274.64   28.95  11 %
# A335 :     19.89   2.86  14 %
# 2.5-3.5keV A+B :     5821.49   1165.37  20 %
# 3.5-6.0keV A+B :     613.49   123.76  20 %
# 6.0-10.0keV A+B :     3.32   1.36  41 %
#
# Doing 100 iterations of DEMReg with input varied within uncertainty!
# WARNING: ITERATION  12  HAS 0 or NEGATIVE-DEM TEMP. BINS!!!
# Not saving this iteration!!
#
# Start Time:  2018-05-29 22:35:40
# Stop Time:  2018-05-29 22:39:45
# You provided both a region box and a specific region.
# Bounding box will be used only for initial data prep (will save submap instead of full disk);
# specific region will be used for DEM
#
# Adding 10% error in quadrature with aiapy.estimate_error output.
#
# ARF File:  ['./initial_dem/22-35-40_22-39-45/nu80410205001A06_0_p_sr.arf']
# RMF File:  ['./initial_dem/22-35-40_22-39-45/nu80410205001A06_0_p_sr.rmf']
# PHA File:  ['./initial_dem/22-35-40_22-39-45/nu80410205001A06_0_p_sr.pha']
# Using grades 0-4 NuSTAR events.
# ARF File:  ['./initial_dem/22-35-40_22-39-45/nu80410205001A06_0_4_p_sr.arf']
# RMF File:  ['./initial_dem/22-35-40_22-39-45/nu80410205001A06_0_4_p_sr.rmf']
# PHA File:  ['./initial_dem/22-35-40_22-39-45/nu80410205001A06_0_4_p_sr.pha']
# ARF File:  ['./initial_dem/22-35-40_22-39-45/nu80410205001A06_21_24_p_sr.arf']
# RMF File:  ['./initial_dem/22-35-40_22-39-45/nu80410205001A06_21_24_p_sr.rmf']
# PHA File:  ['./initial_dem/22-35-40_22-39-45/nu80410205001A06_21_24_p_sr.pha']
#
# Max NuSTAR Energy:  7.439999580383301
# ARF File:  ['./initial_dem/22-35-40_22-39-45/nu80410205001B06_0_p_sr.arf']
# RMF File:  ['./initial_dem/22-35-40_22-39-45/nu80410205001B06_0_p_sr.rmf']
# PHA File:  ['./initial_dem/22-35-40_22-39-45/nu80410205001B06_0_p_sr.pha']
# Using grades 0-4 NuSTAR events.
# ARF File:  ['./initial_dem/22-35-40_22-39-45/nu80410205001B06_0_4_p_sr.arf']
# RMF File:  ['./initial_dem/22-35-40_22-39-45/nu80410205001B06_0_4_p_sr.rmf']
# PHA File:  ['./initial_dem/22-35-40_22-39-45/nu80410205001B06_0_4_p_sr.pha']
# ARF File:  ['./initial_dem/22-35-40_22-39-45/nu80410205001B06_21_24_p_sr.arf']
# RMF File:  ['./initial_dem/22-35-40_22-39-45/nu80410205001B06_21_24_p_sr.rmf']
# PHA File:  ['./initial_dem/22-35-40_22-39-45/nu80410205001B06_21_24_p_sr.pha']
#
# Max NuSTAR Energy:  9.15999984741211
#
# A94 :     2.94   1.50  51 %
# A131 :     24.26   4.29  18 %
# A171 :     651.20   67.88  10 %
# A193 :     751.03   77.49  10 %
# A211 :     274.53   28.94  11 %
# A335 :     19.85   2.85  14 %
# 2.5-3.5keV A+B :     6095.17   1219.75  20 %
# 3.5-6.0keV A+B :     695.09   139.73  20 %
# 6.0-10.0keV A+B :     2.27   0.90  40 %
#
# Doing 100 iterations of DEMReg with input varied within uncertainty!
#
# WARNING: ITERATION  95  HAS 0 or NEGATIVE-DEM TEMP. BINS!!!
# Not saving this iteration!!
#
#
# WARNING: ITERATION  63  HAS 0 or NEGATIVE-DEM TEMP. BINS!!!
# Not saving this iteration!!
#
#
# WARNING: ITERATION  52  HAS 0 or NEGATIVE-DEM TEMP. BINS!!!
# Not saving this iteration!!
#
#
# WARNING: ITERATION  2  HAS 0 or NEGATIVE-DEM TEMP. BINS!!!
# Not saving this iteration!!
#
# Start Time:  2018-05-29 22:39:45
# Stop Time:  2018-05-29 22:43:15
# You provided both a region box and a specific region.
# Bounding box will be used only for initial data prep (will save submap instead of full disk);
# specific region will be used for DEM
#
# Adding 10% error in quadrature with aiapy.estimate_error output.
#
# ARF File:  ['./initial_dem/22-39-45_22-43-15/nu80410205001A06_0_p_sr.arf']
# RMF File:  ['./initial_dem/22-39-45_22-43-15/nu80410205001A06_0_p_sr.rmf']
# PHA File:  ['./initial_dem/22-39-45_22-43-15/nu80410205001A06_0_p_sr.pha']
# Using grades 0-4 NuSTAR events.
# ARF File:  ['./initial_dem/22-39-45_22-43-15/nu80410205001A06_0_4_p_sr.arf']
# RMF File:  ['./initial_dem/22-39-45_22-43-15/nu80410205001A06_0_4_p_sr.rmf']
# PHA File:  ['./initial_dem/22-39-45_22-43-15/nu80410205001A06_0_4_p_sr.pha']
# ARF File:  ['./initial_dem/22-39-45_22-43-15/nu80410205001A06_21_24_p_sr.arf']
# RMF File:  ['./initial_dem/22-39-45_22-43-15/nu80410205001A06_21_24_p_sr.rmf']
# PHA File:  ['./initial_dem/22-39-45_22-43-15/nu80410205001A06_21_24_p_sr.pha']
#
# Max NuSTAR Energy:  7.599999904632568
# ARF File:  ['./initial_dem/22-39-45_22-43-15/nu80410205001B06_0_p_sr.arf']
# RMF File:  ['./initial_dem/22-39-45_22-43-15/nu80410205001B06_0_p_sr.rmf']
# PHA File:  ['./initial_dem/22-39-45_22-43-15/nu80410205001B06_0_p_sr.pha']
# Using grades 0-4 NuSTAR events.
# ARF File:  ['./initial_dem/22-39-45_22-43-15/nu80410205001B06_0_4_p_sr.arf']
# RMF File:  ['./initial_dem/22-39-45_22-43-15/nu80410205001B06_0_4_p_sr.rmf']
# PHA File:  ['./initial_dem/22-39-45_22-43-15/nu80410205001B06_0_4_p_sr.pha']
# ARF File:  ['./initial_dem/22-39-45_22-43-15/nu80410205001B06_21_24_p_sr.arf']
# RMF File:  ['./initial_dem/22-39-45_22-43-15/nu80410205001B06_21_24_p_sr.rmf']
# PHA File:  ['./initial_dem/22-39-45_22-43-15/nu80410205001B06_21_24_p_sr.pha']
#
# Max NuSTAR Energy:  7.759999752044678
#
# A94 :     2.94   1.50  51 %
# A131 :     24.36   4.30  18 %
# A171 :     653.68   68.13  10 %
# A193 :     750.53   77.44  10 %
# A211 :     274.59   28.95  11 %
# A335 :     19.82   2.85  14 %
# 2.5-3.5keV A+B :     6044.24   1209.67  20 %
# 3.5-6.0keV A+B :     677.93   136.41  20 %
# 6.0-10.0keV A+B :     2.70   1.07  40 %
#
# Doing 100 iterations of DEMReg with input varied within uncertainty!
#
# WARNING: ITERATION  97  HAS 0 or NEGATIVE-DEM TEMP. BINS!!!
# Not saving this iteration!!
#
#
# WARNING: ITERATION  25  HAS 0 or NEGATIVE-DEM TEMP. BINS!!!
# Not saving this iteration!!
#
# WARNING: ITERATION  10  HAS Very Small Solution!
# SOLUTION MAX: 239619483090831.94
# Not saving this iteration!!
# If you want to turn this off, comment it out in dodem.
# Start Time:  2018-05-29 22:43:15
# Stop Time:  2018-05-29 22:46:05
# You provided both a region box and a specific region.
# Bounding box will be used only for initial data prep (will save submap instead of full disk);
# specific region will be used for DEM
#
# Adding 10% error in quadrature with aiapy.estimate_error output.
#
# ARF File:  ['./initial_dem/22-43-15_22-46-05/nu80410205001A06_0_p_sr.arf']
# RMF File:  ['./initial_dem/22-43-15_22-46-05/nu80410205001A06_0_p_sr.rmf']
# PHA File:  ['./initial_dem/22-43-15_22-46-05/nu80410205001A06_0_p_sr.pha']
# Using grades 0-4 NuSTAR events.
# ARF File:  ['./initial_dem/22-43-15_22-46-05/nu80410205001A06_0_4_p_sr.arf']
# RMF File:  ['./initial_dem/22-43-15_22-46-05/nu80410205001A06_0_4_p_sr.rmf']
# PHA File:  ['./initial_dem/22-43-15_22-46-05/nu80410205001A06_0_4_p_sr.pha']
# ARF File:  ['./initial_dem/22-43-15_22-46-05/nu80410205001A06_21_24_p_sr.arf']
# RMF File:  ['./initial_dem/22-43-15_22-46-05/nu80410205001A06_21_24_p_sr.rmf']
# PHA File:  ['./initial_dem/22-43-15_22-46-05/nu80410205001A06_21_24_p_sr.pha']
#
# Max NuSTAR Energy:  6.799999713897705
# ARF File:  ['./initial_dem/22-43-15_22-46-05/nu80410205001B06_0_p_sr.arf']
# RMF File:  ['./initial_dem/22-43-15_22-46-05/nu80410205001B06_0_p_sr.rmf']
# PHA File:  ['./initial_dem/22-43-15_22-46-05/nu80410205001B06_0_p_sr.pha']
# Using grades 0-4 NuSTAR events.
# ARF File:  ['./initial_dem/22-43-15_22-46-05/nu80410205001B06_0_4_p_sr.arf']
# RMF File:  ['./initial_dem/22-43-15_22-46-05/nu80410205001B06_0_4_p_sr.rmf']
# PHA File:  ['./initial_dem/22-43-15_22-46-05/nu80410205001B06_0_4_p_sr.pha']
# ARF File:  ['./initial_dem/22-43-15_22-46-05/nu80410205001B06_21_24_p_sr.arf']
# RMF File:  ['./initial_dem/22-43-15_22-46-05/nu80410205001B06_21_24_p_sr.rmf']
# PHA File:  ['./initial_dem/22-43-15_22-46-05/nu80410205001B06_21_24_p_sr.pha']
#
# Max NuSTAR Energy:  7.039999961853027
#
# A94 :     2.94   1.50  51 %
# A131 :     24.40   4.31  18 %
# A171 :     654.39   68.20  10 %
# A193 :     749.40   77.33  10 %
# A211 :     274.23   28.91  11 %
# A335 :     19.81   2.85  14 %
# 2.5-3.5keV A+B :     5621.22   1125.30  20 %
# 3.5-6.0keV A+B :     625.43   126.14  20 %
# 6.0-10.0keV A+B :     2.92   1.25  43 %
#
# Doing 100 iterations of DEMReg with input varied within uncertainty!
#
# WARNING: ITERATION  60  HAS 0 or NEGATIVE-DEM TEMP. BINS!!!
# Not saving this iteration!!
#
#
# WARNING: ITERATION  15  HAS 0 or NEGATIVE-DEM TEMP. BINS!!!
# Not saving this iteration!!
#
#
# WARNING: ITERATION  8  HAS 0 or NEGATIVE-DEM TEMP. BINS!!!
# Not saving this iteration!!
#
# Start Time:  2018-05-29 22:46:05
# Stop Time:  2018-05-29 22:48:55
# You provided both a region box and a specific region.
# Bounding box will be used only for initial data prep (will save submap instead of full disk);
# specific region will be used for DEM
#
# Adding 10% error in quadrature with aiapy.estimate_error output.
#
# ARF File:  ['./initial_dem/22-46-05_22-48-55/nu80410205001A06_0_p_sr.arf']
# RMF File:  ['./initial_dem/22-46-05_22-48-55/nu80410205001A06_0_p_sr.rmf']
# PHA File:  ['./initial_dem/22-46-05_22-48-55/nu80410205001A06_0_p_sr.pha']
# Using grades 0-4 NuSTAR events.
# ARF File:  ['./initial_dem/22-46-05_22-48-55/nu80410205001A06_0_4_p_sr.arf']
# RMF File:  ['./initial_dem/22-46-05_22-48-55/nu80410205001A06_0_4_p_sr.rmf']
# PHA File:  ['./initial_dem/22-46-05_22-48-55/nu80410205001A06_0_4_p_sr.pha']
# ARF File:  ['./initial_dem/22-46-05_22-48-55/nu80410205001A06_21_24_p_sr.arf']
# RMF File:  ['./initial_dem/22-46-05_22-48-55/nu80410205001A06_21_24_p_sr.rmf']
# PHA File:  ['./initial_dem/22-46-05_22-48-55/nu80410205001A06_21_24_p_sr.pha']
# Max NuSTAR Energy:  7.599999904632568
# ARF File:  ['./initial_dem/22-46-05_22-48-55/nu80410205001B06_0_p_sr.arf']
# RMF File:  ['./initial_dem/22-46-05_22-48-55/nu80410205001B06_0_p_sr.rmf']
# PHA File:  ['./initial_dem/22-46-05_22-48-55/nu80410205001B06_0_p_sr.pha']
# Using grades 0-4 NuSTAR events.
# ARF File:  ['./initial_dem/22-46-05_22-48-55/nu80410205001B06_0_4_p_sr.arf']
# RMF File:  ['./initial_dem/22-46-05_22-48-55/nu80410205001B06_0_4_p_sr.rmf']
# PHA File:  ['./initial_dem/22-46-05_22-48-55/nu80410205001B06_0_4_p_sr.pha']
# ARF File:  ['./initial_dem/22-46-05_22-48-55/nu80410205001B06_21_24_p_sr.arf']
# RMF File:  ['./initial_dem/22-46-05_22-48-55/nu80410205001B06_21_24_p_sr.rmf']
# PHA File:  ['./initial_dem/22-46-05_22-48-55/nu80410205001B06_21_24_p_sr.pha']
#
# Max NuSTAR Energy:  9.600000381469727
#
# ['2.5-3.5keV', '3.5-6.0keV']
# Removed rate in  [6.0, 10.0] B  for being negative after pile-up correction.
#
# A94 :     2.93   1.50  51 %
# A131 :     24.37   4.30  18 %
# A171 :     653.11   68.07  10 %
# A193 :     746.66   77.05  10 %
# A211 :     273.63   28.85  11 %
# A335 :     19.75   2.84  14 %
# 2.5-3.5keV A+B :     5557.32   1112.52  20 %
# 3.5-6.0keV A+B :     645.52   130.16  20 %
# 6.0-10.0keV A +  :     3.50   1.12  32 %
#
# Doing 100 iterations of DEMReg with input varied within uncertainty!
#
# WARNING: ITERATION  65  HAS 0 or NEGATIVE-DEM TEMP. BINS!!!
# Not saving this iteration!!
#
#
# WARNING: ITERATION  59  HAS 0 or NEGATIVE-DEM TEMP. BINS!!!
# Not saving this iteration!!
#
#
# WARNING: ITERATION  47  HAS 0 or NEGATIVE-DEM TEMP. BINS!!!
# Not saving this iteration!!
#
# Start Time:  2018-05-29 22:48:55
# Stop Time:  2018-05-29 22:50:50
# You provided both a region box and a specific region.
# Bounding box will be used only for initial data prep (will save submap instead of full disk);
# specific region will be used for DEM
#
# Adding 10% error in quadrature with aiapy.estimate_error output.
#
# ARF File:  ['./initial_dem/22-48-55_22-50-50/nu80410205001A06_0_p_sr.arf']
# RMF File:  ['./initial_dem/22-48-55_22-50-50/nu80410205001A06_0_p_sr.rmf']
# PHA File:  ['./initial_dem/22-48-55_22-50-50/nu80410205001A06_0_p_sr.pha']
# Using grades 0-4 NuSTAR events.
# ARF File:  ['./initial_dem/22-48-55_22-50-50/nu80410205001A06_0_4_p_sr.arf']
# RMF File:  ['./initial_dem/22-48-55_22-50-50/nu80410205001A06_0_4_p_sr.rmf']
# PHA File:  ['./initial_dem/22-48-55_22-50-50/nu80410205001A06_0_4_p_sr.pha']
# ARF File:  ['./initial_dem/22-48-55_22-50-50/nu80410205001A06_21_24_p_sr.arf']
# RMF File:  ['./initial_dem/22-48-55_22-50-50/nu80410205001A06_21_24_p_sr.rmf']
# PHA File:  ['./initial_dem/22-48-55_22-50-50/nu80410205001A06_21_24_p_sr.pha']
#
# Max NuSTAR Energy:  9.039999961853027
# ARF File:  ['./initial_dem/22-48-55_22-50-50/nu80410205001B06_0_p_sr.arf']
# RMF File:  ['./initial_dem/22-48-55_22-50-50/nu80410205001B06_0_p_sr.rmf']
# PHA File:  ['./initial_dem/22-48-55_22-50-50/nu80410205001B06_0_p_sr.pha']
# Using grades 0-4 NuSTAR events.
# ARF File:  ['./initial_dem/22-48-55_22-50-50/nu80410205001B06_0_4_p_sr.arf']
# RMF File:  ['./initial_dem/22-48-55_22-50-50/nu80410205001B06_0_4_p_sr.rmf']
# PHA File:  ['./initial_dem/22-48-55_22-50-50/nu80410205001B06_0_4_p_sr.pha']
# ARF File:  ['./initial_dem/22-48-55_22-50-50/nu80410205001B06_21_24_p_sr.arf']
# RMF File:  ['./initial_dem/22-48-55_22-50-50/nu80410205001B06_21_24_p_sr.rmf']
# PHA File:  ['./initial_dem/22-48-55_22-50-50/nu80410205001B06_21_24_p_sr.pha']
#
# Max NuSTAR Energy:  7.479999542236328
#
# A94 :     2.92   1.50  51 %
# A131 :     24.30   4.30  18 %
# A171 :     652.67   68.03  10 %
# A193 :     744.99   76.88  10 %
# A211 :     273.44   28.83  11 %
# A335 :     19.73   2.84  14 %
# 2.5-3.5keV A+B :     5914.73   1184.47  20 %
# 3.5-6.0keV A+B :     684.45   138.40  20 %
# 6.0-10.0keV A+B :     3.90   1.73  44 %
#
# Doing 100 iterations of DEMReg with input varied within uncertainty!
#
# WARNING: ITERATION  55  HAS 0 or NEGATIVE-DEM TEMP. BINS!!!
# Not saving this iteration!!
#
#
# WARNING: ITERATION  53  HAS 0 or NEGATIVE-DEM TEMP. BINS!!!
# Not saving this iteration!!
#
#
# WARNING: ITERATION  44  HAS 0 or NEGATIVE-DEM TEMP. BINS!!!
# Not saving this iteration!!
#
#
# WARNING: ITERATION  30  HAS 0 or NEGATIVE-DEM TEMP. BINS!!!
# Not saving this iteration!!
#
#
# WARNING: ITERATION  29  HAS 0 or NEGATIVE-DEM TEMP. BINS!!!
# Not saving this iteration!!
#
#
# WARNING: ITERATION  17  HAS 0 or NEGATIVE-DEM TEMP. BINS!!!
# Not saving this iteration!!
#
# Start Time:  2018-05-29 22:50:50
# Stop Time:  2018-05-29 22:51:55
# You provided both a region box and a specific region.
# Bounding box will be used only for initial data prep (will save submap instead of full disk);
# specific region will be used for DEM
#
# Adding 10% error in quadrature with aiapy.estimate_error output.
#
# ARF File:  ['./initial_dem/22-50-50_22-51-55/nu80410205001A06_0_p_sr.arf']
# RMF File:  ['./initial_dem/22-50-50_22-51-55/nu80410205001A06_0_p_sr.rmf']
# PHA File:  ['./initial_dem/22-50-50_22-51-55/nu80410205001A06_0_p_sr.pha']
# Using grades 0-4 NuSTAR events.
# ARF File:  ['./initial_dem/22-50-50_22-51-55/nu80410205001A06_0_4_p_sr.arf']
# RMF File:  ['./initial_dem/22-50-50_22-51-55/nu80410205001A06_0_4_p_sr.rmf']
# PHA File:  ['./initial_dem/22-50-50_22-51-55/nu80410205001A06_0_4_p_sr.pha']
# ARF File:  ['./initial_dem/22-50-50_22-51-55/nu80410205001A06_21_24_p_sr.arf']
# RMF File:  ['./initial_dem/22-50-50_22-51-55/nu80410205001A06_21_24_p_sr.rmf']
# PHA File:  ['./initial_dem/22-50-50_22-51-55/nu80410205001A06_21_24_p_sr.pha']
#
# Max NuSTAR Energy:  7.559999942779541
# ARF File:  ['./initial_dem/22-50-50_22-51-55/nu80410205001B06_0_p_sr.arf']
# RMF File:  ['./initial_dem/22-50-50_22-51-55/nu80410205001B06_0_p_sr.rmf']
# PHA File:  ['./initial_dem/22-50-50_22-51-55/nu80410205001B06_0_p_sr.pha']
# Using grades 0-4 NuSTAR events.
# ARF File:  ['./initial_dem/22-50-50_22-51-55/nu80410205001B06_0_4_p_sr.arf']
# RMF File:  ['./initial_dem/22-50-50_22-51-55/nu80410205001B06_0_4_p_sr.rmf']
# PHA File:  ['./initial_dem/22-50-50_22-51-55/nu80410205001B06_0_4_p_sr.pha']
# ARF File:  ['./initial_dem/22-50-50_22-51-55/nu80410205001B06_21_24_p_sr.arf']
# RMF File:  ['./initial_dem/22-50-50_22-51-55/nu80410205001B06_21_24_p_sr.rmf']
# PHA File:  ['./initial_dem/22-50-50_22-51-55/nu80410205001B06_21_24_p_sr.pha']
#
# Max NuSTAR Energy:  7.039999961853027
#
# A94 :     2.91   1.49  51 %
# A131 :     24.27   4.29  18 %
# A171 :     652.09   67.97  10 %
# A193 :     744.38   76.82  10 %
# A211 :     273.43   28.83  11 %
# A335 :     19.72   2.84  14 %
# 2.5-3.5keV A+B :     6188.80   1240.47  20 %
# 3.5-6.0keV A+B :     702.14   143.11  20 %
# 6.0-10.0keV A+B :     9.12   3.63  40 %
#
# Doing 100 iterations of DEMReg with input varied within uncertainty!
#
# WARNING: ITERATION  42  HAS 0 or NEGATIVE-DEM TEMP. BINS!!!
# Not saving this iteration!!
#
# Start Time:  2018-05-29 22:51:55
# Stop Time:  2018-05-29 22:53:10
# You provided both a region box and a specific region.
# Bounding box will be used only for initial data prep (will save submap instead of full disk);
# specific region will be used for DEM
#
# Adding 10% error in quadrature with aiapy.estimate_error output.
#
# ARF File:  ['./initial_dem/22-51-55_22-53-10/nu80410205001A06_0_p_sr.arf']
# RMF File:  ['./initial_dem/22-51-55_22-53-10/nu80410205001A06_0_p_sr.rmf']
# PHA File:  ['./initial_dem/22-51-55_22-53-10/nu80410205001A06_0_p_sr.pha']
# Using grades 0-4 NuSTAR events.
# ARF File:  ['./initial_dem/22-51-55_22-53-10/nu80410205001A06_0_4_p_sr.arf']
# RMF File:  ['./initial_dem/22-51-55_22-53-10/nu80410205001A06_0_4_p_sr.rmf']
# PHA File:  ['./initial_dem/22-51-55_22-53-10/nu80410205001A06_0_4_p_sr.pha']
# ARF File:  ['./initial_dem/22-51-55_22-53-10/nu80410205001A06_21_24_p_sr.arf']
# RMF File:  ['./initial_dem/22-51-55_22-53-10/nu80410205001A06_21_24_p_sr.rmf']
# PHA File:  ['./initial_dem/22-51-55_22-53-10/nu80410205001A06_21_24_p_sr.pha']
#
# Max NuSTAR Energy:  9.5600004196167
# ARF File:  ['./initial_dem/22-51-55_22-53-10/nu80410205001B06_0_p_sr.arf']
# RMF File:  ['./initial_dem/22-51-55_22-53-10/nu80410205001B06_0_p_sr.rmf']
# PHA File:  ['./initial_dem/22-51-55_22-53-10/nu80410205001B06_0_p_sr.pha']
# Using grades 0-4 NuSTAR events.
# ARF File:  ['./initial_dem/22-51-55_22-53-10/nu80410205001B06_0_4_p_sr.arf']
# RMF File:  ['./initial_dem/22-51-55_22-53-10/nu80410205001B06_0_4_p_sr.rmf']
# PHA File:  ['./initial_dem/22-51-55_22-53-10/nu80410205001B06_0_4_p_sr.pha']
# ARF File:  ['./initial_dem/22-51-55_22-53-10/nu80410205001B06_21_24_p_sr.arf']
# RMF File:  ['./initial_dem/22-51-55_22-53-10/nu80410205001B06_21_24_p_sr.rmf']
# PHA File:  ['./initial_dem/22-51-55_22-53-10/nu80410205001B06_21_24_p_sr.pha']
# Max NuSTAR Energy:  6.759999752044678
#
# A94 :     2.91   1.49  51 %
# A131 :     24.25   4.29  18 %
# A171 :     651.42   67.90  10 %
# A193 :     743.69   76.75  10 %
# A211 :     273.27   28.82  11 %
# A335 :     19.69   2.84  14 %
# 2.5-3.5keV A+B :     6191.08   1240.52  20 %
# 3.5-6.0keV A+B :     685.42   139.37  20 %
# 6.0-10.0keV A+B :     8.36   3.22  39 %
#
# Doing 100 iterations of DEMReg with input varied within uncertainty!
#
# WARNING: ITERATION  75  HAS 0 or NEGATIVE-DEM TEMP. BINS!!!
# Not saving this iteration!!
#
#
# WARNING: ITERATION  65  HAS 0 or NEGATIVE-DEM TEMP. BINS!!!
# Not saving this iteration!!
#
#
# WARNING: ITERATION  42  HAS 0 or NEGATIVE-DEM TEMP. BINS!!!
# Not saving this iteration!!
#
#
# WARNING: ITERATION  17  HAS 0 or NEGATIVE-DEM TEMP. BINS!!!
# Not saving this iteration!!
#
# Start Time:  2018-05-29 22:53:10
# Stop Time:  2018-05-29 22:53:55
# You provided both a region box and a specific region.
# Bounding box will be used only for initial data prep (will save submap instead of full disk);
# specific region will be used for DEM
#
# Adding 10% error in quadrature with aiapy.estimate_error output.
#
# ARF File:  ['./initial_dem/22-53-10_22-53-55/nu80410205001A06_0_p_sr.arf']
# RMF File:  ['./initial_dem/22-53-10_22-53-55/nu80410205001A06_0_p_sr.rmf']
# PHA File:  ['./initial_dem/22-53-10_22-53-55/nu80410205001A06_0_p_sr.pha']
# Using grades 0-4 NuSTAR events.
# ARF File:  ['./initial_dem/22-53-10_22-53-55/nu80410205001A06_0_4_p_sr.arf']
# RMF File:  ['./initial_dem/22-53-10_22-53-55/nu80410205001A06_0_4_p_sr.rmf']
# PHA File:  ['./initial_dem/22-53-10_22-53-55/nu80410205001A06_0_4_p_sr.pha']
# ARF File:  ['./initial_dem/22-53-10_22-53-55/nu80410205001A06_21_24_p_sr.arf']
# RMF File:  ['./initial_dem/22-53-10_22-53-55/nu80410205001A06_21_24_p_sr.rmf']
# PHA File:  ['./initial_dem/22-53-10_22-53-55/nu80410205001A06_21_24_p_sr.pha']
#
# Max NuSTAR Energy:  6.9599995613098145
# ARF File:  ['./initial_dem/22-53-10_22-53-55/nu80410205001B06_0_p_sr.arf']
# RMF File:  ['./initial_dem/22-53-10_22-53-55/nu80410205001B06_0_p_sr.rmf']
# PHA File:  ['./initial_dem/22-53-10_22-53-55/nu80410205001B06_0_p_sr.pha']
# Using grades 0-4 NuSTAR events.
# ARF File:  ['./initial_dem/22-53-10_22-53-55/nu80410205001B06_0_4_p_sr.arf']
# RMF File:  ['./initial_dem/22-53-10_22-53-55/nu80410205001B06_0_4_p_sr.rmf']
# PHA File:  ['./initial_dem/22-53-10_22-53-55/nu80410205001B06_0_4_p_sr.pha']
# ARF File:  ['./initial_dem/22-53-10_22-53-55/nu80410205001B06_21_24_p_sr.arf']
# RMF File:  ['./initial_dem/22-53-10_22-53-55/nu80410205001B06_21_24_p_sr.rmf']
# PHA File:  ['./initial_dem/22-53-10_22-53-55/nu80410205001B06_21_24_p_sr.pha']
#
# Max NuSTAR Energy:  7.399999618530273
#
# A94 :     2.91   1.49  51 %
# A131 :     24.25   4.29  18 %
# A171 :     651.06   67.87  10 %
# A193 :     743.15   76.70  10 %
# A211 :     273.16   28.81  11 %
# A335 :     19.66   2.83  14 %
# 2.5-3.5keV A+B :     6367.39   1277.39  20 %
# 3.5-6.0keV A+B :     769.84   157.84  21 %
# 6.0-10.0keV A+B :     16.37   6.03  37 %
#
# Doing 100 iterations of DEMReg with input varied within uncertainty!
#
# WARNING: ITERATION  98  HAS 0 or NEGATIVE-DEM TEMP. BINS!!!
# Not saving this iteration!!
#
#
# WARNING: ITERATION  95  HAS 0 or NEGATIVE-DEM TEMP. BINS!!!
# Not saving this iteration!!
#
# Start Time:  2018-05-29 22:53:55
# Stop Time:  2018-05-29 22:58:00
# You provided both a region box and a specific region.
# Bounding box will be used only for initial data prep (will save submap instead of full disk);
# specific region will be used for DEM
#
# Adding 10% error in quadrature with aiapy.estimate_error output.
#
# ARF File:  ['./initial_dem/22-53-55_22-58-00/nu80410205001A06_0_p_sr.arf']
# RMF File:  ['./initial_dem/22-53-55_22-58-00/nu80410205001A06_0_p_sr.rmf']
# PHA File:  ['./initial_dem/22-53-55_22-58-00/nu80410205001A06_0_p_sr.pha']
# Using grades 0-4 NuSTAR events.
# ARF File:  ['./initial_dem/22-53-55_22-58-00/nu80410205001A06_0_4_p_sr.arf']
# RMF File:  ['./initial_dem/22-53-55_22-58-00/nu80410205001A06_0_4_p_sr.rmf']
# PHA File:  ['./initial_dem/22-53-55_22-58-00/nu80410205001A06_0_4_p_sr.pha']
# ARF File:  ['./initial_dem/22-53-55_22-58-00/nu80410205001A06_21_24_p_sr.arf']
# RMF File:  ['./initial_dem/22-53-55_22-58-00/nu80410205001A06_21_24_p_sr.rmf']
# PHA File:  ['./initial_dem/22-53-55_22-58-00/nu80410205001A06_21_24_p_sr.pha']
#
# Max NuSTAR Energy:  7.479999542236328
#
# ['2.5-3.5keV', '3.5-6.0keV']
# Removed rate in  [6.0, 10.0] A  for being negative after pile-up correction.
# ARF File:  ['./initial_dem/22-53-55_22-58-00/nu80410205001B06_0_p_sr.arf']
# RMF File:  ['./initial_dem/22-53-55_22-58-00/nu80410205001B06_0_p_sr.rmf']
# PHA File:  ['./initial_dem/22-53-55_22-58-00/nu80410205001B06_0_p_sr.pha']
# Using grades 0-4 NuSTAR events.
# ARF File:  ['./initial_dem/22-53-55_22-58-00/nu80410205001B06_0_4_p_sr.arf']
# RMF File:  ['./initial_dem/22-53-55_22-58-00/nu80410205001B06_0_4_p_sr.rmf']
# PHA File:  ['./initial_dem/22-53-55_22-58-00/nu80410205001B06_0_4_p_sr.pha']
# ARF File:  ['./initial_dem/22-53-55_22-58-00/nu80410205001B06_21_24_p_sr.arf']
# RMF File:  ['./initial_dem/22-53-55_22-58-00/nu80410205001B06_21_24_p_sr.rmf']
# PHA File:  ['./initial_dem/22-53-55_22-58-00/nu80410205001B06_21_24_p_sr.pha']
#
# Max NuSTAR Energy:  11.360000610351562
# Warning: there is at least one NuSTAR event of higher energy than your highest energy range
# Highest energy range: [6.0, 10.0]
# Total Above:  1
# Above Energies:  [11.36000061]
#
# A94 :     2.90   1.49  51 %
# A131 :     24.17   4.28  18 %
# A171 :     649.50   67.71  10 %
# A193 :     742.70   76.65  10 %
# A211 :     273.64   28.85  11 %
# A335 :     19.67   2.83  14 %
# 2.5-3.5keV A+B :     5886.68   1178.02  20 %
# 3.5-6.0keV A+B :     608.08   122.30  20 %
#  + 6.0-10.0keV B :     1.44   0.51  35 %
#
# Doing 100 iterations of DEMReg with input varied within uncertainty!
#
# WARNING: ITERATION  54  HAS 0 or NEGATIVE-DEM TEMP. BINS!!!
# Not saving this iteration!!
#
#
# WARNING: ITERATION  3  HAS 0 or NEGATIVE-DEM TEMP. BINS!!!
# Not saving this iteration!!
#
#
# WARNING: ITERATION  1  HAS 0 or NEGATIVE-DEM TEMP. BINS!!!
# Not saving this iteration!!
#
# Start Time:  2018-05-29 22:58:00
# Stop Time:  2018-05-29 23:00:00
# You provided both a region box and a specific region.
# Bounding box will be used only for initial data prep (will save submap instead of full disk);
# specific region will be used for DEM
#
# Adding 10% error in quadrature with aiapy.estimate_error output.
#
# ARF File:  ['./initial_dem/22-58-00_23-00-00/nu80410205001A06_0_p_sr.arf']
# RMF File:  ['./initial_dem/22-58-00_23-00-00/nu80410205001A06_0_p_sr.rmf']
# PHA File:  ['./initial_dem/22-58-00_23-00-00/nu80410205001A06_0_p_sr.pha']
# Using grades 0-4 NuSTAR events.
# ARF File:  ['./initial_dem/22-58-00_23-00-00/nu80410205001A06_0_4_p_sr.arf']
# RMF File:  ['./initial_dem/22-58-00_23-00-00/nu80410205001A06_0_4_p_sr.rmf']
# PHA File:  ['./initial_dem/22-58-00_23-00-00/nu80410205001A06_0_4_p_sr.pha']
# ARF File:  ['./initial_dem/22-58-00_23-00-00/nu80410205001A06_21_24_p_sr.arf']
# RMF File:  ['./initial_dem/22-58-00_23-00-00/nu80410205001A06_21_24_p_sr.rmf']
# PHA File:  ['./initial_dem/22-58-00_23-00-00/nu80410205001A06_21_24_p_sr.pha']
#
# Max NuSTAR Energy:  7.119999885559082
# ARF File:  ['./initial_dem/22-58-00_23-00-00/nu80410205001B06_0_p_sr.arf']
# RMF File:  ['./initial_dem/22-58-00_23-00-00/nu80410205001B06_0_p_sr.rmf']
# PHA File:  ['./initial_dem/22-58-00_23-00-00/nu80410205001B06_0_p_sr.pha']
# Using grades 0-4 NuSTAR events.
# ARF File:  ['./initial_dem/22-58-00_23-00-00/nu80410205001B06_0_4_p_sr.arf']
# RMF File:  ['./initial_dem/22-58-00_23-00-00/nu80410205001B06_0_4_p_sr.rmf']
# PHA File:  ['./initial_dem/22-58-00_23-00-00/nu80410205001B06_0_4_p_sr.pha']
# ARF File:  ['./initial_dem/22-58-00_23-00-00/nu80410205001B06_21_24_p_sr.arf']
# RMF File:  ['./initial_dem/22-58-00_23-00-00/nu80410205001B06_21_24_p_sr.rmf']
# PHA File:  ['./initial_dem/22-58-00_23-00-00/nu80410205001B06_21_24_p_sr.pha']
#
# Max NuSTAR Energy:  6.639999866485596
#
# A94 :     2.89   1.49  52 %
# A131 :     24.10   4.27  18 %
# A171 :     647.14   67.48  10 %
# A193 :     743.74   76.76  10 %
# A211 :     274.61   28.95  11 %
# A335 :     19.63   2.83  14 %
# 2.5-3.5keV A+B :     5619.95   1125.34  20 %
# 3.5-6.0keV A+B :     558.63   113.07  20 %
# 6.0-10.0keV A+B :     4.11   1.69  41 %
#
# Doing 100 iterations of DEMReg with input varied within uncertainty!
# WARNING: ITERATION  49  HAS 0 or NEGATIVE-DEM TEMP. BINS!!!
# Not saving this iteration!!
#
#
# WARNING: ITERATION  27  HAS 0 or NEGATIVE-DEM TEMP. BINS!!!
# Not saving this iteration!!
#
#
# WARNING: ITERATION  18  HAS 0 or NEGATIVE-DEM TEMP. BINS!!!
# Not saving this iteration!!
#
# Start Time:  2018-05-29 23:00:00
# Stop Time:  2018-05-29 23:02:15
# You provided both a region box and a specific region.
# Bounding box will be used only for initial data prep (will save submap instead of full disk);
# specific region will be used for DEM
#
# Adding 10% error in quadrature with aiapy.estimate_error output.
#
# ARF File:  ['./initial_dem/23-00-00_23-02-15/nu80410205001A06_0_p_sr.arf']
# RMF File:  ['./initial_dem/23-00-00_23-02-15/nu80410205001A06_0_p_sr.rmf']
# PHA File:  ['./initial_dem/23-00-00_23-02-15/nu80410205001A06_0_p_sr.pha']
# Using grades 0-4 NuSTAR events.
# ARF File:  ['./initial_dem/23-00-00_23-02-15/nu80410205001A06_0_4_p_sr.arf']
# RMF File:  ['./initial_dem/23-00-00_23-02-15/nu80410205001A06_0_4_p_sr.rmf']
# PHA File:  ['./initial_dem/23-00-00_23-02-15/nu80410205001A06_0_4_p_sr.pha']
# ARF File:  ['./initial_dem/23-00-00_23-02-15/nu80410205001A06_21_24_p_sr.arf']
# RMF File:  ['./initial_dem/23-00-00_23-02-15/nu80410205001A06_21_24_p_sr.rmf']
# PHA File:  ['./initial_dem/23-00-00_23-02-15/nu80410205001A06_21_24_p_sr.pha']
#
# Max NuSTAR Energy:  21.200000762939453
# Warning: there is at least one NuSTAR event of higher energy than your highest energy range
# Highest energy range: [6.0, 10.0]
# Total Above:  1
# Above Energies:  [21.20000076]
# ARF File:  ['./initial_dem/23-00-00_23-02-15/nu80410205001B06_0_p_sr.arf']
# RMF File:  ['./initial_dem/23-00-00_23-02-15/nu80410205001B06_0_p_sr.rmf']
# PHA File:  ['./initial_dem/23-00-00_23-02-15/nu80410205001B06_0_p_sr.pha']
# Using grades 0-4 NuSTAR events.
# ARF File:  ['./initial_dem/23-00-00_23-02-15/nu80410205001B06_0_4_p_sr.arf']
# RMF File:  ['./initial_dem/23-00-00_23-02-15/nu80410205001B06_0_4_p_sr.rmf']
# PHA File:  ['./initial_dem/23-00-00_23-02-15/nu80410205001B06_0_4_p_sr.pha']
# ARF File:  ['./initial_dem/23-00-00_23-02-15/nu80410205001B06_21_24_p_sr.arf']
# RMF File:  ['./initial_dem/23-00-00_23-02-15/nu80410205001B06_21_24_p_sr.rmf']
# PHA File:  ['./initial_dem/23-00-00_23-02-15/nu80410205001B06_21_24_p_sr.pha']
#
# Max NuSTAR Energy:  8.119999885559082
#
# A94 :     2.89   1.49  52 %
# A131 :     24.04   4.27  18 %
# A171 :     644.53   67.22  10 %
# A193 :     743.95   76.78  10 %
# A211 :     274.82   28.97  11 %
# A335 :     19.59   2.82  14 %
# 2.5-3.5keV A+B :     5589.43   1119.07  20 %
# 3.5-6.0keV A+B :     559.32   113.04  20 %
# 6.0-10.0keV A+B :     4.13   1.62  39 %
#
# Doing 100 iterations of DEMReg with input varied within uncertainty!
#
# WARNING: ITERATION  28  HAS 0 or NEGATIVE-DEM TEMP. BINS!!!
# Not saving this iteration!!
#
#
# WARNING: ITERATION  14  HAS 0 or NEGATIVE-DEM TEMP. BINS!!!
# Not saving this iteration!!
#
# Start Time:  2018-05-29 23:02:15
# Stop Time:  2018-05-29 23:04:40
# You provided both a region box and a specific region.
# Bounding box will be used only for initial data prep (will save submap instead of full disk);
# specific region will be used for DEM
#
# Adding 10% error in quadrature with aiapy.estimate_error output.
#
# ARF File:  ['./initial_dem/23-02-15_23-04-40/nu80410205001A06_0_p_sr.arf']
# RMF File:  ['./initial_dem/23-02-15_23-04-40/nu80410205001A06_0_p_sr.rmf']
# PHA File:  ['./initial_dem/23-02-15_23-04-40/nu80410205001A06_0_p_sr.pha']
# Using grades 0-4 NuSTAR events.
# ARF File:  ['./initial_dem/23-02-15_23-04-40/nu80410205001A06_0_4_p_sr.arf']
# RMF File:  ['./initial_dem/23-02-15_23-04-40/nu80410205001A06_0_4_p_sr.rmf']
# PHA File:  ['./initial_dem/23-02-15_23-04-40/nu80410205001A06_0_4_p_sr.pha']
# ARF File:  ['./initial_dem/23-02-15_23-04-40/nu80410205001A06_21_24_p_sr.arf']
# RMF File:  ['./initial_dem/23-02-15_23-04-40/nu80410205001A06_21_24_p_sr.rmf']
# PHA File:  ['./initial_dem/23-02-15_23-04-40/nu80410205001A06_21_24_p_sr.pha']
#
# Max NuSTAR Energy:  7.039999961853027
# ARF File:  ['./initial_dem/23-02-15_23-04-40/nu80410205001B06_0_p_sr.arf']
# RMF File:  ['./initial_dem/23-02-15_23-04-40/nu80410205001B06_0_p_sr.rmf']
# PHA File:  ['./initial_dem/23-02-15_23-04-40/nu80410205001B06_0_p_sr.pha']
# Using grades 0-4 NuSTAR events.
# ARF File:  ['./initial_dem/23-02-15_23-04-40/nu80410205001B06_0_4_p_sr.arf']
# RMF File:  ['./initial_dem/23-02-15_23-04-40/nu80410205001B06_0_4_p_sr.rmf']
# PHA File:  ['./initial_dem/23-02-15_23-04-40/nu80410205001B06_0_4_p_sr.pha']
# ARF File:  ['./initial_dem/23-02-15_23-04-40/nu80410205001B06_21_24_p_sr.arf']
# RMF File:  ['./initial_dem/23-02-15_23-04-40/nu80410205001B06_21_24_p_sr.rmf']
# PHA File:  ['./initial_dem/23-02-15_23-04-40/nu80410205001B06_21_24_p_sr.pha']
#
# Max NuSTAR Energy:  7.159999847412109
#
# A94 :     2.88   1.49  52 %
# A131 :     23.98   4.26  18 %
# A171 :     642.32   66.99  10 %
# A193 :     743.70   76.75  10 %
# A211 :     274.51   28.94  11 %
# A335 :     19.53   2.82  14 %
# 2.5-3.5keV A+B :     5482.85   1097.66  20 %
# 3.5-6.0keV A+B :     558.43   112.77  20 %
# 6.0-10.0keV A+B :     2.56   1.17  46 %
#
# Doing 100 iterations of DEMReg with input varied within uncertainty!
#
# WARNING: ITERATION  87  HAS 0 or NEGATIVE-DEM TEMP. BINS!!!
# Not saving this iteration!!
#
#
# WARNING: ITERATION  27  HAS 0 or NEGATIVE-DEM TEMP. BINS!!!
# Not saving this iteration!!
#
# Start Time:  2018-05-29 23:04:40
# Stop Time:  2018-05-29 23:07:40
# You provided both a region box and a specific region.
# Bounding box will be used only for initial data prep (will save submap instead of full disk);
# specific region will be used for DEM
#
# Adding 10% error in quadrature with aiapy.estimate_error output.
#
# ARF File:  ['./initial_dem/23-04-40_23-07-40/nu80410205001A06_0_p_sr.arf']
# RMF File:  ['./initial_dem/23-04-40_23-07-40/nu80410205001A06_0_p_sr.rmf']
# PHA File:  ['./initial_dem/23-04-40_23-07-40/nu80410205001A06_0_p_sr.pha']
# Using grades 0-4 NuSTAR events.
# ARF File:  ['./initial_dem/23-04-40_23-07-40/nu80410205001A06_0_4_p_sr.arf']
# RMF File:  ['./initial_dem/23-04-40_23-07-40/nu80410205001A06_0_4_p_sr.rmf']
# PHA File:  ['./initial_dem/23-04-40_23-07-40/nu80410205001A06_0_4_p_sr.pha']
# ARF File:  ['./initial_dem/23-04-40_23-07-40/nu80410205001A06_21_24_p_sr.arf']
# RMF File:  ['./initial_dem/23-04-40_23-07-40/nu80410205001A06_21_24_p_sr.rmf']
# PHA File:  ['./initial_dem/23-04-40_23-07-40/nu80410205001A06_21_24_p_sr.pha']
#
# Max NuSTAR Energy:  22.959999084472656
# Warning: there is at least one NuSTAR event of higher energy than your highest energy range
# Highest energy range: [6.0, 10.0]
# Total Above:  2
# Above Energies:  [11.40000057 22.95999908]
#
# ['2.5-3.5keV', '3.5-6.0keV']
# Removed rate in  [6.0, 10.0] A  for being negative after pile-up correction.
# ARF File:  ['./initial_dem/23-04-40_23-07-40/nu80410205001B06_0_p_sr.arf']
# RMF File:  ['./initial_dem/23-04-40_23-07-40/nu80410205001B06_0_p_sr.rmf']
# PHA File:  ['./initial_dem/23-04-40_23-07-40/nu80410205001B06_0_p_sr.pha']
# Using grades 0-4 NuSTAR events.
# ARF File:  ['./initial_dem/23-04-40_23-07-40/nu80410205001B06_0_4_p_sr.arf']
# RMF File:  ['./initial_dem/23-04-40_23-07-40/nu80410205001B06_0_4_p_sr.rmf']
# PHA File:  ['./initial_dem/23-04-40_23-07-40/nu80410205001B06_0_4_p_sr.pha']
# ARF File:  ['./initial_dem/23-04-40_23-07-40/nu80410205001B06_21_24_p_sr.arf']
# RMF File:  ['./initial_dem/23-04-40_23-07-40/nu80410205001B06_21_24_p_sr.rmf']
# PHA File:  ['./initial_dem/23-04-40_23-07-40/nu80410205001B06_21_24_p_sr.pha']
#
# Max NuSTAR Energy:  7.439999580383301
#
# A94 :     2.87   1.49  52 %
# A131 :     23.94   4.25  18 %
# A171 :     639.65   66.73  10 %
# A193 :     742.42   76.63  10 %
# A211 :     274.04   28.89  11 %
# A335 :     19.49   2.81  14 %
# 2.5-3.5keV A+B :     5635.94   1128.09  20 %
# 3.5-6.0keV A+B :     571.23   115.14  20 %
#  + 6.0-10.0keV B :     2.51   0.80  32 %
#
# Doing 100 iterations of DEMReg with input varied within uncertainty!
#
# WARNING: ITERATION  71  HAS 0 or NEGATIVE-DEM TEMP. BINS!!!
# Not saving this iteration!!
#
#
# WARNING: ITERATION  24  HAS 0 or NEGATIVE-DEM TEMP. BINS!!!
# Not saving this iteration!!
#
#
# WARNING: ITERATION  15  HAS 0 or NEGATIVE-DEM TEMP. BINS!!!
# Not saving this iteration!!
#
# Start Time:  2018-05-29 23:07:40
# Stop Time:  2018-05-29 23:08:10
# You provided both a region box and a specific region.
# Bounding box will be used only for initial data prep (will save submap instead of full disk);
# specific region will be used for DEM
# Adding 10% error in quadrature with aiapy.estimate_error output.
#
# ARF File:  ['./initial_dem/23-07-40_23-08-10/nu80410205001A06_0_p_sr.arf']
# RMF File:  ['./initial_dem/23-07-40_23-08-10/nu80410205001A06_0_p_sr.rmf']
# PHA File:  ['./initial_dem/23-07-40_23-08-10/nu80410205001A06_0_p_sr.pha']
# Using grades 0-4 NuSTAR events.
# ARF File:  ['./initial_dem/23-07-40_23-08-10/nu80410205001A06_0_4_p_sr.arf']
# RMF File:  ['./initial_dem/23-07-40_23-08-10/nu80410205001A06_0_4_p_sr.rmf']
# PHA File:  ['./initial_dem/23-07-40_23-08-10/nu80410205001A06_0_4_p_sr.pha']
# ARF File:  ['./initial_dem/23-07-40_23-08-10/nu80410205001A06_21_24_p_sr.arf']
# RMF File:  ['./initial_dem/23-07-40_23-08-10/nu80410205001A06_21_24_p_sr.rmf']
# PHA File:  ['./initial_dem/23-07-40_23-08-10/nu80410205001A06_21_24_p_sr.pha']
#
# Max NuSTAR Energy:  6.799999713897705
# ARF File:  ['./initial_dem/23-07-40_23-08-10/nu80410205001B06_0_p_sr.arf']
# RMF File:  ['./initial_dem/23-07-40_23-08-10/nu80410205001B06_0_p_sr.rmf']
# PHA File:  ['./initial_dem/23-07-40_23-08-10/nu80410205001B06_0_p_sr.pha']
# Using grades 0-4 NuSTAR events.
# ARF File:  ['./initial_dem/23-07-40_23-08-10/nu80410205001B06_0_4_p_sr.arf']
# RMF File:  ['./initial_dem/23-07-40_23-08-10/nu80410205001B06_0_4_p_sr.rmf']
# PHA File:  ['./initial_dem/23-07-40_23-08-10/nu80410205001B06_0_4_p_sr.pha']
# ARF File:  ['./initial_dem/23-07-40_23-08-10/nu80410205001B06_21_24_p_sr.arf']
# RMF File:  ['./initial_dem/23-07-40_23-08-10/nu80410205001B06_21_24_p_sr.rmf']
# PHA File:  ['./initial_dem/23-07-40_23-08-10/nu80410205001B06_21_24_p_sr.pha']
#
# Max NuSTAR Energy:  6.679999828338623
#
# A94 :     2.87   1.48  52 %
# A131 :     23.91   4.25  18 %
# A171 :     637.43   66.50  10 %
# A193 :     740.95   76.48  10 %
# A211 :     273.41   28.83  11 %
# A335 :     19.45   2.81  14 %
# 2.5-3.5keV A+B :     5982.73   1202.23  20 %
# 3.5-6.0keV A+B :     784.75   162.55  21 %
# 6.0-10.0keV A+B :     19.61   7.73  39 %
#
# Doing 100 iterations of DEMReg with input varied within uncertainty!
#
# WARNING: ITERATION  82  HAS 0 or NEGATIVE-DEM TEMP. BINS!!!
# Not saving this iteration!!
#
# Start Time:  2018-05-29 23:08:10
# Stop Time:  2018-05-29 23:09:05
# You provided both a region box and a specific region.
# Bounding box will be used only for initial data prep (will save submap instead of full disk);
# specific region will be used for DEM
#
# Adding 10% error in quadrature with aiapy.estimate_error output.
#
# ARF File:  ['./initial_dem/23-08-10_23-09-05/nu80410205001A06_0_p_sr.arf']
# RMF File:  ['./initial_dem/23-08-10_23-09-05/nu80410205001A06_0_p_sr.rmf']
# PHA File:  ['./initial_dem/23-08-10_23-09-05/nu80410205001A06_0_p_sr.pha']
# Using grades 0-4 NuSTAR events.
# ARF File:  ['./initial_dem/23-08-10_23-09-05/nu80410205001A06_0_4_p_sr.arf']
# RMF File:  ['./initial_dem/23-08-10_23-09-05/nu80410205001A06_0_4_p_sr.rmf']
# PHA File:  ['./initial_dem/23-08-10_23-09-05/nu80410205001A06_0_4_p_sr.pha']
# ARF File:  ['./initial_dem/23-08-10_23-09-05/nu80410205001A06_21_24_p_sr.arf']
# RMF File:  ['./initial_dem/23-08-10_23-09-05/nu80410205001A06_21_24_p_sr.rmf']
# PHA File:  ['./initial_dem/23-08-10_23-09-05/nu80410205001A06_21_24_p_sr.pha']
#
# Max NuSTAR Energy:  7.279999732971191
# ARF File:  ['./initial_dem/23-08-10_23-09-05/nu80410205001B06_0_p_sr.arf']
# RMF File:  ['./initial_dem/23-08-10_23-09-05/nu80410205001B06_0_p_sr.rmf']
# PHA File:  ['./initial_dem/23-08-10_23-09-05/nu80410205001B06_0_p_sr.pha']
# Using grades 0-4 NuSTAR events.
# ARF File:  ['./initial_dem/23-08-10_23-09-05/nu80410205001B06_0_4_p_sr.arf']
# RMF File:  ['./initial_dem/23-08-10_23-09-05/nu80410205001B06_0_4_p_sr.rmf']
# PHA File:  ['./initial_dem/23-08-10_23-09-05/nu80410205001B06_0_4_p_sr.pha']
# ARF File:  ['./initial_dem/23-08-10_23-09-05/nu80410205001B06_21_24_p_sr.arf']
# RMF File:  ['./initial_dem/23-08-10_23-09-05/nu80410205001B06_21_24_p_sr.rmf']
# PHA File:  ['./initial_dem/23-08-10_23-09-05/nu80410205001B06_21_24_p_sr.pha']
#
# Max NuSTAR Energy:  9.359999656677246
#
# A94 :     2.87   1.48  52 %
# A131 :     23.87   4.25  18 %
# A171 :     636.17   66.38  10 %
# A193 :     739.33   76.32  10 %
# A211 :     273.24   28.81  11 %
# A335 :     19.39   2.80  14 %
# 2.5-3.5keV A+B :     6298.91   1262.98  20 %
# 3.5-6.0keV A+B :     892.84   181.74  20 %
# 6.0-10.0keV A+B :     6.29   2.94  47 %
#
# Doing 100 iterations of DEMReg with input varied within uncertainty!
#
# WARNING: ITERATION  98  HAS 0 or NEGATIVE-DEM TEMP. BINS!!!
# Not saving this iteration!!
#
#
# WARNING: ITERATION  90  HAS 0 or NEGATIVE-DEM TEMP. BINS!!!
# Not saving this iteration!!
#
#
# WARNING: ITERATION  82  HAS 0 or NEGATIVE-DEM TEMP. BINS!!!
# Not saving this iteration!!
#
#
# WARNING: ITERATION  63  HAS 0 or NEGATIVE-DEM TEMP. BINS!!!
# Not saving this iteration!!
#
#
# WARNING: ITERATION  7  HAS 0 or NEGATIVE-DEM TEMP. BINS!!!
# Not saving this iteration!!
#
# Start Time:  2018-05-29 23:09:05
# Stop Time:  2018-05-29 23:09:50
# You provided both a region box and a specific region.
# Bounding box will be used only for initial data prep (will save submap instead of full disk);
# specific region will be used for DEM
#
# Adding 10% error in quadrature with aiapy.estimate_error output.
#
# ARF File:  ['./initial_dem/23-09-05_23-09-50/nu80410205001A06_0_p_sr.arf']
# RMF File:  ['./initial_dem/23-09-05_23-09-50/nu80410205001A06_0_p_sr.rmf']
# PHA File:  ['./initial_dem/23-09-05_23-09-50/nu80410205001A06_0_p_sr.pha']
# Using grades 0-4 NuSTAR events.
# ARF File:  ['./initial_dem/23-09-05_23-09-50/nu80410205001A06_0_4_p_sr.arf']
# RMF File:  ['./initial_dem/23-09-05_23-09-50/nu80410205001A06_0_4_p_sr.rmf']
# PHA File:  ['./initial_dem/23-09-05_23-09-50/nu80410205001A06_0_4_p_sr.pha']
# ARF File:  ['./initial_dem/23-09-05_23-09-50/nu80410205001A06_21_24_p_sr.arf']
# RMF File:  ['./initial_dem/23-09-05_23-09-50/nu80410205001A06_21_24_p_sr.rmf']
# PHA File:  ['./initial_dem/23-09-05_23-09-50/nu80410205001A06_21_24_p_sr.pha']
#
# Max NuSTAR Energy:  24.31999969482422
# Warning: there is at least one NuSTAR event of higher energy than your highest energy range
# Highest energy range: [6.0, 10.0]
# Total Above:  1
# Above Energies:  [24.31999969]
# ARF File:  ['./initial_dem/23-09-05_23-09-50/nu80410205001B06_0_p_sr.arf']
# RMF File:  ['./initial_dem/23-09-05_23-09-50/nu80410205001B06_0_p_sr.rmf']
# PHA File:  ['./initial_dem/23-09-05_23-09-50/nu80410205001B06_0_p_sr.pha']
# Using grades 0-4 NuSTAR events.
# ARF File:  ['./initial_dem/23-09-05_23-09-50/nu80410205001B06_0_4_p_sr.arf']
# RMF File:  ['./initial_dem/23-09-05_23-09-50/nu80410205001B06_0_4_p_sr.rmf']
# PHA File:  ['./initial_dem/23-09-05_23-09-50/nu80410205001B06_0_4_p_sr.pha']
# ARF File:  ['./initial_dem/23-09-05_23-09-50/nu80410205001B06_21_24_p_sr.arf']
# RMF File:  ['./initial_dem/23-09-05_23-09-50/nu80410205001B06_21_24_p_sr.rmf']
# PHA File:  ['./initial_dem/23-09-05_23-09-50/nu80410205001B06_21_24_p_sr.pha']
#
# Max NuSTAR Energy:  16.439998626708984
# Warning: there is at least one NuSTAR event of higher energy than your highest energy range
# Highest energy range: [6.0, 10.0]
# Total Above:  1
# Above Energies:  [16.43999863]
#
# A94 :     2.87   1.49  52 %
# A131 :     23.82   4.24  18 %
# A171 :     634.29   66.19  10 %
# A193 :     739.10   76.29  10 %
# A211 :     272.77   28.77  11 %
# A335 :     19.40   2.80  14 %
# 2.5-3.5keV A+B :     6610.09   1326.05  20 %
# 3.5-6.0keV A+B :     878.24   179.65  20 %
# 6.0-10.0keV A+B :     14.31   5.59  39 %
#
# Doing 100 iterations of DEMReg with input varied within uncertainty!
#
# WARNING: ITERATION  15  HAS 0 or NEGATIVE-DEM TEMP. BINS!!!
# Not saving this iteration!!
#
# Start Time:  2018-05-29 23:09:50
# Stop Time:  2018-05-29 23:10:25
# You provided both a region box and a specific region.
# Bounding box will be used only for initial data prep (will save submap instead of full disk);
# specific region will be used for DEM
#
# Adding 10% error in quadrature with aiapy.estimate_error output.
#
# ARF File:  ['./initial_dem/23-09-50_23-10-25/nu80410205001A06_0_p_sr.arf']
# RMF File:  ['./initial_dem/23-09-50_23-10-25/nu80410205001A06_0_p_sr.rmf']
# PHA File:  ['./initial_dem/23-09-50_23-10-25/nu80410205001A06_0_p_sr.pha']
# Using grades 0-4 NuSTAR events.
# ARF File:  ['./initial_dem/23-09-50_23-10-25/nu80410205001A06_0_4_p_sr.arf']
# RMF File:  ['./initial_dem/23-09-50_23-10-25/nu80410205001A06_0_4_p_sr.rmf']
# PHA File:  ['./initial_dem/23-09-50_23-10-25/nu80410205001A06_0_4_p_sr.pha']
# ARF File:  ['./initial_dem/23-09-50_23-10-25/nu80410205001A06_21_24_p_sr.arf']
# RMF File:  ['./initial_dem/23-09-50_23-10-25/nu80410205001A06_21_24_p_sr.rmf']
# PHA File:  ['./initial_dem/23-09-50_23-10-25/nu80410205001A06_21_24_p_sr.pha']
# Max NuSTAR Energy:  7.439999580383301
# ARF File:  ['./initial_dem/23-09-50_23-10-25/nu80410205001B06_0_p_sr.arf']
# RMF File:  ['./initial_dem/23-09-50_23-10-25/nu80410205001B06_0_p_sr.rmf']
# PHA File:  ['./initial_dem/23-09-50_23-10-25/nu80410205001B06_0_p_sr.pha']
# Using grades 0-4 NuSTAR events.
# ARF File:  ['./initial_dem/23-09-50_23-10-25/nu80410205001B06_0_4_p_sr.arf']
# RMF File:  ['./initial_dem/23-09-50_23-10-25/nu80410205001B06_0_4_p_sr.rmf']
# PHA File:  ['./initial_dem/23-09-50_23-10-25/nu80410205001B06_0_4_p_sr.pha']
# ARF File:  ['./initial_dem/23-09-50_23-10-25/nu80410205001B06_21_24_p_sr.arf']
# RMF File:  ['./initial_dem/23-09-50_23-10-25/nu80410205001B06_21_24_p_sr.rmf']
# PHA File:  ['./initial_dem/23-09-50_23-10-25/nu80410205001B06_21_24_p_sr.pha']
#
# Max NuSTAR Energy:  7.119999885559082
#
# A94 :     2.87   1.48  52 %
# A131 :     23.81   4.24  18 %
# A171 :     633.60   66.12  10 %
# A193 :     738.49   76.23  10 %
# A211 :     272.58   28.75  11 %
# A335 :     19.39   2.80  14 %
# 2.5-3.5keV A+B :     6816.93   1368.67  20 %
# 3.5-6.0keV A+B :     966.70   198.57  21 %
# 6.0-10.0keV A+B :     14.37   6.17  43 %
#
# Doing 100 iterations of DEMReg with input varied within uncertainty!
#
# WARNING: ITERATION  36  HAS 0 or NEGATIVE-DEM TEMP. BINS!!!
# Not saving this iteration!!
#
#
# WARNING: ITERATION  1  HAS 0 or NEGATIVE-DEM TEMP. BINS!!!
# Not saving this iteration!!
#
# Start Time:  2018-05-29 23:10:25
# Stop Time:  2018-05-29 23:11:40
# You provided both a region box and a specific region.
# Bounding box will be used only for initial data prep (will save submap instead of full disk);
# specific region will be used for DEM
#
# Adding 10% error in quadrature with aiapy.estimate_error output.
#
# ARF File:  ['./initial_dem/23-10-25_23-11-40/nu80410205001A06_0_p_sr.arf']
# RMF File:  ['./initial_dem/23-10-25_23-11-40/nu80410205001A06_0_p_sr.rmf']
# PHA File:  ['./initial_dem/23-10-25_23-11-40/nu80410205001A06_0_p_sr.pha']
# Using grades 0-4 NuSTAR events.
# ARF File:  ['./initial_dem/23-10-25_23-11-40/nu80410205001A06_0_4_p_sr.arf']
# RMF File:  ['./initial_dem/23-10-25_23-11-40/nu80410205001A06_0_4_p_sr.rmf']
# PHA File:  ['./initial_dem/23-10-25_23-11-40/nu80410205001A06_0_4_p_sr.pha']
# ARF File:  ['./initial_dem/23-10-25_23-11-40/nu80410205001A06_21_24_p_sr.arf']
# RMF File:  ['./initial_dem/23-10-25_23-11-40/nu80410205001A06_21_24_p_sr.rmf']
# PHA File:  ['./initial_dem/23-10-25_23-11-40/nu80410205001A06_21_24_p_sr.pha']
#
# Max NuSTAR Energy:  7.919999599456787
# ARF File:  ['./initial_dem/23-10-25_23-11-40/nu80410205001B06_0_p_sr.arf']
# RMF File:  ['./initial_dem/23-10-25_23-11-40/nu80410205001B06_0_p_sr.rmf']
# PHA File:  ['./initial_dem/23-10-25_23-11-40/nu80410205001B06_0_p_sr.pha']
# Using grades 0-4 NuSTAR events.
# ARF File:  ['./initial_dem/23-10-25_23-11-40/nu80410205001B06_0_4_p_sr.arf']
# RMF File:  ['./initial_dem/23-10-25_23-11-40/nu80410205001B06_0_4_p_sr.rmf']
# PHA File:  ['./initial_dem/23-10-25_23-11-40/nu80410205001B06_0_4_p_sr.pha']
# ARF File:  ['./initial_dem/23-10-25_23-11-40/nu80410205001B06_21_24_p_sr.arf']
# RMF File:  ['./initial_dem/23-10-25_23-11-40/nu80410205001B06_21_24_p_sr.rmf']
# PHA File:  ['./initial_dem/23-10-25_23-11-40/nu80410205001B06_21_24_p_sr.pha']
#
# Max NuSTAR Energy:  7.399999618530273
#
# A94 :     2.86   1.48  52 %
# A131 :     23.75   4.23  18 %
# A171 :     631.82   65.94  10 %
# A193 :     737.00   76.08  10 %
# A211 :     272.08   28.70  11 %
# A335 :     19.40   2.80  14 %
# 2.5-3.5keV A+B :     6560.45   1314.51  20 %
# 3.5-6.0keV A+B :     844.55   171.32  20 %
# 6.0-10.0keV A+B :     9.61   3.60  37 %
#
# Doing 100 iterations of DEMReg with input varied within uncertainty!
#
# WARNING: ITERATION  53  HAS 0 or NEGATIVE-DEM TEMP. BINS!!!
# Not saving this iteration!!
#
# Start Time:  2018-05-29 23:11:40
# Stop Time:  2018-05-29 23:13:45
# You provided both a region box and a specific region.
# Bounding box will be used only for initial data prep (will save submap instead of full disk);
# specific region will be used for DEM
#
# Adding 10% error in quadrature with aiapy.estimate_error output.
#
# ARF File:  ['./initial_dem/23-11-40_23-13-45/nu80410205001A06_0_p_sr.arf']
# RMF File:  ['./initial_dem/23-11-40_23-13-45/nu80410205001A06_0_p_sr.rmf']
# PHA File:  ['./initial_dem/23-11-40_23-13-45/nu80410205001A06_0_p_sr.pha']
# Using grades 0-4 NuSTAR events.
# ARF File:  ['./initial_dem/23-11-40_23-13-45/nu80410205001A06_0_4_p_sr.arf']
# RMF File:  ['./initial_dem/23-11-40_23-13-45/nu80410205001A06_0_4_p_sr.rmf']
# PHA File:  ['./initial_dem/23-11-40_23-13-45/nu80410205001A06_0_4_p_sr.pha']
# ARF File:  ['./initial_dem/23-11-40_23-13-45/nu80410205001A06_21_24_p_sr.arf']
# RMF File:  ['./initial_dem/23-11-40_23-13-45/nu80410205001A06_21_24_p_sr.rmf']
# PHA File:  ['./initial_dem/23-11-40_23-13-45/nu80410205001A06_21_24_p_sr.pha']
#
# Max NuSTAR Energy:  7.839999675750732
# ARF File:  ['./initial_dem/23-11-40_23-13-45/nu80410205001B06_0_p_sr.arf']
# RMF File:  ['./initial_dem/23-11-40_23-13-45/nu80410205001B06_0_p_sr.rmf']
# PHA File:  ['./initial_dem/23-11-40_23-13-45/nu80410205001B06_0_p_sr.pha']
# Using grades 0-4 NuSTAR events.
# ARF File:  ['./initial_dem/23-11-40_23-13-45/nu80410205001B06_0_4_p_sr.arf']
# RMF File:  ['./initial_dem/23-11-40_23-13-45/nu80410205001B06_0_4_p_sr.rmf']
# PHA File:  ['./initial_dem/23-11-40_23-13-45/nu80410205001B06_0_4_p_sr.pha']
# ARF File:  ['./initial_dem/23-11-40_23-13-45/nu80410205001B06_21_24_p_sr.arf']
# RMF File:  ['./initial_dem/23-11-40_23-13-45/nu80410205001B06_21_24_p_sr.rmf']
# PHA File:  ['./initial_dem/23-11-40_23-13-45/nu80410205001B06_21_24_p_sr.pha']
#
# Max NuSTAR Energy:  7.799999713897705
#
# A94 :     2.85   1.48  52 %
# A131 :     23.69   4.23  18 %
# A171 :     629.76   65.74  10 %
# A193 :     735.82   75.97  10 %
# A211 :     271.85   28.67  11 %
# A335 :     19.39   2.80  14 %
# 2.5-3.5keV A+B :     5921.16   1185.56  20 %
# 3.5-6.0keV A+B :     593.11   119.94  20 %
# 6.0-10.0keV A+B :     5.02   1.91  38 %
#
# Doing 100 iterations of DEMReg with input varied within uncertainty!
#
# WARNING: ITERATION  91  HAS 0 or NEGATIVE-DEM TEMP. BINS!!!
# Not saving this iteration!!
#
#
# WARNING: ITERATION  50  HAS 0 or NEGATIVE-DEM TEMP. BINS!!!
# Not saving this iteration!!
#
#
# WARNING: ITERATION  19  HAS 0 or NEGATIVE-DEM TEMP. BINS!!!
# Not saving this iteration!!
#
# Start Time:  2018-05-29 23:13:45
# Stop Time:  2018-05-29 23:15:25
# You provided both a region box and a specific region.
# Bounding box will be used only for initial data prep (will save submap instead of full disk);
# specific region will be used for DEM
#
# Adding 10% error in quadrature with aiapy.estimate_error output.
#
# ARF File:  ['./initial_dem/23-13-45_23-15-25/nu80410205001A06_0_p_sr.arf']
# RMF File:  ['./initial_dem/23-13-45_23-15-25/nu80410205001A06_0_p_sr.rmf']
# PHA File:  ['./initial_dem/23-13-45_23-15-25/nu80410205001A06_0_p_sr.pha']
# Using grades 0-4 NuSTAR events.
# ARF File:  ['./initial_dem/23-13-45_23-15-25/nu80410205001A06_0_4_p_sr.arf']
# RMF File:  ['./initial_dem/23-13-45_23-15-25/nu80410205001A06_0_4_p_sr.rmf']
# PHA File:  ['./initial_dem/23-13-45_23-15-25/nu80410205001A06_0_4_p_sr.pha']
# ARF File:  ['./initial_dem/23-13-45_23-15-25/nu80410205001A06_21_24_p_sr.arf']
# RMF File:  ['./initial_dem/23-13-45_23-15-25/nu80410205001A06_21_24_p_sr.rmf']
# PHA File:  ['./initial_dem/23-13-45_23-15-25/nu80410205001A06_21_24_p_sr.pha']
#
# Max NuSTAR Energy:  7.399999618530273
# ARF File:  ['./initial_dem/23-13-45_23-15-25/nu80410205001B06_0_p_sr.arf']
# RMF File:  ['./initial_dem/23-13-45_23-15-25/nu80410205001B06_0_p_sr.rmf']
# PHA File:  ['./initial_dem/23-13-45_23-15-25/nu80410205001B06_0_p_sr.pha']
# Using grades 0-4 NuSTAR events.
# ARF File:  ['./initial_dem/23-13-45_23-15-25/nu80410205001B06_0_4_p_sr.arf']
# RMF File:  ['./initial_dem/23-13-45_23-15-25/nu80410205001B06_0_4_p_sr.rmf']
# PHA File:  ['./initial_dem/23-13-45_23-15-25/nu80410205001B06_0_4_p_sr.pha']
# ARF File:  ['./initial_dem/23-13-45_23-15-25/nu80410205001B06_21_24_p_sr.arf']
# RMF File:  ['./initial_dem/23-13-45_23-15-25/nu80410205001B06_21_24_p_sr.rmf']
# PHA File:  ['./initial_dem/23-13-45_23-15-25/nu80410205001B06_21_24_p_sr.pha']
#
# Max NuSTAR Energy:  7.639999866485596
#
# A94 :     2.84   1.48  52 %
# A131 :     23.65   4.22  18 %
# A171 :     626.84   65.44  10 %
# A193 :     735.03   75.89  10 %
# A211 :     271.85   28.68  11 %
# A335 :     19.40   2.80  14 %
# 2.5-3.5keV A+B :     5634.00   1128.40  20 %
# 3.5-6.0keV A+B :     545.66   110.72  20 %
# 6.0-10.0keV A+B :     4.14   1.83  44 %
#
# Doing 100 iterations of DEMReg with input varied within uncertainty!
#
# WARNING: ITERATION  96  HAS 0 or NEGATIVE-DEM TEMP. BINS!!!
# Not saving this iteration!!
# WARNING: ITERATION  63  HAS 0 or NEGATIVE-DEM TEMP. BINS!!!
# Not saving this iteration!!
#
#
# WARNING: ITERATION  24  HAS 0 or NEGATIVE-DEM TEMP. BINS!!!
# Not saving this iteration!!
#
# Start Time:  2018-05-29 23:15:25
# Stop Time:  2018-05-29 23:20:00
# You provided both a region box and a specific region.
# Bounding box will be used only for initial data prep (will save submap instead of full disk);
# specific region will be used for DEM
#
# Adding 10% error in quadrature with aiapy.estimate_error output.
#
# ARF File:  ['./initial_dem/23-15-25_23-20-00/nu80410205001A06_0_p_sr.arf']
# RMF File:  ['./initial_dem/23-15-25_23-20-00/nu80410205001A06_0_p_sr.rmf']
# PHA File:  ['./initial_dem/23-15-25_23-20-00/nu80410205001A06_0_p_sr.pha']
# Using grades 0-4 NuSTAR events.
# ARF File:  ['./initial_dem/23-15-25_23-20-00/nu80410205001A06_0_4_p_sr.arf']
# RMF File:  ['./initial_dem/23-15-25_23-20-00/nu80410205001A06_0_4_p_sr.rmf']
# PHA File:  ['./initial_dem/23-15-25_23-20-00/nu80410205001A06_0_4_p_sr.pha']
# ARF File:  ['./initial_dem/23-15-25_23-20-00/nu80410205001A06_21_24_p_sr.arf']
# RMF File:  ['./initial_dem/23-15-25_23-20-00/nu80410205001A06_21_24_p_sr.rmf']
# PHA File:  ['./initial_dem/23-15-25_23-20-00/nu80410205001A06_21_24_p_sr.pha']
#
# Max NuSTAR Energy:  7.759999752044678
# ARF File:  ['./initial_dem/23-15-25_23-20-00/nu80410205001B06_0_p_sr.arf']
# RMF File:  ['./initial_dem/23-15-25_23-20-00/nu80410205001B06_0_p_sr.rmf']
# PHA File:  ['./initial_dem/23-15-25_23-20-00/nu80410205001B06_0_p_sr.pha']
# Using grades 0-4 NuSTAR events.
# ARF File:  ['./initial_dem/23-15-25_23-20-00/nu80410205001B06_0_4_p_sr.arf']
# RMF File:  ['./initial_dem/23-15-25_23-20-00/nu80410205001B06_0_4_p_sr.rmf']
# PHA File:  ['./initial_dem/23-15-25_23-20-00/nu80410205001B06_0_4_p_sr.pha']
# ARF File:  ['./initial_dem/23-15-25_23-20-00/nu80410205001B06_21_24_p_sr.arf']
# RMF File:  ['./initial_dem/23-15-25_23-20-00/nu80410205001B06_21_24_p_sr.rmf']
# PHA File:  ['./initial_dem/23-15-25_23-20-00/nu80410205001B06_21_24_p_sr.pha']
#
# Max NuSTAR Energy:  7.71999979019165
#
# A94 :     2.84   1.48  52 %
# A131 :     23.52   4.21  18 %
# A171 :     621.26   64.89  10 %
# A193 :     735.30   75.91  10 %
# A211 :     272.11   28.70  11 %
# A335 :     19.39   2.80  14 %
# 2.5-3.5keV A+B :     5352.36   1071.18  20 %
# 3.5-6.0keV A+B :     502.68   101.24  20 %
# 6.0-10.0keV A+B :     2.91   1.07  37 %
#
# Doing 100 iterations of DEMReg with input varied within uncertainty!
#
# WARNING: ITERATION  87  HAS 0 or NEGATIVE-DEM TEMP. BINS!!!
# Not saving this iteration!!
#
#
# WARNING: ITERATION  69  HAS 0 or NEGATIVE-DEM TEMP. BINS!!!
# Not saving this iteration!!
#
#
# WARNING: ITERATION  67  HAS 0 or NEGATIVE-DEM TEMP. BINS!!!
# Not saving this iteration!!
#
#
# WARNING: ITERATION  42  HAS 0 or NEGATIVE-DEM TEMP. BINS!!!
# Not saving this iteration!!

# %% [markdown]
# So many DEM results – while we can look at the saved plots for each time interval, it may be more interesting to extract specific parameters describing the distribution and see how they evolve in time.
#
# Here, we examine a number of DEM parameters.

# %%
importlib.reload(viz)
vals = viz.get_DEM_timeseries(time_intervals, working_dir, minT, maxT, name)    


peaks=vals['peaks']
peaksmk = [10**m1/1e6 for m1 in peaks]    

backcolors=['pink', 'lavenderblush']
color='Red'
    
viz.pretty_orbit_timeseries(time_intervals, peaksmk, 'DEM Peak Temperature (MK)', 'DEM Peak Temperature',
                        color, backcolors)


backcolors=['powderblue', 'aliceblue']
color='Blue'

above10s=np.array(vals['above10s'])
above10s_=above10s[:,0]

viz.pretty_orbit_timeseries(time_intervals, above10s_, 'EM (cm^-5)', 'Total EM >10 MK',
                        color, backcolors, error=True, quantity_low=above10s[:,1], quantity_high=above10s[:,2], 
                        ylog=True, comparisonbar=True, comp_band=[1.8e22, 1.5e23, 'Ishikawa (2017) 95%'])

backcolors=['powderblue', 'aliceblue']
color='Green'

above7s=np.array(vals['above7s'])
above7s_=above7s[:,0]

viz.pretty_orbit_timeseries(time_intervals, above7s_, 'EM (cm^-5)', 'Total EM >7 MK',
                        color, backcolors, error=True, quantity_low=above7s[:,1], quantity_high=above7s[:,2], 
                        ylog=True)

backcolors=['powderblue', 'aliceblue']
color='Purple'

above5s=np.array(vals['above5s'])
above5s_=above5s[:,0]

viz.pretty_orbit_timeseries(time_intervals, above5s_, 'EM (cm^-5)', 'Total EM >5 MK',
                        color, backcolors, error=True, quantity_low=above5s[:,1], quantity_high=above5s[:,2], 
                        ylog=True)


backcolors=['khaki', 'lemonchiffon']
color='Orange'

val=np.array(vals['low_powers'])

viz.pretty_orbit_timeseries(time_intervals, val, 'Index', 'Lower Power Law',
                        color, backcolors, error=False)


backcolors=['khaki', 'lemonchiffon']
color='Red'

val=np.array(vals['hi_powers'])*-1

viz.pretty_orbit_timeseries(time_intervals, val, 'Index', 'Upper Power Law',
                        color, backcolors, error=False)
