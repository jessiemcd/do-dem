# %% [markdown]
# Various figures related to characterizing the hot side of the EMD. The code needed to make paper figures is first, followed by a bunch of other alternate representations, etc.

# %%
path_to_dodem = '/Users/jmdunca2/do-dem/'
from sys import path as sys_path
sys_path.append(path_to_dodem+'/dodem/')

import HARP_and_age as haa
import nustar_utilities as nuutil
import lightcurves as lc
import visualize_dem_results as viz
import all_nu_analysis as ana

import pickle
import importlib

import numpy as np
from matplotlib import pyplot as plt
from astropy import units as u
import matplotlib.dates as mdates

from astropy.visualization import quantity_support
quantity_support()

with open('/Users/jmdunca2/do-dem/reference_files/all_targets_postghost_postshut.pickle', 'rb') as f:
    all_targets = pickle.load(f)

# %%
#Make EM > 10 MK needed arrays etc - weight vis uncertainties rather than ranges (not duration-weighted).
#This is not a paper figure, but it shows how the order of regions was determined for the paper figures 6,7.

duration_weight=False

with open('/Users/jmdunca2/do-dem/reference_files/samesames.pickle', 'rb') as f:
    data = pickle.load(f)

samesames = data['same region lists']
grf = data['ghost ray flags']
filelist = ana.get_same_region_file_lists(samesames, all_targets)


#Factor to adjust integrated EM values
area_i = 100**2
area_m = np.pi*150**2
#print(area_i, area_m)
factor = area_m/area_i
#factor=1


allgood=0
region_above10s=[]
region_totaltime=[]
region_totalvals=[]
times_per=[]
contigs=[]
all_times=[]
all_intervals=[]

region_int_above10s=[]

for i in range(0, len(filelist)):
    gf = filelist[i]

    vals = []
    above10s_ = []
    totaltime = 0
    times=[]
    durs=[]
    ups=[]
    downs=[]
    for f_ in gf:
        with open(f_, 'rb') as f:
            data = pickle.load(f)
        #print(f_)
        #print(data.keys())
        time = data['time_interval']
        dur = (time[1]-time[0]).to(u.s).value
        durs.append(dur)
        times.append(time)
        above10s = data['above_10MK']
        #print(f_)
        #print(above10s)
        above10s_.append(above10s[0])
        vals.append([dur*above10s[0]])
        totaltime+=dur
        ups.append(above10s[2])
        downs.append(above10s[1])

    contiguous, intervals, int_inds = ana.check_contig(times)
    print(samesames[i])
    print(contiguous)
    print(int_inds)
    print(intervals)
    #print(times)
    print('')
    if vals:
        region_int_above10s_=[]
        for ii in int_inds:
            indx = np.arange(ii[0],ii[1])
            int_vals = np.array(vals)[indx]
            int_a10s = np.array(above10s_)[indx]
            int_durs = np.array(durs)[indx]
            region_int_above10s_.append([np.sum(int_vals)/np.sum(int_durs)*factor, np.min(int_a10s)*factor, np.max(int_a10s)*factor])

        region_int_above10s.append(region_int_above10s_)

        ldowns = np.log10(np.array(downs))
        lups = np.log10(np.array(ups))
        la10s = np.log10(np.array(above10s_))
        
        if duration_weight:
            weighted_val = np.sum([la10s[i]*durs[i]/totaltime for i in range(0, len(la10s))])
            ddif = weighted_val-ldowns
            ein = np.sum([(ddif[i]*durs[i]/totaltime)**2 for i in range(0, len(la10s))])**(1/2)
            edwn = 10**(weighted_val - ein)
            udiff = lups-weighted_val
            euin = np.sum([(udiff[i]*durs[i]/totaltime)**2 for i in range(0, len(la10s))])**(1/2)
            eup = 10**(euin + weighted_val)
            print(ein, euin)
            print(weighted_val, edwn, eup)
            input_val = 10**(weighted_val)
        else:
            lmean = np.mean(la10s)
            ddif = la10s-ldowns
            edwn = 10**(lmean-np.sum([dd**2 for dd in ddif])**(1/2)/len(ddif))
            udif = lups-la10s
            eup = 10**(np.sum([dd**2 for dd in udif])**(1/2)/len(udif) + lmean)
            input_val = 10**(lmean)
        

        
        #region_above10s.append([np.sum(vals)/totaltime*factor, np.min(downs)*factor, np.max(ups)*factor])
        region_above10s.append([input_val*factor, edwn*factor, eup*factor]) 
        region_totaltime.append(totaltime)
        region_totalvals.append(len(vals))
        times_per.append([np.min(times), np.max(times)])
        all_times.append(times)
        all_intervals.append(intervals)
        contigs.append(contiguous)

    else:
        region_int_above10s.append([])
        region_above10s.append([0, 0, 0])
        region_totaltime.append(0)
        region_totalvals.append(0)
        times_per.append([])
        all_times.append([])
        all_intervals.append([])
        contigs.append(False)
    



outputs = [region_above10s, region_totaltime, region_totalvals, times_per, all_times, all_intervals, contigs]


order = np.argsort(np.array(region_above10s)[:,0])
regids = [samesames[i] for i in order]
grf = [grf[i] for i in order]

ghost_ticks = np.where(grf)[0]

plotlabs = ana.make_labels(regids, all_targets)

#print('')
#print(len(labs))
#print(len(order))

region_time_hr = np.array((region_totaltime*u.s).to(u.hr))
#print(region_time_hr[order])


fig, ax = plt.subplots(1, 1, figsize=(28,10))


xerrl = (np.array(region_above10s)[:,0][order]/factor - np.array(region_above10s)[:,1][order]/factor)
xerrl[np.where(xerrl < 1e10)] = 0.0
xerrh = (np.array(region_above10s)[:,2][order]/factor - np.array(region_above10s)[:,0][order]/factor)
xerrh[np.where(xerrh < 1e10)] = 0.0

#xerr = [(np.array(region_above10s)[:,0][order] - np.array(region_above10s)[:,1][order]), 
#        (np.array(region_above10s)[:,2][order] - np.array(region_above10s)[:,0][order])]

xerr_nf = [xerrl, xerrh]

ax.errorbar(np.array(region_above10s)[:,0][order]/factor, np.arange(0, len(filelist), 1), 
            xerr=xerr_nf,
           linestyle='', marker='o', linewidth=3, markersize=10, color='indianred', 
            label='New Regions (no area factor)', alpha=0.3, zorder=0)

xerrl = (np.array(region_above10s)[:,0][order] - np.array(region_above10s)[:,1][order])
xerrl[np.where(xerrl < 1e10)] = 0.0
xerrh = (np.array(region_above10s)[:,2][order] - np.array(region_above10s)[:,0][order])
xerrh[np.where(xerrh < 1e10)] = 0.0

#xerr = [(np.array(region_above10s)[:,0][order] - np.array(region_above10s)[:,1][order]), 
#        (np.array(region_above10s)[:,2][order] - np.array(region_above10s)[:,0][order])]

xerr = [xerrl, xerrh]

ax.errorbar(np.array(region_above10s)[:,0][order], np.arange(0, len(filelist), 1), 
            xerr=xerr,
           linestyle='', marker='o', linewidth=3, markersize=10, color='indianred', label='New Regions', zorder=1)



oneerr = np.zeros((2,1))

ginds = [25, 29, 28]
colors = ['darkgreen', 'purple', 'royalblue']
labels = ['Duncan+2024', 'Hannah+2016 "L3"', 'Hannah+2016 "L2"']
gc=0
for gind in ginds:
    oneerr[0] = xerr[0][gind]
    oneerr[1] = xerr[1][gind]
    
    print(oneerr)
    
    ax.errorbar(np.array(region_above10s)[:,0][order][gind]/factor, np.arange(0, len(filelist), 1)[gind],
                xerr=oneerr/factor,
                linestyle='', marker='o', color=colors[gc], linewidth=3, markersize=10, alpha=0.3, zorder=2) #, s=140)
    
    
    ax.errorbar(np.array(region_above10s)[:,0][order][gind], np.arange(0, len(filelist), 1)[gind],
                xerr=oneerr,
                linestyle='', marker='o', color=colors[gc], linewidth=3, markersize=10, label=labels[gc], zorder=2) #, s=140)

    gc+=1



fntsz=25
ax.set_xscale('log')
ax.axvline(1.8e22, color='steelblue', zorder=0)
ax.axvline(1.5e23, color='steelblue', zorder=0)
ax.axvspan(1.8e22, 1.5e23, alpha=0.3, color='steelblue', label='Ishikawa+2017 95% Interval', zorder=0)
ax.set_yticks(np.arange(0, len(filelist))) #[2:]
ax.set_yticklabels(labels=plotlabs, fontsize=17) #[2:]
plt.xticks(fontsize=20)
ax.set_xlabel('Total EM >10 MK ('+(u.cm**(-5)).to_string('latex_inline')+')', fontsize=20)
ax.grid(axis = 'y', linestyle='dotted')
ax.legend(loc='lower right', fontsize=fntsz)
ax.set_ylim([-1,len(filelist)])
#ax.set_xlim([4e17,2e24])
ax.set_title('Average EM integrated >10 MK per region', fontsize=30, fontweight='bold')
for i in ghost_ticks:
    ax.get_yticklabels()[i].set_color('red')
print('')

plt.savefig('per_region_above10_uncertainty_bounds_asym_full_prop_noweight.png', dpi=300)
# Out:
# ['01-nov-14_1 region_0']
# True
# [(0, 2)]
# [[<Time object: scale='utc' format='datetime' value=[datetime.datetime(2014, 11, 1, 21, 34, 45)
#  datetime.datetime(2014, 11, 1, 21, 41, 55)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2014, 11, 1, 21, 41, 55)
#  datetime.datetime(2014, 11, 1, 21, 47, 50)]>]]
#
# ['01-nov-14_1 region_1']
# True
# [(0, 1)]
# [[<Time object: scale='utc' format='datetime' value=[datetime.datetime(2014, 11, 1, 21, 34, 45)
#  datetime.datetime(2014, 11, 1, 21, 47, 50)]>]]
#
# ['11-dec-14 region_0']
# True
# [(0, 1)]
# [[<Time object: scale='utc' format='datetime' value=[datetime.datetime(2014, 12, 11, 18, 38, 55)
#  datetime.datetime(2014, 12, 11, 18, 47, 5)]>]]
#
# ['19-feb-16 region_0']
# False
# [(0, 1), (1, 5), (5, 6)]
# [[<Time object: scale='utc' format='datetime' value=[datetime.datetime(2016, 2, 19, 18, 54, 50)
#  datetime.datetime(2016, 2, 19, 19, 8, 55)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2016, 2, 19, 20, 31, 30)
#  datetime.datetime(2016, 2, 19, 20, 34, 35)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2016, 2, 19, 20, 34, 35)
#  datetime.datetime(2016, 2, 19, 20, 37, 45)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2016, 2, 19, 20, 37, 45)
#  datetime.datetime(2016, 2, 19, 20, 41, 15)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2016, 2, 19, 20, 41, 15)
#  datetime.datetime(2016, 2, 19, 20, 45)]>], [[<Time object: scale='utc' format='datetime' value=2016-02-19 23:44:55>, <Time object: scale='utc' format='datetime' value=2016-02-20 00:09:50>]]]
#
# ['22-apr-16_2 region_0']
# False
# [(0, 1), (1, 2), (2, 6)]
# [[<Time object: scale='utc' format='datetime' value=[datetime.datetime(2016, 4, 22, 18, 47, 45)
#  datetime.datetime(2016, 4, 22, 19, 6, 20)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2016, 4, 22, 20, 24, 30)
#  datetime.datetime(2016, 4, 22, 20, 38, 45)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2016, 4, 22, 22, 1, 10)
#  datetime.datetime(2016, 4, 22, 22, 6, 25)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2016, 4, 22, 22, 6, 25)
#  datetime.datetime(2016, 4, 22, 22, 12, 45)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2016, 4, 22, 22, 12, 45)
#  datetime.datetime(2016, 4, 22, 22, 18, 30)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2016, 4, 22, 22, 18, 30)
#  datetime.datetime(2016, 4, 22, 22, 25, 10)]>]]
#
# ['27-jul-16_1 region_0', '26-jul-16_1 region_0']
# False
# [(0, 3), (3, 4), (4, 5)]
# [[<Time object: scale='utc' format='datetime' value=[datetime.datetime(2016, 7, 27, 0, 13)
#  datetime.datetime(2016, 7, 27, 0, 18, 50)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2016, 7, 27, 0, 18, 50)
#  datetime.datetime(2016, 7, 27, 0, 23)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2016, 7, 27, 0, 23)
#  datetime.datetime(2016, 7, 27, 0, 25, 10)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2016, 7, 26, 20, 11, 35)
#  datetime.datetime(2016, 7, 26, 20, 23, 20)]>], [[<Time object: scale='utc' format='datetime' value=2016-07-26 20:59:35>, <Time object: scale='utc' format='datetime' value=2016-07-26 21:55:25>]]]
#
# ['26-jul-16_1 region_1']
# True
# [(0, 1)]
# [[<Time object: scale='utc' format='datetime' value=[datetime.datetime(2016, 7, 26, 20, 59, 35)
#  datetime.datetime(2016, 7, 26, 21, 55, 25)]>]]
#
# ['10-oct-17 region_0']
# False
# [(0, 1), (1, 3)]
# [[<Time object: scale='utc' format='datetime' value=[datetime.datetime(2017, 10, 10, 3, 21, 15)
#  datetime.datetime(2017, 10, 10, 4, 4, 45)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2017, 10, 10, 4, 41, 50)
#  datetime.datetime(2017, 10, 10, 5, 9, 15)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2017, 10, 10, 5, 9, 15)
#  datetime.datetime(2017, 10, 10, 5, 41, 25)]>]]
#
# ['10-oct-17 region_1']
# False
# [(0, 1), (1, 2)]
# [[[<Time object: scale='utc' format='datetime' value=2017-10-10 03:21:15>, <Time object: scale='utc' format='datetime' value=2017-10-10 04:04:45>]], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2017, 10, 10, 4, 41, 50)
#  datetime.datetime(2017, 10, 10, 5, 41, 25)]>]]
#
# ['29-may-18_1 region_0']
# False
# [(0, 1), (1, 3), (3, 11), (11, 13), (13, 17), (17, 19), (19, 20), (20, 24)]
# [[<Time object: scale='utc' format='datetime' value=[datetime.datetime(2018, 5, 29, 15, 59, 35)
#  datetime.datetime(2018, 5, 29, 16, 0, 40)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2018, 5, 29, 16, 3, 5)
#  datetime.datetime(2018, 5, 29, 16, 3, 45)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2018, 5, 29, 16, 3, 45)
#  datetime.datetime(2018, 5, 29, 16, 4, 50)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2018, 5, 29, 18, 15, 15)
#  datetime.datetime(2018, 5, 29, 18, 22, 40)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2018, 5, 29, 18, 22, 40)
#  datetime.datetime(2018, 5, 29, 18, 23, 40)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2018, 5, 29, 18, 23, 40)
#  datetime.datetime(2018, 5, 29, 18, 24, 20)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2018, 5, 29, 18, 24, 20)
#  datetime.datetime(2018, 5, 29, 18, 25, 20)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2018, 5, 29, 18, 25, 20)
#  datetime.datetime(2018, 5, 29, 18, 26, 15)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2018, 5, 29, 18, 26, 15)
#  datetime.datetime(2018, 5, 29, 18, 27)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2018, 5, 29, 18, 27)
#  datetime.datetime(2018, 5, 29, 18, 29, 15)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2018, 5, 29, 18, 29, 15)
#  datetime.datetime(2018, 5, 29, 18, 32, 15)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2018, 5, 29, 19, 8, 55)
#  datetime.datetime(2018, 5, 29, 19, 15, 15)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2018, 5, 29, 19, 15, 15)
#  datetime.datetime(2018, 5, 29, 19, 17, 5)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2018, 5, 29, 19, 26, 5)
#  datetime.datetime(2018, 5, 29, 19, 28, 5)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2018, 5, 29, 19, 28, 5)
#  datetime.datetime(2018, 5, 29, 19, 30, 30)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2018, 5, 29, 19, 30, 30)
#  datetime.datetime(2018, 5, 29, 19, 33, 20)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2018, 5, 29, 19, 33, 20)
#  datetime.datetime(2018, 5, 29, 19, 38, 30)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2018, 5, 29, 21, 1, 35)
#  datetime.datetime(2018, 5, 29, 21, 5, 35)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2018, 5, 29, 21, 5, 35)
#  datetime.datetime(2018, 5, 29, 21, 15, 50)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2018, 5, 29, 22, 22, 15)
#  datetime.datetime(2018, 5, 29, 22, 26, 5)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2018, 5, 29, 22, 30, 45)
#  datetime.datetime(2018, 5, 29, 22, 32, 55)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2018, 5, 29, 22, 32, 55)
#  datetime.datetime(2018, 5, 29, 22, 36, 25)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2018, 5, 29, 22, 36, 25)
#  datetime.datetime(2018, 5, 29, 22, 43, 5)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2018, 5, 29, 22, 43, 5)
#  datetime.datetime(2018, 5, 29, 22, 46)]>]]
#
# ['29-may-18_2 region_0']
# True
# [(0, 1)]
# [[<Time object: scale='utc' format='datetime' value=[datetime.datetime(2018, 5, 29, 21, 16, 55)
#  datetime.datetime(2018, 5, 29, 21, 31, 40)]>]]
#
# ['07-sep-18 region_0']
# False
# [(0, 2), (2, 3), (3, 5)]
# [[<Time object: scale='utc' format='datetime' value=[datetime.datetime(2018, 9, 7, 14, 56, 55)
#  datetime.datetime(2018, 9, 7, 15, 14, 20)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2018, 9, 7, 15, 14, 20)
#  datetime.datetime(2018, 9, 7, 15, 56, 35)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2018, 9, 7, 16, 57)
#  datetime.datetime(2018, 9, 7, 17, 33, 15)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2018, 9, 7, 18, 10, 15)
#  datetime.datetime(2018, 9, 7, 18, 27, 45)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2018, 9, 7, 18, 27, 45)
#  datetime.datetime(2018, 9, 7, 18, 36, 30)]>]]
#
# ['10-sep-18 region_0', '09-sep-18 region_0']
# False
# [(0, 1), (1, 4), (4, 5), (5, 6), (6, 7), (7, 11), (11, 14)]
# [[<Time object: scale='utc' format='datetime' value=[datetime.datetime(2018, 9, 10, 14, 29, 10)
#  datetime.datetime(2018, 9, 10, 14, 49, 40)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2018, 9, 10, 15, 26, 40)
#  datetime.datetime(2018, 9, 10, 15, 43, 45)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2018, 9, 10, 15, 43, 45)
#  datetime.datetime(2018, 9, 10, 16, 10, 40)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2018, 9, 10, 16, 10, 40)
#  datetime.datetime(2018, 9, 10, 16, 17, 30)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2018, 9, 10, 17, 3, 20)
#  datetime.datetime(2018, 9, 10, 17, 14, 35)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2018, 9, 9, 8, 50, 5)
#  datetime.datetime(2018, 9, 9, 9, 2, 10)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2018, 9, 9, 11, 6, 50)
#  datetime.datetime(2018, 9, 9, 11, 26, 25)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2018, 9, 9, 12, 30, 5)
#  datetime.datetime(2018, 9, 9, 12, 33, 25)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2018, 9, 9, 12, 33, 25)
#  datetime.datetime(2018, 9, 9, 12, 35, 30)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2018, 9, 9, 12, 35, 30)
#  datetime.datetime(2018, 9, 9, 12, 38, 30)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2018, 9, 9, 12, 38, 30)
#  datetime.datetime(2018, 9, 9, 12, 41, 10)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2018, 9, 9, 12, 49, 40)
#  datetime.datetime(2018, 9, 9, 12, 54, 5)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2018, 9, 9, 12, 54, 5)
#  datetime.datetime(2018, 9, 9, 12, 57, 25)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2018, 9, 9, 12, 57, 25)
#  datetime.datetime(2018, 9, 9, 13, 3, 5)]>]]
#
# ['13-apr-19 region_0', '12-apr-19 region_0']
# False
# [(0, 6), (6, 11), (11, 19), (19, 20), (20, 22), (22, 24), (24, 26), (26, 34), (34, 37), (37, 39), (39, 42), (42, 47), (47, 57)]
# [[<Time object: scale='utc' format='datetime' value=[datetime.datetime(2019, 4, 13, 3, 5, 50)
#  datetime.datetime(2019, 4, 13, 3, 6, 35)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2019, 4, 13, 3, 6, 35)
#  datetime.datetime(2019, 4, 13, 3, 7, 30)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2019, 4, 13, 3, 7, 30)
#  datetime.datetime(2019, 4, 13, 3, 8, 25)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2019, 4, 13, 3, 8, 25)
#  datetime.datetime(2019, 4, 13, 3, 9, 25)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2019, 4, 13, 3, 9, 25)
#  datetime.datetime(2019, 4, 13, 3, 10, 55)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2019, 4, 13, 3, 10, 55)
#  datetime.datetime(2019, 4, 13, 3, 11, 50)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2019, 4, 13, 3, 22)
#  datetime.datetime(2019, 4, 13, 3, 24, 15)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2019, 4, 13, 3, 24, 15)
#  datetime.datetime(2019, 4, 13, 3, 25)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2019, 4, 13, 3, 25)
#  datetime.datetime(2019, 4, 13, 3, 26, 10)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2019, 4, 13, 3, 26, 10)
#  datetime.datetime(2019, 4, 13, 3, 26, 40)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2019, 4, 13, 3, 26, 40)
#  datetime.datetime(2019, 4, 13, 3, 29, 15)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2019, 4, 13, 4, 6, 5)
#  datetime.datetime(2019, 4, 13, 4, 8, 55)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2019, 4, 13, 4, 8, 55)
#  datetime.datetime(2019, 4, 13, 4, 9, 45)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2019, 4, 13, 4, 9, 45)
#  datetime.datetime(2019, 4, 13, 4, 10, 55)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2019, 4, 13, 4, 10, 55)
#  datetime.datetime(2019, 4, 13, 4, 12, 5)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2019, 4, 13, 4, 12, 5)
#  datetime.datetime(2019, 4, 13, 4, 14, 45)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2019, 4, 13, 4, 14, 45)
#  datetime.datetime(2019, 4, 13, 4, 17, 25)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2019, 4, 13, 4, 17, 25)
#  datetime.datetime(2019, 4, 13, 4, 18, 30)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2019, 4, 13, 4, 18, 30)
#  datetime.datetime(2019, 4, 13, 4, 20, 35)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2019, 4, 13, 10, 32, 45)
#  datetime.datetime(2019, 4, 13, 10, 36, 20)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2019, 4, 13, 10, 43, 45)
#  datetime.datetime(2019, 4, 13, 10, 47, 35)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2019, 4, 13, 10, 47, 35)
#  datetime.datetime(2019, 4, 13, 10, 50, 20)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2019, 4, 13, 10, 59, 35)
#  datetime.datetime(2019, 4, 13, 11, 0, 50)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2019, 4, 13, 11, 0, 50)
#  datetime.datetime(2019, 4, 13, 11, 2, 25)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2019, 4, 13, 11, 21, 20)
#  datetime.datetime(2019, 4, 13, 11, 24, 30)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2019, 4, 13, 11, 24, 30)
#  datetime.datetime(2019, 4, 13, 11, 32, 30)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2019, 4, 12, 15, 12, 55)
#  datetime.datetime(2019, 4, 12, 15, 16, 5)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2019, 4, 12, 15, 16, 5)
#  datetime.datetime(2019, 4, 12, 15, 18, 55)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2019, 4, 12, 15, 18, 55)
#  datetime.datetime(2019, 4, 12, 15, 22, 50)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2019, 4, 12, 15, 22, 50)
#  datetime.datetime(2019, 4, 12, 15, 25, 40)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2019, 4, 12, 15, 25, 40)
#  datetime.datetime(2019, 4, 12, 15, 27, 50)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2019, 4, 12, 15, 27, 50)
#  datetime.datetime(2019, 4, 12, 15, 30, 45)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2019, 4, 12, 15, 30, 45)
#  datetime.datetime(2019, 4, 12, 15, 32, 30)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2019, 4, 12, 15, 32, 30)
#  datetime.datetime(2019, 4, 12, 15, 36, 15)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2019, 4, 12, 15, 59, 10)
#  datetime.datetime(2019, 4, 12, 16, 0, 45)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2019, 4, 12, 16, 0, 45)
#  datetime.datetime(2019, 4, 12, 16, 2, 50)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2019, 4, 12, 16, 2, 50)
#  datetime.datetime(2019, 4, 12, 16, 5, 10)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2019, 4, 12, 17, 36, 35)
#  datetime.datetime(2019, 4, 12, 17, 37, 25)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2019, 4, 12, 17, 37, 25)
#  datetime.datetime(2019, 4, 12, 17, 38, 5)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2019, 4, 12, 20, 2, 50)
#  datetime.datetime(2019, 4, 12, 20, 4)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2019, 4, 12, 20, 4)
#  datetime.datetime(2019, 4, 12, 20, 5, 15)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2019, 4, 12, 20, 5, 15)
#  datetime.datetime(2019, 4, 12, 20, 8, 5)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2019, 4, 12, 20, 11, 25)
#  datetime.datetime(2019, 4, 12, 20, 12, 10)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2019, 4, 12, 20, 12, 10)
#  datetime.datetime(2019, 4, 12, 20, 12, 55)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2019, 4, 12, 20, 12, 55)
#  datetime.datetime(2019, 4, 12, 20, 14, 15)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2019, 4, 12, 20, 14, 15)
#  datetime.datetime(2019, 4, 12, 20, 16, 45)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2019, 4, 12, 20, 16, 45)
#  datetime.datetime(2019, 4, 12, 20, 18, 35)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2019, 4, 12, 21, 39, 30)
#  datetime.datetime(2019, 4, 12, 21, 41, 5)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2019, 4, 12, 21, 41, 5)
#  datetime.datetime(2019, 4, 12, 21, 42, 15)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2019, 4, 12, 21, 42, 15)
#  datetime.datetime(2019, 4, 12, 21, 44, 10)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2019, 4, 12, 21, 44, 10)
#  datetime.datetime(2019, 4, 12, 21, 46, 10)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2019, 4, 12, 21, 46, 10)
#  datetime.datetime(2019, 4, 12, 21, 48, 30)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2019, 4, 12, 21, 48, 30)
#  datetime.datetime(2019, 4, 12, 21, 50, 30)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2019, 4, 12, 21, 50, 30)
#  datetime.datetime(2019, 4, 12, 21, 52, 30)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2019, 4, 12, 21, 52, 30)
#  datetime.datetime(2019, 4, 12, 22, 23)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2019, 4, 12, 22, 23)
#  datetime.datetime(2019, 4, 12, 22, 27, 15)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2019, 4, 12, 22, 27, 15)
#  datetime.datetime(2019, 4, 12, 22, 30, 15)]>]]
#
# ['29-jan-20 region_0']
# False
# [(0, 1), (1, 2), (2, 3), (3, 4), (4, 5)]
# [[<Time object: scale='utc' format='datetime' value=[datetime.datetime(2020, 1, 29, 11, 12, 35)
#  datetime.datetime(2020, 1, 29, 11, 20, 10)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2020, 1, 29, 11, 47, 15)
#  datetime.datetime(2020, 1, 29, 11, 53, 55)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2020, 1, 29, 16, 41, 10)
#  datetime.datetime(2020, 1, 29, 17, 7, 45)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2020, 1, 29, 17, 48, 35)
#  datetime.datetime(2020, 1, 29, 17, 56)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2020, 1, 29, 19, 18, 50)
#  datetime.datetime(2020, 1, 29, 19, 24, 40)]>]]
#
# ['30-jan-20 region_0']
# False
# [(0, 1), (1, 2)]
# [[<Time object: scale='utc' format='datetime' value=[datetime.datetime(2020, 1, 30, 13, 31, 40)
#  datetime.datetime(2020, 1, 30, 13, 33, 35)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2020, 1, 30, 18, 30, 50)
#  datetime.datetime(2020, 1, 30, 18, 49, 41)]>]]
#
# ['08-jun-20 region_0', '07-jun-20 region_0', '06-jun-20 region_0']
# False
# [(0, 1), (1, 3), (3, 5), (5, 6), (6, 7), (7, 8), (8, 9), (9, 12), (12, 18)]
# [[<Time object: scale='utc' format='datetime' value=[datetime.datetime(2020, 6, 8, 19, 54, 59)
#  datetime.datetime(2020, 6, 8, 20, 0, 54)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2020, 6, 8, 20, 8, 9)
#  datetime.datetime(2020, 6, 8, 20, 14, 44)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2020, 6, 8, 20, 14, 44)
#  datetime.datetime(2020, 6, 8, 20, 26, 29)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2020, 6, 8, 21, 6, 20)
#  datetime.datetime(2020, 6, 8, 21, 15, 10)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2020, 6, 8, 21, 15, 10)
#  datetime.datetime(2020, 6, 8, 21, 19, 50)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2020, 6, 8, 21, 44, 20)
#  datetime.datetime(2020, 6, 8, 21, 49, 5)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2020, 6, 7, 19, 45, 24)
#  datetime.datetime(2020, 6, 7, 19, 47, 29)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2020, 6, 7, 20, 2, 29)
#  datetime.datetime(2020, 6, 7, 20, 13, 34)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2020, 6, 7, 21, 25, 30)
#  datetime.datetime(2020, 6, 7, 21, 26)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2020, 6, 6, 20, 44, 5)
#  datetime.datetime(2020, 6, 6, 20, 46, 20)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2020, 6, 6, 20, 46, 20)
#  datetime.datetime(2020, 6, 6, 20, 48, 40)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2020, 6, 6, 20, 48, 40)
#  datetime.datetime(2020, 6, 6, 20, 49, 35)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2020, 6, 6, 21, 24, 35)
#  datetime.datetime(2020, 6, 6, 21, 25, 5)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2020, 6, 6, 21, 25, 5)
#  datetime.datetime(2020, 6, 6, 21, 25, 35)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2020, 6, 6, 21, 25, 35)
#  datetime.datetime(2020, 6, 6, 21, 26, 15)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2020, 6, 6, 21, 26, 15)
#  datetime.datetime(2020, 6, 6, 21, 26, 45)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2020, 6, 6, 21, 26, 45)
#  datetime.datetime(2020, 6, 6, 21, 27, 35)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2020, 6, 6, 21, 27, 35)
#  datetime.datetime(2020, 6, 6, 21, 28, 15)]>]]
#
# ['08-jan-21 region_0']
# True
# [(0, 4)]
# [[<Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 1, 8, 10, 12, 45)
#  datetime.datetime(2021, 1, 8, 10, 33, 10)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 1, 8, 10, 33, 10)
#  datetime.datetime(2021, 1, 8, 10, 40, 20)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 1, 8, 10, 40, 20)
#  datetime.datetime(2021, 1, 8, 10, 51, 25)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 1, 8, 10, 51, 25)
#  datetime.datetime(2021, 1, 8, 11, 13, 50)]>]]
#
# ['14-jan-21 region_0']
# False
# [(0, 1), (1, 2), (2, 3)]
# [[<Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 1, 14, 9, 34, 20)
#  datetime.datetime(2021, 1, 14, 9, 52, 35)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 1, 14, 11, 10, 55)
#  datetime.datetime(2021, 1, 14, 11, 22, 5)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 1, 14, 12, 47, 35)
#  datetime.datetime(2021, 1, 14, 13, 32, 35)]>]]
#
# ['20-jan-21 region_0']
# True
# [(0, 1)]
# [[<Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 1, 20, 12, 17, 30)
#  datetime.datetime(2021, 1, 20, 12, 20, 40)]>]]
#
# ['29-apr-21 region_0']
# False
# [(0, 1), (1, 4), (4, 5), (5, 7), (7, 8), (8, 9)]
# [[<Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 4, 29, 14, 53, 45)
#  datetime.datetime(2021, 4, 29, 14, 59, 45)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 4, 29, 16, 30, 20)
#  datetime.datetime(2021, 4, 29, 16, 38, 5)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 4, 29, 16, 38, 5)
#  datetime.datetime(2021, 4, 29, 16, 44, 45)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 4, 29, 16, 44, 45)
#  datetime.datetime(2021, 4, 29, 16, 48, 5)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 4, 29, 19, 2)
#  datetime.datetime(2021, 4, 29, 19, 7, 20)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 4, 29, 20, 21, 10)
#  datetime.datetime(2021, 4, 29, 20, 22)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 4, 29, 20, 22)
#  datetime.datetime(2021, 4, 29, 20, 23, 25)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 4, 29, 21, 20, 15)
#  datetime.datetime(2021, 4, 29, 21, 24, 40)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 4, 29, 22, 15, 5)
#  datetime.datetime(2021, 4, 29, 22, 15, 50)]>]]
#
# ['03-may-21_1 region_0']
# True
# [(0, 5)]
# [[<Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 5, 3, 17, 8, 55)
#  datetime.datetime(2021, 5, 3, 17, 9, 55)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 5, 3, 17, 9, 55)
#  datetime.datetime(2021, 5, 3, 17, 13, 15)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 5, 3, 17, 13, 15)
#  datetime.datetime(2021, 5, 3, 17, 18)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 5, 3, 17, 18)
#  datetime.datetime(2021, 5, 3, 17, 22, 55)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 5, 3, 17, 22, 55)
#  datetime.datetime(2021, 5, 3, 17, 24, 30)]>]]
#
# ['03-may-21_2 region_0']
# False
# [(0, 1), (1, 2), (2, 3)]
# [[<Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 5, 3, 18, 45, 10)
#  datetime.datetime(2021, 5, 3, 18, 53, 20)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 5, 3, 20, 21, 50)
#  datetime.datetime(2021, 5, 3, 20, 34, 15)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 5, 3, 21, 58, 25)
#  datetime.datetime(2021, 5, 3, 22, 17, 25)]>]]
#
# ['20-jul-21 region_0']
# False
# [(0, 1), (1, 4), (4, 8), (8, 9), (9, 11)]
# [[<Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 7, 20, 2, 52)
#  datetime.datetime(2021, 7, 20, 3, 1, 15)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 7, 20, 3, 37, 20)
#  datetime.datetime(2021, 7, 20, 3, 41, 50)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 7, 20, 3, 41, 50)
#  datetime.datetime(2021, 7, 20, 3, 51, 20)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 7, 20, 3, 51, 20)
#  datetime.datetime(2021, 7, 20, 4, 37, 55)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 7, 20, 5, 59, 45)
#  datetime.datetime(2021, 7, 20, 6, 3, 40)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 7, 20, 6, 3, 40)
#  datetime.datetime(2021, 7, 20, 6, 6, 30)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 7, 20, 6, 6, 30)
#  datetime.datetime(2021, 7, 20, 6, 8, 55)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 7, 20, 6, 8, 55)
#  datetime.datetime(2021, 7, 20, 6, 14, 30)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 7, 20, 7, 15)
#  datetime.datetime(2021, 7, 20, 7, 28)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 7, 20, 8, 27, 10)
#  datetime.datetime(2021, 7, 20, 8, 35, 10)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 7, 20, 8, 35, 10)
#  datetime.datetime(2021, 7, 20, 8, 39, 10)]>]]
#
# ['20-jul-21 region_1']
# False
# [(0, 9), (9, 22), (22, 29), (29, 31), (31, 32), (32, 37), (37, 39), (39, 40)]
# [[<Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 7, 20, 2, 52)
#  datetime.datetime(2021, 7, 20, 2, 52, 50)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 7, 20, 2, 52, 50)
#  datetime.datetime(2021, 7, 20, 2, 53, 50)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 7, 20, 2, 53, 50)
#  datetime.datetime(2021, 7, 20, 2, 54, 45)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 7, 20, 2, 54, 45)
#  datetime.datetime(2021, 7, 20, 2, 56, 15)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 7, 20, 2, 56, 15)
#  datetime.datetime(2021, 7, 20, 2, 57, 15)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 7, 20, 2, 57, 15)
#  datetime.datetime(2021, 7, 20, 2, 58, 5)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 7, 20, 2, 58, 5)
#  datetime.datetime(2021, 7, 20, 2, 59)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 7, 20, 2, 59)
#  datetime.datetime(2021, 7, 20, 2, 59, 55)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 7, 20, 2, 59, 55)
#  datetime.datetime(2021, 7, 20, 3, 1, 15)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 7, 20, 3, 37, 20)
#  datetime.datetime(2021, 7, 20, 3, 38, 50)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 7, 20, 3, 38, 50)
#  datetime.datetime(2021, 7, 20, 3, 40, 30)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 7, 20, 3, 40, 30)
#  datetime.datetime(2021, 7, 20, 3, 42, 15)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 7, 20, 3, 42, 15)
#  datetime.datetime(2021, 7, 20, 3, 44, 15)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 7, 20, 3, 44, 15)
#  datetime.datetime(2021, 7, 20, 3, 45, 35)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 7, 20, 3, 45, 35)
#  datetime.datetime(2021, 7, 20, 3, 47, 20)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 7, 20, 3, 47, 20)
#  datetime.datetime(2021, 7, 20, 3, 48, 40)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 7, 20, 3, 48, 40)
#  datetime.datetime(2021, 7, 20, 3, 50, 45)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 7, 20, 3, 50, 45)
#  datetime.datetime(2021, 7, 20, 3, 51, 50)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 7, 20, 3, 51, 50)
#  datetime.datetime(2021, 7, 20, 3, 53, 10)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 7, 20, 3, 53, 10)
#  datetime.datetime(2021, 7, 20, 3, 54, 25)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 7, 20, 3, 54, 25)
#  datetime.datetime(2021, 7, 20, 4, 36, 15)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 7, 20, 4, 36, 15)
#  datetime.datetime(2021, 7, 20, 4, 37, 55)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 7, 20, 6, 0, 50)
#  datetime.datetime(2021, 7, 20, 6, 3, 30)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 7, 20, 6, 3, 30)
#  datetime.datetime(2021, 7, 20, 6, 4, 55)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 7, 20, 6, 4, 55)
#  datetime.datetime(2021, 7, 20, 6, 6, 20)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 7, 20, 6, 6, 20)
#  datetime.datetime(2021, 7, 20, 6, 8, 20)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 7, 20, 6, 8, 20)
#  datetime.datetime(2021, 7, 20, 6, 9, 50)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 7, 20, 6, 9, 50)
#  datetime.datetime(2021, 7, 20, 6, 12, 15)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 7, 20, 6, 12, 15)
#  datetime.datetime(2021, 7, 20, 6, 14, 30)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 7, 20, 6, 50, 35)
#  datetime.datetime(2021, 7, 20, 6, 52)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 7, 20, 6, 52)
#  datetime.datetime(2021, 7, 20, 6, 54, 55)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 7, 20, 7, 4)
#  datetime.datetime(2021, 7, 20, 7, 5, 55)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 7, 20, 7, 17, 10)
#  datetime.datetime(2021, 7, 20, 7, 23, 35)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 7, 20, 7, 23, 35)
#  datetime.datetime(2021, 7, 20, 7, 27, 5)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 7, 20, 7, 27, 5)
#  datetime.datetime(2021, 7, 20, 7, 30, 30)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 7, 20, 7, 30, 30)
#  datetime.datetime(2021, 7, 20, 7, 33, 50)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 7, 20, 7, 33, 50)
#  datetime.datetime(2021, 7, 20, 7, 36, 40)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 7, 20, 8, 27, 10)
#  datetime.datetime(2021, 7, 20, 8, 35, 10)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 7, 20, 8, 35, 10)
#  datetime.datetime(2021, 7, 20, 8, 39, 10)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 7, 20, 10, 8, 15)
#  datetime.datetime(2021, 7, 20, 10, 13, 15)]>]]
#
# ['30-jul-21_1 region_0']
# True
# [(0, 1)]
# [[[<Time object: scale='utc' format='datetime' value=2021-07-30 21:18:20>, <Time object: scale='utc' format='datetime' value=2021-07-30 22:18:50>]]]
#
# ['30-jul-21_1 region_1']
# True
# [(0, 1)]
# [[[<Time object: scale='utc' format='datetime' value=2021-07-30 21:18:20>, <Time object: scale='utc' format='datetime' value=2021-07-30 22:18:50>]]]
#
# ['30-jul-21_2 region_0']
# True
# [(0, 1)]
# [[<Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 7, 30, 20, 16, 55)
#  datetime.datetime(2021, 7, 30, 20, 42, 10)]>]]
#
# ['17-nov-21_1 region_0']
# True
# [(0, 1)]
# [[<Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 11, 17, 17, 28, 35)
#  datetime.datetime(2021, 11, 17, 18, 29, 5)]>]]
#
# ['22-nov-21_1 region_0', '21-nov-21 region_0', '20-nov-21 region_0', '19-nov-21 region_0']
# False
# [(0, 1), (1, 2), (2, 3), (3, 5)]
# [[<Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 11, 22, 0, 32, 35)
#  datetime.datetime(2021, 11, 22, 0, 50, 10)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 11, 21, 22, 55, 55)
#  datetime.datetime(2021, 11, 21, 23, 31, 10)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 11, 20, 1, 50, 30)
#  datetime.datetime(2021, 11, 20, 2, 0, 35)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 11, 19, 22, 37, 15)
#  datetime.datetime(2021, 11, 19, 22, 54, 5)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2021, 11, 19, 22, 54, 5)
#  datetime.datetime(2021, 11, 19, 23, 1, 15)]>]]
#
# ['03-jun-22_2 region_0']
# False
# [(0, 1), (1, 2), (2, 3)]
# [[<Time object: scale='utc' format='datetime' value=[datetime.datetime(2022, 6, 3, 18, 36, 35)
#  datetime.datetime(2022, 6, 3, 18, 55, 40)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2022, 6, 3, 21, 32, 45)
#  datetime.datetime(2022, 6, 3, 21, 54, 10)]>], [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2022, 6, 3, 22, 28, 50)
#  datetime.datetime(2022, 6, 3, 22, 33, 30)]>]]
#
# ['03-jun-22_2 region_1']
# True
# [(0, 1)]
# [[<Time object: scale='utc' format='datetime' value=[datetime.datetime(2022, 6, 3, 22, 25, 5)
#  datetime.datetime(2022, 6, 3, 22, 33, 30)]>]]
#
# ['11-dec-22_2 region_0']
# True
# [(0, 6)]
# [[<Time object: scale='utc' format='datetime' value=[datetime.datetime(2022, 12, 11, 22, 18, 10)
#  datetime.datetime(2022, 12, 11, 22, 19, 55)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2022, 12, 11, 22, 19, 55)
#  datetime.datetime(2022, 12, 11, 22, 20, 55)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2022, 12, 11, 22, 20, 55)
#  datetime.datetime(2022, 12, 11, 22, 22, 15)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2022, 12, 11, 22, 22, 15)
#  datetime.datetime(2022, 12, 11, 22, 26)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2022, 12, 11, 22, 26)
#  datetime.datetime(2022, 12, 11, 22, 28, 10)]>, <Time object: scale='utc' format='datetime' value=[datetime.datetime(2022, 12, 11, 22, 28, 10)
#  datetime.datetime(2022, 12, 11, 22, 30, 35)]>]]
#
# [[6.51071194e+20]
#  [4.77456703e+20]]
# [[1.77390166e+21]
#  [6.08350337e+21]]
# [[1.34930768e+21]
#  [3.58622486e+21]]

# %%
#Make EM > 10 MK needed arrays etc - NEW VERISON WHERE WE SHIFT THE ISHIKAWA RANGE INSTEAD.

plot_all_intervals=False
plot_peak_ratio=False
plot_all_contig=True

labelfontsize=25

with open('/Users/jmdunca2/do-dem/reference_files/samesames.pickle', 'rb') as f:
    data = pickle.load(f)


samesames = data['same region lists']
grf = data['ghost ray flags']
#Lists per region
filelist = ana.get_same_region_file_lists(samesames, all_targets)

filelist = [filelist[i] for i in order]
samesames = [samesames[i] for i in order]
grf = [grf[i] for i in order]

#Factor to adjust integrated EM values
area_i = 100**2
area_m = np.pi*150**2
#print(area_i, area_m)
factor = area_m/area_i
#factor=1
print(factor)


# allgood=0
# region_above10s=[]
# region_totaltime=[]
# region_totalvals=[]
# times_per=[]
# contigs=[]
# all_times=[]
# all_intervals=[]

# region_int_above10s=[]

fig, ax = plt.subplots(1, 1, figsize=(28,30), tight_layout={'pad': 1})

ylabelvals = []
val=0
for i in range(0, len(filelist)):
    gf = filelist[i]

    #VERSION WHERE WE PLOT ALL FILES AT RANDOM FOR THE REGION
    #==============================================================
    # regnum=0
    # for f_ in gf:
    #     with open(f_, 'rb') as f:
    #         data = pickle.load(f)

    #     vert=val
    #     xerrl = (np.array([data['above_10MK'][0]- data['above_10MK'][1]]))
    #     #xerrl[np.where(xerrl < 1e10)] = 0.0
    #     xerrh = (np.array([data['above_10MK'][2] - data['above_10MK'][0]]))
    #     #xerrh[np.where(xerrh < 1e10)] = 0.0
        
    #     xerr = [xerrl, xerrh]

    #     ax.errorbar(data['above_10MK'][0], vert, xerr=xerr,
    #             linestyle='', marker='o', linewidth=3, markersize=10, color='indianred', zorder=1)
    #     ax.errorbar(data['above_10MK'][0], vert,
    #             linestyle='', marker='o', linewidth=3, markersize=10, color='black', zorder=2)#, label='New Regions', zorder=1)
    #     val+=1
    #     regnum+=1

    # ylabelvals.append(val-round(regnum/2.)+1.)
    # ax.axhline(val+4, 
    #             linestyle='dotted', color='black')#, label='New Regions', zorder=1)
    # val+=10
    #==============================================================

    regnum=0
    times=[]
    above10s=[]
    peakEMs=[]
    for f_ in gf:
        with open(f_, 'rb') as f:
            data = pickle.load(f)
        times.append(data['time_interval'])
        #above10s.append([factor*d for d in data['above_10MK']])
        above10s.append([d for d in data['above_10MK']])
        peakEMs.append(data['max'])

    contiguous, intervals, int_inds = ana.check_contig(times)
    if times:
        flipper=1
        if plot_all_intervals:
            colors=['hi', 'forestgreen', 'teal']
            for ii in int_inds:
                indx = np.arange(ii[0],ii[1])
                int_a10s = np.array(above10s)[indx]
                if plot_peak_ratio:
                    peaks=np.array(peakEMs)[indx]
                    int_a10s = [int_a10s[p]/peaks[p] for p in range(0, len(peaks))]
                for ia10 in int_a10s:
    
                    vert=val
                    xerrl = (np.array([ia10[0]- ia10[1]]))
                    #xerrl[np.where(xerrl < 1e10)] = 0.0
                    xerrh = (np.array([ia10[2] - ia10[0]]))
                    #xerrh[np.where(xerrh < 1e10)] = 0.0
                    
                    xerr = [xerrl, xerrh]                
                    ax.errorbar(ia10[0], vert, xerr=xerr, linestyle='', marker='o', linewidth=3, markersize=10, 
                                color=colors[flipper], zorder=1)
                    ax.errorbar(ia10[0], vert, linestyle='', marker='o', linewidth=3, markersize=10, color='black', zorder=2)
                    val+=1
                    regnum+=1
                flipper*=-1
                    
                val+=5
                
        elif plot_all_contig:
            colors=['hi', 'mediumseagreen', 'darkgreen']
            for ii in int_inds:
                indx = np.arange(ii[0],ii[1])
                int_a10s = np.array(above10s)[indx]
                if plot_peak_ratio:
                    peaks=np.array(peakEMs)[indx]
                    int_a10s = np.array([int_a10s[p]/peaks[p] for p in range(0, len(peaks))])
                    
                #Taking the mean and conducting error propogation
                la10s = np.log10(int_a10s[:,0])
                lmean = np.mean(la10s)
                ddif = la10s - np.log10(int_a10s[:,1])
                #ddif = la10s-ldowns
                edwn = 10**(lmean-np.sum([dd**2 for dd in ddif])**(1/2)/len(ddif))
                udif = np.log10(int_a10s[:,2])-la10s
                eup = 10**(np.sum([dd**2 for dd in udif])**(1/2)/len(udif) + lmean)
                input_val = 10**(lmean)

                vert=val
                xerrl = (np.array([input_val - edwn]))
                #xerrl[np.where(xerrl < 1e10)] = 0.0
                xerrh = (np.array([eup - input_val]))
                #xerrh[np.where(xerrh < 1e10)] = 0.0

                #xerr_og = [xerrl/factor, xerrh/factor]
                
                xerr = [xerrl, xerrh]
                ax.errorbar(input_val, vert, xerr=xerr, linestyle='', marker='o', linewidth=4, markersize=10, color=colors[flipper], zorder=1)
                #ax.errorbar(input_val/factor, vert, xerr=xerr_og, linestyle='', marker='o', linewidth=4, markersize=10, alpha=0.3, 
                #            color=colors[flipper], zorder=1)
                ax.errorbar(input_val, vert, linestyle='', marker='o', linewidth=4, markersize=10, color='black', zorder=2)
                #ax.errorbar(input_val/factor, vert, linestyle='', marker='o', linewidth=4, markersize=10, alpha=0.3, 
                #            color='black', zorder=2)
                val+=4
                regnum+=1
                flipper*=-1
                    
        
        ylabelvals.append(val-round(regnum/2.)+1.)
        ax.axhline(val+6, linestyle='dotted', color='black')#, label='New Regions', zorder=1)
        val+=10

startlevel=1e14
box_properties = dict(boxstyle='round', facecolor='green', alpha=0.5, edgecolor='black')
for i in range(0, len(plotlabs)):
    #print(plotlabs[i])
    if plotlabs[i] == '1-nov-2014 AR12192':
        color='grey'
        box_properties = dict(boxstyle='round', facecolor=color, edgecolor='black')
        ax.text(startlevel, ylabelvals[i]+3, 'Hannah+2016 L2', fontsize=labelfontsize-2, style='italic', bbox=box_properties)
        ax.axhspan(ylabelvals[i]-9, ylabelvals[i]+4, color=color, alpha=0.25)
        
    if plotlabs[i] == '1-nov-2014 AR12194':
        color='silver' #color='goldenrod'
        box_properties = dict(boxstyle='round', facecolor=color, edgecolor='black')
        ax.text(startlevel, ylabelvals[i], 'Hannah+2016 L3', fontsize=labelfontsize-2, style='italic', bbox=box_properties)
        ax.axhspan(ylabelvals[i]-9, ylabelvals[i]+4, color=color, alpha=0.25)
        
    if plotlabs[i] == '29-may-2018 AR12712':
        color='grey' #color='pink'
        box_properties = dict(boxstyle='round', facecolor=color, edgecolor='black')
        ax.text(startlevel, ylabelvals[i], 'Duncan+2024', fontsize=labelfontsize-2, style='italic', bbox=box_properties)
        ax.axhspan(ylabelvals[i]-32, ylabelvals[i]+8, color=color, alpha=0.25)
        


ax.set_yticks(ylabelvals)#[2:]
ax.set_yticklabels(labels=plotlabs, fontsize=labelfontsize)
ax.set_xscale('log')
plt.xticks(fontsize=labelfontsize)

ishi_range = [1.8e22, 1.5e23]
ishi_range_adjust = [ir/factor for ir in ishi_range]

if not plot_peak_ratio:
    ax.set_xlabel('Total EM >10 MK ['+(u.cm**(-5)).to_string('latex_inline')+']', fontsize=labelfontsize)
    #ax.axvline(ishi_range[0], color='steelblue', zorder=0, linestyle='dashed')
    #ax.axvline(ishi_range[1], color='steelblue', zorder=0, linestyle='dashed')
    #ax.axvspan(ishi_range[0], ishi_range[1], alpha=0.2, color='steelblue', label='Ishikawa+2017 95% Interval', zorder=0)
    ax.axvline(ishi_range_adjust[0], color='steelblue', zorder=0)
    ax.axvline(ishi_range_adjust[1], color='steelblue', zorder=0)
    ax.axvspan(ishi_range_adjust[0], ishi_range_adjust[1], alpha=0.4, color='steelblue', label='Ishikawa+2017 95% Interval x (Area Factor)', zorder=0)    
    
ghost_ticks = np.where(grf)[0]
for i in ghost_ticks:
    ax.get_yticklabels()[i].set_color('red')
print('')

ax.set_ylim([-10,val])
ax.set_xlim([5e13,2e23])
ax.legend(loc='lower right', fontsize=labelfontsize+5)

if plot_all_intervals:
    if plot_peak_ratio:
        plt.savefig('all_values_above10_all_peak_rat_ishiadj.png', dpi=300)
    else:
        plt.savefig('all_values_above10_all_ishiadj.png', dpi=300)

if plot_all_contig:
    if plot_peak_ratio:
        plt.savefig('all_values_above10_contig_peak_rat_ishiadj.png', dpi=300)
    else:
        plt.savefig('all_values_above10_contig_ishiadj.png', dpi=300)
# Out:
# 7.068583470577035

# %%
#Make EM > 5 MK needed arrays etc - in comparison with Ishikawa+Krucker2019

plot_all_intervals=False
plot_peak_ratio=False
plot_all_contig=True

labelfontsize=25

with open('/Users/jmdunca2/do-dem/reference_files/samesames.pickle', 'rb') as f:
    data = pickle.load(f)


samesames = data['same region lists']
grf = data['ghost ray flags']
#Lists per region
filelist = ana.get_same_region_file_lists(samesames, all_targets)

filelist = [filelist[i] for i in order]
samesames = [samesames[i] for i in order]
grf = [grf[i] for i in order]


#Factor to adjust integrated EM values
ishi_area = 360**2
ex_area = (360*u.arcsec)**2 #with units
nuarea = np.pi*150**2
factor = nuarea/ishi_area
print('Area Difference Factor: ', factor)

conversion = ((750*u.km)/(1*u.arcsec))**2
print(conversion)

#total area factor
taf = (ex_area*conversion).decompose()
print(taf)

orbits = [[6.3e45, 16e45]*(u.cm)**(-3), [0.033e45, 11e45]*(u.cm)**(-3), [6.6e45, 17e45]*(u.cm)**(-3), [6.3e45, 16e45]*(u.cm)**(-3)]
print('')

conv_orbits = []
for oo in orbits:
    conv_orbits.append([(oo[0]/taf).decompose().to(1/(u.cm**5)).value/factor, 
          (oo[1]/taf).decompose().to(1/(u.cm**5)).value/factor])

print(conv_orbits)





fig, ax = plt.subplots(1, 1, figsize=(28,30), tight_layout={'pad': 1})

ylabelvals = []
val=0
for i in range(0, len(filelist)):
    gf = filelist[i]

    regnum=0
    times=[]
    above5s=[]
    peakEMs=[]
    for f_ in gf:
        with open(f_, 'rb') as f:
            data = pickle.load(f)
        times.append(data['time_interval'])
        #above10s.append([factor*d for d in data['above_10MK']])
        above5s.append([d for d in data['above_5MK']])
        peakEMs.append(data['max'])

    contiguous, intervals, int_inds = ana.check_contig(times)
    if times:
        flipper=1
        if plot_all_intervals:
            colors=['hi', 'mediumpurple', 'rebeccapurple']
            for ii in int_inds:
                indx = np.arange(ii[0],ii[1])
                int_a5s = np.array(above5s)[indx]
                if plot_peak_ratio:
                    peaks=np.array(peakEMs)[indx]
                    int_a5s = [int_a10s[p]/peaks[p] for p in range(0, len(peaks))]
                for ia5 in int_a5s:
    
                    vert=val
                    xerrl = (np.array([ia5[0]- ia5[1]]))
                    #xerrl[np.where(xerrl < 1e10)] = 0.0
                    xerrh = (np.array([ia5[2] - ia5[0]]))
                    #xerrh[np.where(xerrh < 1e10)] = 0.0
                    
                    xerr = [xerrl, xerrh]                
                    ax.errorbar(ia5[0], vert, xerr=xerr, linestyle='', marker='o', linewidth=3, markersize=10, 
                                color=colors[flipper], zorder=1)
                    ax.errorbar(ia5[0], vert, linestyle='', marker='o', linewidth=3, markersize=10, color='black', zorder=2)
                    val+=1
                    regnum+=1
                flipper*=-1
                    
                val+=5
                
        elif plot_all_contig:
            colors=['hi', 'steelblue', 'lightskyblue']
            for ii in int_inds:
                indx = np.arange(ii[0],ii[1])
                int_a5s = np.array(above5s)[indx]
                if plot_peak_ratio:
                    peaks=np.array(peakEMs)[indx]
                    int_a5s = np.array([int_a5s[p]/peaks[p] for p in range(0, len(peaks))])
                    
                #Taking the mean and conducting error propogation
                la5s = np.log10(int_a5s[:,0])
                lmean = np.mean(la5s)
                ddif = la5s - np.log10(int_a5s[:,1])
                #ddif = la10s-ldowns
                edwn = 10**(lmean-np.sum([dd**2 for dd in ddif])**(1/2)/len(ddif))
                udif = np.log10(int_a5s[:,2])-la5s
                eup = 10**(np.sum([dd**2 for dd in udif])**(1/2)/len(udif) + lmean)
                input_val = 10**(lmean)

                vert=val
                xerrl = (np.array([input_val - edwn]))
                #xerrl[np.where(xerrl < 1e10)] = 0.0
                xerrh = (np.array([eup - input_val]))
                #xerrh[np.where(xerrh < 1e10)] = 0.0

                #xerr_og = [xerrl/factor, xerrh/factor]
                
                xerr = [xerrl, xerrh]
                ax.errorbar(input_val, vert, xerr=xerr, linestyle='', marker='o', linewidth=4, markersize=10, color=colors[flipper], zorder=1)
                #ax.errorbar(input_val/factor, vert, xerr=xerr_og, linestyle='', marker='o', linewidth=4, markersize=10, alpha=0.3, 
                #            color=colors[flipper], zorder=1)
                ax.errorbar(input_val, vert, linestyle='', marker='o', linewidth=4, markersize=10, color='black', zorder=2)
                #ax.errorbar(input_val/factor, vert, linestyle='', marker='o', linewidth=4, markersize=10, alpha=0.3, 
                #            color='black', zorder=2)
                val+=4
                regnum+=1
                flipper*=-1
                    
        
        ylabelvals.append(val-round(regnum/2.)+1.)
        ax.axhline(val+6, linestyle='dotted', color='black')#, label='New Regions', zorder=1)
        val+=10

startlevel=1.5e18
box_properties = dict(boxstyle='round', facecolor='green', alpha=0.5, edgecolor='black')
for i in range(0, len(plotlabs)):
    #print(plotlabs[i])
    if plotlabs[i] == '1-nov-2014 AR12192':
        color='grey'
        box_properties = dict(boxstyle='round', facecolor=color, edgecolor='black')
        ax.text(startlevel, ylabelvals[i]+3, 'Hannah+2016 L2', fontsize=labelfontsize-2, style='italic', bbox=box_properties)
        ax.axhspan(ylabelvals[i]-9, ylabelvals[i]+4, color=color, alpha=0.25)
        
    if plotlabs[i] == '1-nov-2014 AR12194':
        color='silver'
        box_properties = dict(boxstyle='round', facecolor=color, edgecolor='black')
        ax.text(startlevel, ylabelvals[i], 'Hannah+2016 L3', fontsize=labelfontsize-2, style='italic', bbox=box_properties)
        ax.axhspan(ylabelvals[i]-9, ylabelvals[i]+4, color=color, alpha=0.25)
        
    if plotlabs[i] == '29-may-2018 AR12712':
        color='grey'
        box_properties = dict(boxstyle='round', facecolor=color, edgecolor='black')
        ax.text(startlevel, ylabelvals[i], 'Duncan+2024', fontsize=labelfontsize-2, style='italic', bbox=box_properties)
        ax.axhspan(ylabelvals[i]-32, ylabelvals[i]+8, color=color, alpha=0.25)
        


ax.set_yticks(ylabelvals)#[2:]
ax.set_yticklabels(labels=plotlabs, fontsize=labelfontsize)
ax.set_xscale('log')
plt.xticks(fontsize=labelfontsize)

colors=['#0072B2', '#009E73', '#CC79A7'] #'#56B4E9', 

if not plot_peak_ratio:
    ax.set_xlabel('Total EM >5 MK ['+(u.cm**(-5)).to_string('latex_inline')+']', fontsize=labelfontsize)
    countr=0
    for cc in conv_orbits[0:3]:
        ax.axvline(cc[0], color=colors[countr], zorder=2)
        ax.axvline(cc[1], color=colors[countr], zorder=2)
        ax.axvspan(cc[0], cc[1], alpha=0.2, color=colors[countr], 
                   label='Ishikawa+2019, Orbit '+str(countr+1)+' x (Area Factor)', zorder=0)
        countr+=1
     
ghost_ticks = np.where(grf)[0]
for i in ghost_ticks:
    ax.get_yticklabels()[i].set_color('red')
print('')

ax.set_ylim([-10,val])
ax.set_xlim([1e18,3e26])
ax.legend(loc='lower right', fontsize=labelfontsize+5)

if plot_all_intervals:
    if plot_peak_ratio:
        plt.savefig('all_values_above5_all_peak_rat_ishiadj.png', dpi=300)
    else:
        plt.savefig('all_values_above5_all_ishiadj.png', dpi=300)

if plot_all_contig:
    if plot_peak_ratio:
        plt.savefig('all_values_above5_contig_peak_rat_ishiadj.png', dpi=300)
    else:
        plt.savefig('all_values_above5_contig_ishiadj.png', dpi=300)
# Out:
# Area Difference Factor:  0.545415391248228
# 562500.0 km2 / arcsec2
# 7.29e+16 m2
#
# [[1.5844758778926468e+25, 4.024065721632118e+25], [8.299635550866246e+22, 2.7665451836220816e+25], [1.6599271101732493e+25, 4.275569829234127e+25], [1.5844758778926468e+25, 4.024065721632118e+25]]

# %%
#Consistency plot - new two-panel format - data prep. This cell takes around 7 minutes to run. The following cell contains 
#the figure code itself, separated so formatting changes can be made without re-running this part. 

import glob
import os
import visualize_dem_results as viz


time_weighted = True
seconds_per = 1

tickfont=15

with open('/Users/jmdunca2/do-dem/reference_files/samesames.pickle', 'rb') as f:
    data = pickle.load(f)

#get file lists for each region
samesames = data['same region lists']
grf = data['ghost ray flags']
filelist = ana.get_same_region_file_lists(samesames, all_targets)

all_durs = []
totals = []
above_material = []
for i in range(0, len(samesames)):
    key = samesames[i][0].split(' ')[0]
    sumcons_tw=[]
    dur_each=np.zeros(5)*u.s
    a5w7s, a7w10s, a5w10s, a10w12s, a12w15s = [], [], [], [], []
    #for each completed DEM in the list...
    for ff in filelist[i]:
        if 'ghost_corr' in ff:
            files = glob.glob(os.path.dirname(ff)+'/*'+key+'ghost_corr_MC_DEM_result.pickle')
        else:
            #Get the consistency files (DEM results with different temp bounds)
            files = glob.glob(os.path.dirname(ff)+'/*'+key+'_MC_DEM_result.pickle')
        #If there are multiple keys, need a second form to make sure we get 
        #the consistency files (DEM results with different temp bounds)
        if len(samesames[i]) > 1:
            #print(samesames[i])
            key2 = samesames[i][1].split(' ')[0]
            if 'ghost_corr' in ff:
                files.extend(glob.glob(os.path.dirname(ff)+'/*'+key2+'_ghost_corr_MC_DEM_result.pickle'))
            else:
                files.extend(glob.glob(os.path.dirname(ff)+'/*'+key2+'_MC_DEM_result.pickle'))

        #Sort by temp bounds
        files.sort()
        #for f in files:
        #    print(f)
        #print('')
        sumcon=0
        
        #get the sum of the consistency values over all files for this result
        for f in files:
            data, timestring, time = viz.load_DEM(f)
            #if data['chisq'] > 2.5:
                #print('chisq: ', data['chisq'], key, timestring, f)
            sumcon += (1 if viz.checkresid(data) == 0 else 0)

        #get the time interval duation, add to total duration for that consistency sum
        dur = (time[1]-time[0]).to(u.s)
        dur_each[sumcon]+=dur

        #If material above 5 MK is needed:
        if sumcon > 0:
            #print(files[1])
            #Get above 5 MK material needed for DEM with 7 MK upper bound
            a5w7s.append(np.array(viz.get_DEM_params(files[1])[2]))
            if sumcon > 1:
                #Get above 7 MK material needed for DEM with 10 MK upper bound
                a7w10s.append(np.array(viz.get_DEM_params(files[2])[3]))
                a5w10s.append(np.array(viz.get_DEM_params(files[2])[2]))
            if sumcon > 2:
                #Get above 10 MK material needed for DEM with 12.6 MK upper bound
                a10w12s.append(np.array(viz.get_DEM_params(files[3])[4]))
            if sumcon > 3:
                #Get above 12.6 MK material needed for DEM with 15.8 MK upper bound
                #print(files[4])
                #print(viz.get_DEM_params(files[4]))
                #print(viz.get_DEM_params(files[4])[-1])
                a12w15s.append(np.array(viz.get_DEM_params(files[4])[-3]))

        
    above_material.append([np.array(a5w7s), np.array(a7w10s), np.array(a5w10s), np.array(a10w12s), np.array(a12w15s)])
    total=np.sum(dur_each)
    all_durs.append(dur_each/total)
    totals.append(total)


consorder = np.argsort(np.array(all_durs)[:,0])
regids = [samesames[i] for i in consorder]
print(regids[0:9])
consorder[0:9] = [11, 18, 15, 32, 1, 30, 31, 19, 23] #consorder[0:7] = [11,17,31,1,29,30,18]#consorder[0:4] = [12, 18, 31, 30]# [12, 18, 32, 31] #consorder[0:3] = [12, 18, 29]
#print('WARNING MANUAL EDIT OF CONSISTENCY ORDER FOR NICE PLOTTING!!!')
print('')
regids = [samesames[i] for i in consorder]
print(regids[0:9])


above_material = [above_material[i] for i in consorder]
regids = [samesames[i] for i in consorder]
durs_order = [all_durs[i] for i in consorder]
plotlabs = ana.make_labels(regids, all_targets)
grf2 = [grf[i] for i in consorder]


ghost_ticks = np.where(grf2)[0]

# res_dict = {}
# for i in range(0, len(regids)):
#     res_dict[plotlabs[i]] = durs_order[i]

# category_names = ['5 MK', '7 MK', '10 MK', '12.6 MK', '15.8 MK']
# results=res_dict
# Out:
# [['11-dec-22_2 region_0'], ['01-nov-14_1 region_1'], ['03-jun-22_2 region_0'], ['20-jul-21 region_0'], ['20-jan-21 region_0'], ['14-jan-21 region_0'], ['07-sep-18 region_0'], ['03-jun-22_2 region_1'], ['30-jan-20 region_0']]
#
# [['07-sep-18 region_0'], ['14-jan-21 region_0'], ['30-jan-20 region_0'], ['11-dec-22_2 region_0'], ['01-nov-14_1 region_1'], ['03-jun-22_2 region_0'], ['03-jun-22_2 region_1'], ['20-jan-21 region_0'], ['20-jul-21 region_0']]

# %%
for i in range(0, len(samesames)):
    print(i, samesames[i])
# Out:
# 0 ['01-nov-14_1 region_0']
# 1 ['01-nov-14_1 region_1']
# 2 ['11-dec-14 region_0']
# 3 ['19-feb-16 region_0']
# 4 ['22-apr-16_2 region_0']
# 5 ['27-jul-16_1 region_0', '26-jul-16_1 region_0']
# 6 ['26-jul-16_1 region_1']
# 7 ['10-oct-17 region_0']
# 8 ['10-oct-17 region_1']
# 9 ['29-may-18_1 region_0']
# 10 ['29-may-18_2 region_0']
# 11 ['07-sep-18 region_0']
# 12 ['10-sep-18 region_0', '09-sep-18 region_0']
# 13 ['13-apr-19 region_0', '12-apr-19 region_0']
# 14 ['29-jan-20 region_0']
# 15 ['30-jan-20 region_0']
# 16 ['08-jun-20 region_0', '07-jun-20 region_0', '06-jun-20 region_0']
# 17 ['08-jan-21 region_0']
# 18 ['14-jan-21 region_0']
# 19 ['20-jan-21 region_0']
# 20 ['29-apr-21 region_0']
# 21 ['03-may-21_1 region_0']
# 22 ['03-may-21_2 region_0']
# 23 ['20-jul-21 region_0']
# 24 ['20-jul-21 region_1']
# 25 ['30-jul-21_1 region_0']
# 26 ['30-jul-21_1 region_1']
# 27 ['30-jul-21_2 region_0']
# 28 ['17-nov-21_1 region_0']
# 29 ['22-nov-21_1 region_0', '21-nov-21 region_0', '20-nov-21 region_0', '19-nov-21 region_0']
# 30 ['03-jun-22_2 region_0']
# 31 ['03-jun-22_2 region_1']
# 32 ['11-dec-22_2 region_0']

# %%
"""
https://matplotlib.org/stable/gallery/lines_bars_and_markers/horizontal_barchart_distribution.html
adapted from ^
"""
labels = plotlabs #list(results.keys())
data = np.array(durs_order) #np.array(list(results.values()))
data_cum = data.cumsum(axis=1)
#category_colors = plt.colormaps['rainbow']([0.15  , 0.3, 0.65, 0.8, 0.95 ])#[0.8  , 0.6, 0.4, 0.2, 0.05 ])
okabe_ito = [
    "#56B4E9",
    "#009E73",
    "#F0E442",
    "#0072B2",
    "#E69F00",
    "#D55E00",
    "#CC79A7",
    "#000000",
]
category_colors = okabe_ito[:5]
    #np.linspace(0.8, 0.15, data.shape[1]))
category_names = ['<5 MK', '<7 MK', '<10 MK', '<12.6 MK', '<15.8 MK']

fig, axes = plt.subplots(1,2, figsize=(20, 8), tight_layout = {'pad': 1})

ax=axes[0]
ax.invert_yaxis()
#ax.xaxis.set_visible(False)
#ax.yaxis.set_visible(False)
#ax.tick_params(axis='x', labelrotation=45)
#ax.set_xlim(0, np.sum(data, axis=1).max())



for i, (colname, color) in enumerate(zip(category_names, category_colors)):
    widths = data[:, i]
    starts = data_cum[:, i] - widths
    rects = ax.bar(np.arange(len(labels), 0, -1),#labels, 
                   widths, bottom=starts, width=0.5, #tick_label=plotlabs, 
                   #left=starts, #height=0.5,
                    label=colname, color=color)

    #r, g, b, _ = color
    #text_color = 'white' if r * g * b < 0.5 else 'darkgrey'
    #ax.bar_label(rects, label_type='center', color=text_color)

ax.legend(ncols=len(category_names), bbox_to_anchor=(0, 1),
          loc='lower left', fontsize='large')
#ax.set_ylim([-(len(regids)-len(abovelabs)),len(abovelabs)+1])
#ax.tick_params(axis='x', labelrotation=45, ha='right')
ax.set_xticks(np.arange(len(labels), 0, -1))
ax.set_xticklabels(labels, rotation=45, ha='right', fontsize=11)
ax.set_ylabel('% of observed quiescent time', fontsize=20)
ax.set_yticklabels([0, 20, 40, 60, 80, 100], fontsize=15)
for i in ghost_ticks:
    indi = np.arange(len(labels), 0, -1)[i]
    #print(i, indi)
    ax.get_xticklabels()[i].set_color('red')

region_a5w7s = []
region_a7w10s = []
region_a5w10s = []
region_a10w12s = []
region_a12w15s = []
abovelabs = []
for i in range(0,len(regids)):
    
    if np.sum(durs_order[i][1:]) > 0:
        abovelabs.append(plotlabs[i])
        a5w7s = above_material[i][0]
        region_a5w7s.append([np.mean(a5w7s, axis=0)[0], np.min(a5w7s, axis=0)[0], np.max(a5w7s, axis=0)[0]])
        a7w10s = above_material[i][1]
        a5w10s = above_material[i][2]
        a10w12s = above_material[i][3]
        a12w15s = above_material[i][4]
        if len(a7w10s) == 0:
            region_a7w10s.append([0,0,0])
            region_a5w10s.append([0,0,0])
        else:
            region_a7w10s.append([np.mean(a7w10s, axis=0)[0], np.min(a7w10s, axis=0)[0], np.max(a7w10s, axis=0)[0]])
            region_a5w10s.append([np.mean(a5w10s, axis=0)[0], np.min(a5w10s, axis=0)[0], np.max(a5w10s, axis=0)[0]])
        if len(a10w12s) == 0:
            region_a10w12s.append([0,0,0])
        else:
            region_a10w12s.append([np.mean(a10w12s, axis=0)[0], np.min(a10w12s, axis=0)[0], np.max(a10w12s, axis=0)[0]])
        if len(a12w15s) == 0:
            region_a12w15s.append([0,0,0])
        else:
            if len(a12w15s) > 1:
                region_a12w15s.append([np.mean(a12w15s, axis=0)[0], np.min(a12w15s, axis=0)[0], np.max(a12w15s, axis=0)[0]])
            else:
                region_a12w15s.append([a12w15s[0][0], a12w15s[0][0], a12w15s[0][0]])
                print([a12w15s[0][0], a12w15s[0][0], a12w15s[0][0]])
                print(a12w15s[0])
ax=axes[1]


alabs = ['EM >5 MK (limit 7 MK)', 'EM >7 MK (limit 10 MK)', 'EM >10 MK (limit 12.6 MK)', 
        'EM >12.6 MK (limit 15.8 MK)']
ras = [region_a5w7s, region_a7w10s, region_a10w12s, region_a12w15s]
acolor = [okabe_ito[-2], '#0072B2', '#17BECF', okabe_ito[-1]]
for i in range(0, len(alabs)):
    xerrl = (np.array(ras[i])[:,0]- np.array(ras[i])[:,1])
    xerrh = (np.array(ras[i])[:,2]- np.array(ras[i])[:,0])
    xerr = [xerrl, xerrh]

    ax.errorbar(np.array(ras[i])[:,0], np.arange(len(abovelabs), 0, -1), 
                xerr=xerr,
               linestyle='', marker='o', linewidth=3, markersize=10, color=acolor[i], 
                label=alabs[i], alpha=1, zorder=0) 


# # xerrl = (np.array(region_a5w10s)[:,0]- np.array(region_a5w10s)[:,1])
# # xerrh = (np.array(region_a5w10s)[:,2]- np.array(region_a5w10s)[:,0])
# # xerr = [xerrl, xerrh]

# # ax.errorbar(np.array(region_a5w10s)[:,0], np.arange(len(abovelabs), 0, -1), 
# #             xerr=xerr,
# #            linestyle='', marker='o', linewidth=3, markersize=10, color='purple', 
# #             label='Above 5 MK (when limit 10 MK)', alpha=0.5, zorder=0) 

# xerrl = (np.array(region_a7w10s)[:,0]- np.array(region_a7w10s)[:,1])
# xerrh = (np.array(region_a7w10s)[:,2]- np.array(region_a7w10s)[:,0])
# xerr = [xerrl, xerrh]

# ax.errorbar(np.array(region_a7w10s)[:,0], np.arange(len(abovelabs), 0, -1), 
#             xerr=xerr,
#            linestyle='', marker='o', linewidth=3, markersize=10, color='green', 
#             label='Above 7 MK (when limit 10 MK)', alpha=1, zorder=0)  


# xerrl = (np.array(region_a10w12s)[:,0]- np.array(region_a10w12s)[:,1])
# xerrh = (np.array(region_a10w12s)[:,2]- np.array(region_a10w12s)[:,0])
# xerr = [xerrl, xerrh]

# ax.errorbar(np.array(region_a7w10s)[:,0], np.arange(len(abovelabs), 0, -1), 
#             xerr=xerr,
#            linestyle='', marker='o', linewidth=3, markersize=10, color='green', 
#             label='Above 7 MK (when limit 10 MK)', alpha=1, zorder=0)  


fntsz=17
ax.set_xscale('log')
ax.set_yticks(np.arange(len(abovelabs), 0, -1)) #[2:]
ax.set_yticklabels(labels=abovelabs, fontsize=15) #[2:]
#HARD CODED TO THE NUMBER OF GHOST RAY INTERVALS THAT HAVE >5MK CONSISTENCY INTERVALS (5):
for i in ghost_ticks[0:9]:
    indi = np.arange(len(abovelabs), 0, -1)[i]
    #print(i, indi)
    ax.get_yticklabels()[i].set_color('red')

plt.xticks(fontsize=20)
ax.set_xlabel('EM ['+(u.cm**(-5)).to_string('latex_inline')+']', fontsize=25)
ax.grid(axis = 'y', linestyle='dotted')
ax.legend(fontsize=fntsz)
#ax.set_ylim([-(len(regids)-len(abovelabs)),len(abovelabs)+1])
#ax.set_xlim([1e20,2e24])
#ax.set_title('Average and range of integrated EM', fontsize=15, fontweight='bold')
#for i in ghost_ticks:
#    ax.get_yticklabels()[i].set_color('red')
print('')


plt.savefig('new_consistency_ghostcorr_list4_newuncert.png', dpi=300)
# Out:
# /var/folders/55/06y21cm93w70z_8gl7yxv2t40000gq/T/ipykernel_37821/1214244831.py:56: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_yticklabels([0, 20, 40, 60, 80, 100], fontsize=15)
# [3.2352100956538944e+17, 3.2352100956538944e+17, 3.2352100956538944e+17]
# [3.23521010e+17 2.98829661e+15 2.00330892e+18]

# %% [markdown]
# Remaining code makes various other versions of these figures, not ultimately included in the paper.

# %%
#Consistency plot

import glob
import os
import visualize_dem_results as viz

time_weighted = True
seconds_per = 1

tickfont=15

with open('/Users/jmdunca2/do-dem/reference_files/samesames.pickle', 'rb') as f:
    data = pickle.load(f)

samesames = data['same region lists']
filelist = ana.get_same_region_file_lists(samesames, all_targets)

all_sumcons = []
for i in range(0, len(samesames)):
    key = samesames[i][0].split(' ')[0]
    sumcons_tw=[]
    for ff in filelist[i]:
        files = glob.glob(os.path.dirname(ff)+'/*'+key+'_MC_DEM_result.pickle')
        if len(samesames[i]) > 1:
            #print(samesames[i])
            key2 = samesames[i][1].split(' ')[0]
            files.extend(glob.glob(os.path.dirname(ff)+'/*'+key2+'_MC_DEM_result.pickle'))
                         
        files.sort()
        sumcon = 0.5
        for f in files:
            data, timestring, time = viz.load_DEM(f)
        
            sumcon += (1 if viz.checkresid(data) == 0 else 0)
        if time_weighted:
            dur = (time[1]-time[0]).to(u.s)
            time_mult = round(dur.value/seconds_per)
            sumcons_tw.extend([sumcon for i in range(0,time_mult)])
        if sumcon > 2.5:
            print(files[-1])
                

    all_sumcons.append(sumcons_tw)
    if not sumcons_tw:
        print('NO FILES FOR: ', samesames[i])



regids = [samesames[i] for i in order]
sumcons_order = [all_sumcons[i] for i in order]



fig, axes = plt.subplots(1, 1, figsize=(6,12), tight_layout = {'pad': 1})

yvs=[]
for i in range(0, len(regids)):
    sizes = np.histogram(sumcons_order[i], bins=[0.5,1.5,2.5,3.5, 4.5, 5.5, 6.5])[0]/10.
    yvs.append(i)
    axes.scatter(np.array([0.5,1.5,2.5,3.5, 4.5, 5.5])+0.5, np.zeros(6)+(i), s=sizes, zorder=3)
    axes.axhline(i, color='whitesmoke')


axes.set_xticks([1,2,3,4], ['5', '7', '10', '12.6'], fontsize=tickfont)
axes.set_xlabel('Upper Limit (MK)', fontsize=13)
axes.set_xlim([0.5,6.5])
    
axes.set_yticks(yvs)
axes.set_yticklabels(labels=plotlabs, fontsize=13)
axes.set_ylim([-1,35])
for i in ghost_ticks:
    axes.get_yticklabels()[i].set_color('red')

plt.savefig('consistency_bubbles_postghost_postshut_ghostcorr_cstat_newuncert.png', dpi=300)


# fig, axes = plt.subplots(len(regids[2:])+1, 1, figsize=(4,(len(regids[2:])+1)), sharex=True)

# for i in range(0, len(regids[2:])):
#     ax=axes[i]
#     ax.hist(sumcons_order[2:][i], bins=[0.5,1.5,2.5,3.5, 4.5, 5.5], edgecolor='black', color='palevioletred')
#     #ax.set_ylabel(ylabel)   
#     ax.set_xlim([0, 6.5])
#     ax.set_ylim([1, 1e5])
#     ax.set_yscale('log')
#     ax.text(3, 2e4, labs[2:][i], fontweight='bold')
#     #ax.set_xlabel('Upper Limit (MK)', fontsize=15)

# ax=axes[-1]
# ax.set_xticks([1,2,3,4], ['5', '7', '10', '12.6'], fontsize=tickfont)

# fig.subplots_adjust(hspace=0)
# Out:
# /Users/jmdunca2/do-dem/DEM_folders//initial_dem_7sep18//14-56-55_15-14-20/14-56-55_15-14-20_5.6_7.2_07-sep-18_MC_DEM_result.pickle
# /Users/jmdunca2/do-dem/DEM_folders//initial_dem_7sep18//18-27-45_18-36-30/18-27-45_18-36-30_5.6_7.2_07-sep-18_MC_DEM_result.pickle

# %%
#Make EM > 10 MK needed arrays etc – DURATION-WEIGHTED. 

with open('/Users/jmdunca2/do-dem/reference_files/samesames.pickle', 'rb') as f:
    data = pickle.load(f)

samesames = data['same region lists']
grf = data['ghost ray flags']
filelist = ana.get_same_region_file_lists(samesames, all_targets)


#Factor to adjust integrated EM values
area_i = 100**2
area_m = np.pi*150**2
#print(area_i, area_m)
factor = area_m/area_i
#factor=1


allgood=0
region_above10s=[]
region_totaltime=[]
region_totalvals=[]
times_per=[]
contigs=[]
all_times=[]
all_intervals=[]

region_int_above10s=[]

for i in range(0, len(filelist)):
    gf = filelist[i]

    vals = []
    above10s_ = []
    totaltime = 0
    times=[]
    durs=[]
    for f_ in gf:
        with open(f_, 'rb') as f:
            data = pickle.load(f)
        time = data['time_interval']
        dur = (time[1]-time[0]).to(u.s).value
        durs.append(dur)
        times.append(time)
        above10s = data['above_10MK']
        #print(f_)
        #print(above10s)
        above10s_.append(above10s[0])
        vals.append([dur*above10s[0]])
        totaltime+=dur

    contiguous, intervals, int_inds = ana.check_contig(times)
    print(samesames[i])
    print(contiguous)
    print(int_inds)
    print(intervals)
    #print(times)
    print('')
    if vals:
        region_int_above10s_=[]
        for ii in int_inds:
            indx = np.arange(ii[0],ii[1])
            int_vals = np.array(vals)[indx]
            int_a10s = np.array(above10s_)[indx]
            int_durs = np.array(durs)[indx]
            region_int_above10s_.append([np.sum(int_vals)/np.sum(int_durs)*factor, np.min(int_a10s)*factor, np.max(int_a10s)*factor])

        region_int_above10s.append(region_int_above10s_)
        
        region_above10s.append([np.sum(vals)/totaltime*factor, np.min(above10s_)*factor, np.max(above10s_)*factor])
        region_totaltime.append(totaltime)
        region_totalvals.append(len(vals))
        times_per.append([np.min(times), np.max(times)])
        all_times.append(times)
        all_intervals.append(intervals)
        contigs.append(contiguous)

    else:
        region_int_above10s.append([])
        region_above10s.append([0, 0, 0])
        region_totaltime.append(0)
        region_totalvals.append(0)
        times_per.append([])
        all_times.append([])
        all_intervals.append([])
        contigs.append(False)
    



outputs = [region_above10s, region_totaltime, region_totalvals, times_per, all_times, all_intervals, contigs]



order = np.argsort(np.array(region_above10s)[:,0])
regids = [samesames[i] for i in order]

plotlabs = ana.make_labels(regids, all_targets)
region_int_above10s_sort = [region_int_above10s[i] for i in order]


fig, ax = plt.subplots(1, 1, figsize=(28,28))

val=0
for rr in region_int_above10s_sort:
    regionabove10s=rr
    xerrl = (np.array(regionabove10s)[:,0]- np.array(regionabove10s)[:,1])
    xerrl[np.where(xerrl < 1e10)] = 0.0
    xerrh = (np.array(regionabove10s)[:,2] - np.array(regionabove10s)[:,0])
    xerrh[np.where(xerrh < 1e10)] = 0.0
    
    xerr = [xerrl, xerrh]

    vert=np.arange(0, (len(rr)))*0.1+val
    if len(vert) ==0:
        vert=np.array([val])
    ax.errorbar(np.array(regionabove10s)[:,0], vert, 
                xerr=xerr,
               linestyle='', marker='o', linewidth=3, alpha=0.5, markersize=10, color='indianred',zorder=0)
    ax.errorbar(np.array(regionabove10s)[:,0], vert, 
               linestyle='', marker='o', linewidth=3, markersize=10, color='indianred', zorder=1)#, label='New Regions', zorder=1)
    val+=3

ax.set_yticks(np.arange(0, val, 3)) #[2:]
ax.set_yticklabels(labels=plotlabs, fontsize=17)
ax.set_xscale('log')
ax.grid(axis = 'y', linestyle='dotted')
plt.xticks(fontsize=20)
ax.set_xlabel('Total EM >10 MK ('+(u.cm**(-5)).to_string('latex_inline')+')', fontsize=20)
ax.axvline(1.8e22, color='steelblue', zorder=0)
ax.axvline(1.5e23, color='steelblue', zorder=0)
ax.axvspan(1.8e22, 1.5e23, alpha=0.3, color='steelblue', label='Ishikawa+2017 95% Interval', zorder=0)

plt.savefig('before_cstat_check_all_contiguous_postcstat_newuncert.png', dpi=300)

# %%
#Make EM > 10 MK plot

with open('/Users/jmdunca2/do-dem/reference_files/samesames.pickle', 'rb') as f:
    data = pickle.load(f)

samesames = data['same region lists']
grf = data['ghost ray flags']
filelist = ana.get_same_region_file_lists(samesames, all_targets)


#Factor to adjust integrated EM values
area_i = 100**2
area_m = np.pi*150**2
#print(area_i, area_m)
factor = area_m/area_i
#factor=1


allgood=0
region_above10s=[]
region_totaltime=[]
region_10overpeak=[]
for i in range(0, len(filelist)):
    gf = filelist[i]

    vals = []
    vals2 = []
    durs = []
    above10s_ = []
    totaltime = 0
    for f_ in gf:
        with open(f_, 'rb') as f:
            data = pickle.load(f)
        time = data['time_interval']
        dur = (time[1]-time[0]).to(u.s).value
        above10s = data['above_10MK']
        peakEM = data['max']
        #print(f_)
        #print(above10s)
        above10s_.append(above10s[0])
        vals.append([dur*above10s[0]])
        vals2.append([dur*above10s[0]/peakEM])
        durs.append(dur) 
        totaltime+=dur

    #print(totaltime)
    if vals:
        region_above10s.append([np.sum(vals)/totaltime*factor, np.min(above10s_)*factor, np.max(above10s_)*factor])
        region_totaltime.append(totaltime)
        region_10overpeak.append([np.sum(vals2)/totaltime, np.min(vals2)/durs[np.where(vals2 == np.min(vals2))[0][0]], 
                                                              np.max(vals2)/durs[np.where(vals2 == np.max(vals2))[0][0]]])

    else:
        region_above10s.append([0, 0, 0])
        region_totaltime.append(0)
        region_10overpeak.append([0, 0, 0])


    

order = np.argsort(np.array(region_above10s)[:,0])
regids = [samesames[i] for i in order]
grf = [grf[i] for i in order]

ghost_ticks = np.where(grf)[0]

plotlabs = ana.make_labels(regids, all_targets)

#print('')
#print(len(labs))
#print(len(order))

region_time_hr = np.array((region_totaltime*u.s).to(u.hr))
#print(region_time_hr[order])


fig, ax = plt.subplots(1, 1, figsize=(24,10))


xerrl = (np.array(region_above10s)[:,0][order] - np.array(region_above10s)[:,1][order])
xerrl[np.where(xerrl < 1e10)] = 0.0
xerrh = (np.array(region_above10s)[:,2][order] - np.array(region_above10s)[:,0][order])
xerrh[np.where(xerrh < 1e10)] = 0.0

# xerr = [(np.array(region_above10s)[:,0][order] - np.array(region_above10s)[:,1][order]), 
#        (np.array(region_above10s)[:,2][order] - np.array(region_above10s)[:,0][order])]

xerr = [xerrl, xerrh]

ax.errorbar(np.array(region_above10s)[:,0][order], np.arange(0, len(filelist), 1), 
            xerr=xerr, linestyle='', marker='o', linewidth=3, markersize=10, color='indianred', label='New Regions', zorder=1)


xerrl = (np.array(region_above10s)[:,0][order]/factor - np.array(region_above10s)[:,1][order]/factor)
xerrl[np.where(xerrl < 1e10)] = 0.0
xerrh = (np.array(region_above10s)[:,2][order]/factor - np.array(region_above10s)[:,0][order]/factor)
xerrh[np.where(xerrh < 1e10)] = 0.0

# xerr = [(np.array(region_above10s)[:,0][order] - np.array(region_above10s)[:,1][order]), 
#        (np.array(region_above10s)[:,2][order] - np.array(region_above10s)[:,0][order])]

xerr2 = [xerrl, xerrh]



ax.errorbar(np.array(region_above10s)[:,0][order]/factor, np.arange(0, len(filelist), 1), 
            xerr=xerr2, linestyle='', marker='o', linewidth=3, markersize=10, color='indianred', 
            alpha=0.3, label='New Regions (no area factor)', zorder=1)





oneerr = np.zeros((2,1))

ginds = [27, 30, 29]
colors = ['darkgreen', 'purple', 'royalblue']
labels = ['Duncan+2024', 'Hannah+2016 "L3"', 'Hannah+2016 "L2"']
gc=0
for gind in ginds:
    oneerr[0] = xerr[0][gind]
    oneerr[1] = xerr[1][gind]

    ax.errorbar(np.array(region_above10s)[:,0][order][gind], np.arange(0, len(filelist), 1)[gind],
                xerr=oneerr,
                linestyle='', marker='o', color=colors[gc], linewidth=3, markersize=10, label=labels[gc], zorder=2) #, s=140)

    oneerr[0] = xerr2[0][gind]
    oneerr[1] = xerr2[1][gind]
    
    ax.errorbar(np.array(region_above10s)[:,0][order][gind]/factor, np.arange(0, len(filelist), 1)[gind],
                xerr=oneerr,
                linestyle='', marker='o', color=colors[gc], linewidth=3, markersize=10, alpha=0.3) #, label=labels[gc], zorder=2,
                #, s=140)

    gc+=1



fntsz=20
ax.set_xscale('log')
ax.axvline(1.8e22, color='steelblue', zorder=0)
ax.axvline(1.5e23, color='steelblue', zorder=0)
ax.axvspan(1.8e22, 1.5e23, alpha=0.3, color='steelblue', label='Ishikawa (2017) 95% Interval', zorder=0)
ax.set_yticks(np.arange(0, len(filelist))) #[2:]
ax.set_yticklabels(labels=plotlabs, fontsize=17) #[2:]
plt.xticks(fontsize=20)
ax.set_xlabel('Total EM >10 MK (cm^-5) ', fontsize=20)
ax.grid(axis = 'y', linestyle='dotted')
ax.legend(loc='lower right', fontsize=fntsz)
ax.set_ylim([-1,len(filelist)])
ax.set_xlim([8e16,2e24])
ax.set_title('Time-weighted average and range of EM integrated >10 MK', fontsize=25, fontweight='bold')
for i in ghost_ticks:
    ax.get_yticklabels()[i].set_color('red')
print('')

plt.savefig('per_region_above10_ghostcorr_cstat_newuncert.png', dpi=300)

# %%
#Make EM > 10 MK plot

with open('/Users/jmdunca2/do-dem/reference_files/samesames.pickle', 'rb') as f:
    data = pickle.load(f)

samesames = data['same region lists']
grf = data['ghost ray flags']
filelist = ana.get_same_region_file_lists(samesames, all_targets)


#Factor to adjust integrated EM values
area_i = 100**2
area_m = np.pi*150**2
#print(area_i, area_m)
factor = area_m/area_i
#factor=1


allgood=0
region_above10s=[]
region_totaltime=[]
region_10overpeak=[]
for i in range(0, len(filelist)):
    gf = filelist[i]

    vals = []
    vals2 = []
    durs = []
    above10s_ = []
    totaltime = 0
    for f_ in gf:
        with open(f_, 'rb') as f:
            data = pickle.load(f)
        time = data['time_interval']
        dur = (time[1]-time[0]).to(u.s).value
        above10s = data['above_10MK']
        peakEM = data['max']
        #print(f_)
        #print(above10s)
        above10s_.append(above10s[0])
        vals.append([dur*above10s[0]])
        vals2.append([dur*above10s[0]/peakEM])
        durs.append(dur) 
        totaltime+=dur

    #print(totaltime)
    if vals:
        region_above10s.append([np.sum(vals)/totaltime*factor, np.min(above10s_)*factor, np.max(above10s_)*factor])
        region_totaltime.append(totaltime)
        region_10overpeak.append([np.sum(vals2)/totaltime, np.min(vals2)/durs[np.where(vals2 == np.min(vals2))[0][0]], 
                                                              np.max(vals2)/durs[np.where(vals2 == np.max(vals2))[0][0]]])

    else:
        region_above10s.append([0, 0, 0])
        region_totaltime.append(0)
        region_10overpeak.append([0, 0, 0])


    

order = np.argsort(np.array(region_10overpeak)[:,0])
regids = [samesames[i] for i in order]
grf = [grf[i] for i in order]

ghost_ticks = np.where(grf)[0]

plotlabs = ana.make_labels(regids, all_targets)

#print('')
#print(len(labs))
#print(len(order))

region_time_hr = np.array((region_totaltime*u.s).to(u.hr))
#print(region_time_hr[order])


fig, ax = plt.subplots(1, 1, figsize=(7,10))


xerrl = (np.array(region_10overpeak)[:,0][order] - np.array(region_10overpeak)[:,1][order])
xerrl[np.where(xerrl < 1e10)] = 0.0
xerrh = (np.array(region_10overpeak)[:,2][order] - np.array(region_10overpeak)[:,0][order])
xerrh[np.where(xerrh < 1e10)] = 0.0

#xerr = [(np.array(region_above10s)[:,0][order] - np.array(region_above10s)[:,1][order]), 
#        (np.array(region_above10s)[:,2][order] - np.array(region_above10s)[:,0][order])]

xerr = [xerrl, xerrh]

ax.errorbar(np.array(region_10overpeak)[:,0][order], np.arange(0, len(filelist), 1), 
            xerr=xerr, linestyle='', marker='o', linewidth=3, markersize=10, color='indianred', label='New Regions', zorder=1)



oneerr = np.zeros((2,1))

ginds = [24, 29, 28]
colors = ['darkgreen', 'purple', 'royalblue']
labels = ['Duncan+2024', 'Hannah+2016 "L3"', 'Hannah+2016 "L2"']
gc=0
for gind in ginds:
    oneerr[0] = xerr[0][gind]
    oneerr[1] = xerr[1][gind]

    ax.errorbar(np.array(region_10overpeak)[:,0][order][gind], np.arange(0, len(filelist), 1)[gind],
                xerr=oneerr,
                linestyle='', marker='o', color=colors[gc], linewidth=3, markersize=10, label=labels[gc], zorder=2) #, s=140)

    gc+=1



fntsz=20
ax.set_xscale('log')
# ax.axvline(1.8e22, color='steelblue', zorder=0)
# ax.axvline(1.5e23, color='steelblue', zorder=0)
# ax.axvspan(1.8e22, 1.5e23, alpha=0.3, color='steelblue', label='Ishikawa (2017) 95% Interval', zorder=0)
ax.set_yticks(np.arange(0, len(filelist))) #[2:]
ax.set_yticklabels(labels=plotlabs, fontsize=17) #[2:]
plt.xticks(fontsize=20)
ax.set_xlabel('Ratio ', fontsize=20)
ax.grid(axis = 'y', linestyle='dotted')
ax.legend(loc='lower right', fontsize=fntsz)
ax.set_ylim([-1,len(filelist)])
#ax.set_xlim([4e17,2e24])
ax.set_title('EM >10 MK / Peak EM', fontsize=30, fontweight='bold')
for i in ghost_ticks:
    ax.get_yticklabels()[i].set_color('red')
print('')

plt.savefig('per_region_above10EM_over_peakEM_ghostcorr_cstat.png', dpi=300)

# %% [markdown]
# Rather than plotting the full range of the values for a given region, or the full range of the values for a given contiguous interval, what about plotting all of the values with their uncertainties?

# %%
#Make EM > 10 MK needed arrays etc

plot_all_intervals=False
plot_peak_ratio=False
plot_all_contig=True

labelfontsize=25

with open('/Users/jmdunca2/do-dem/reference_files/samesames.pickle', 'rb') as f:
    data = pickle.load(f)


samesames = data['same region lists']
grf = data['ghost ray flags']
#Lists per region
filelist = ana.get_same_region_file_lists(samesames, all_targets)

filelist = [filelist[i] for i in order]
samesames = [samesames[i] for i in order]
grf = [grf[i] for i in order]

#Factor to adjust integrated EM values
area_i = 100**2
area_m = np.pi*150**2
#print(area_i, area_m)
factor = area_m/area_i
#factor=1


# allgood=0
# region_above10s=[]
# region_totaltime=[]
# region_totalvals=[]
# times_per=[]
# contigs=[]
# all_times=[]
# all_intervals=[]

# region_int_above10s=[]

fig, ax = plt.subplots(1, 1, figsize=(28,30), tight_layout={'pad': 1})

ylabelvals = []
val=0
for i in range(0, len(filelist)):
    gf = filelist[i]

    #VERSION WHERE WE PLOT ALL FILES AT RANDOM FOR THE REGION
    #==============================================================
    # regnum=0
    # for f_ in gf:
    #     with open(f_, 'rb') as f:
    #         data = pickle.load(f)

    #     vert=val
    #     xerrl = (np.array([data['above_10MK'][0]- data['above_10MK'][1]]))
    #     #xerrl[np.where(xerrl < 1e10)] = 0.0
    #     xerrh = (np.array([data['above_10MK'][2] - data['above_10MK'][0]]))
    #     #xerrh[np.where(xerrh < 1e10)] = 0.0
        
    #     xerr = [xerrl, xerrh]

    #     ax.errorbar(data['above_10MK'][0], vert, xerr=xerr,
    #             linestyle='', marker='o', linewidth=3, markersize=10, color='indianred', zorder=1)
    #     ax.errorbar(data['above_10MK'][0], vert,
    #             linestyle='', marker='o', linewidth=3, markersize=10, color='black', zorder=2)#, label='New Regions', zorder=1)
    #     val+=1
    #     regnum+=1

    # ylabelvals.append(val-round(regnum/2.)+1.)
    # ax.axhline(val+4, 
    #             linestyle='dotted', color='black')#, label='New Regions', zorder=1)
    # val+=10
    #==============================================================

    regnum=0
    times=[]
    above10s=[]
    peakEMs=[]
    for f_ in gf:
        with open(f_, 'rb') as f:
            data = pickle.load(f)
        times.append(data['time_interval'])
        above10s.append([factor*d for d in data['above_10MK']])
        peakEMs.append(data['max'])

    contiguous, intervals, int_inds = ana.check_contig(times)
    if times:
        flipper=1
        if plot_all_intervals:
            colors=['hi', 'forestgreen', 'teal']
            for ii in int_inds:
                indx = np.arange(ii[0],ii[1])
                int_a10s = np.array(above10s)[indx]
                if plot_peak_ratio:
                    peaks=np.array(peakEMs)[indx]
                    int_a10s = [int_a10s[p]/peaks[p] for p in range(0, len(peaks))]
                for ia10 in int_a10s:
    
                    vert=val
                    xerrl = (np.array([ia10[0]- ia10[1]]))
                    #xerrl[np.where(xerrl < 1e10)] = 0.0
                    xerrh = (np.array([ia10[2] - ia10[0]]))
                    #xerrh[np.where(xerrh < 1e10)] = 0.0
                    
                    xerr = [xerrl, xerrh]                
                    ax.errorbar(ia10[0], vert, xerr=xerr, linestyle='', marker='o', linewidth=3, markersize=10, 
                                color=colors[flipper], zorder=1)
                    ax.errorbar(ia10[0], vert, linestyle='', marker='o', linewidth=3, markersize=10, color='black', zorder=2)
                    val+=1
                    regnum+=1
                flipper*=-1
                    
                val+=5
                
        elif plot_all_contig:
            colors=['hi', 'mediumseagreen', 'darkgreen']
            for ii in int_inds:
                indx = np.arange(ii[0],ii[1])
                int_a10s = np.array(above10s)[indx]
                if plot_peak_ratio:
                    peaks=np.array(peakEMs)[indx]
                    int_a10s = np.array([int_a10s[p]/peaks[p] for p in range(0, len(peaks))])
                    
                #Taking the mean and conducting error propogation
                la10s = np.log10(int_a10s[:,0])
                lmean = np.mean(la10s)
                ddif = la10s - np.log10(int_a10s[:,1])
                #ddif = la10s-ldowns
                edwn = 10**(lmean-np.sum([dd**2 for dd in ddif])**(1/2)/len(ddif))
                udif = np.log10(int_a10s[:,2])-la10s
                eup = 10**(np.sum([dd**2 for dd in udif])**(1/2)/len(udif) + lmean)
                input_val = 10**(lmean)

                vert=val
                xerrl = (np.array([input_val - edwn]))
                #xerrl[np.where(xerrl < 1e10)] = 0.0
                xerrh = (np.array([eup - input_val]))
                #xerrh[np.where(xerrh < 1e10)] = 0.0

                xerr_og = [xerrl/factor, xerrh/factor]
                
                xerr = [xerrl, xerrh]
                ax.errorbar(input_val, vert, xerr=xerr, linestyle='', marker='o', linewidth=4, markersize=10, color=colors[flipper], zorder=1)
                ax.errorbar(input_val/factor, vert, xerr=xerr_og, linestyle='', marker='o', linewidth=4, markersize=10, alpha=0.3, 
                            color=colors[flipper], zorder=1)
                ax.errorbar(input_val, vert, linestyle='', marker='o', linewidth=4, markersize=10, color='black', zorder=2)
                ax.errorbar(input_val/factor, vert, linestyle='', marker='o', linewidth=4, markersize=10, alpha=0.3, 
                            color='black', zorder=2)
                val+=4
                regnum+=1
                flipper*=-1
                    
        
        ylabelvals.append(val-round(regnum/2.)+1.)
        ax.axhline(val+6, linestyle='dotted', color='black')#, label='New Regions', zorder=1)
        val+=10

box_properties = dict(boxstyle='round', facecolor='green', alpha=0.5, edgecolor='black')
for i in range(0, len(plotlabs)):
    #print(plotlabs[i])
    if plotlabs[i] == '1-nov-14 AR12192':
        color='grey'
        box_properties = dict(boxstyle='round', facecolor=color, edgecolor='black')
        ax.text(5e14, ylabelvals[i]+3, 'Hannah+2016 L2', fontsize=labelfontsize-2, style='italic', bbox=box_properties)
        ax.axhspan(ylabelvals[i]-9, ylabelvals[i]+4, color=color, alpha=0.25)
        
    if plotlabs[i] == '1-nov-14 AR12194':
        color='goldenrod'
        box_properties = dict(boxstyle='round', facecolor=color, edgecolor='black')
        ax.text(5e14, ylabelvals[i], 'Hannah+2016 L3', fontsize=labelfontsize-2, style='italic', bbox=box_properties)
        ax.axhspan(ylabelvals[i]-9, ylabelvals[i]+4, color=color, alpha=0.25)
        
    if plotlabs[i] == '29-may-18 AR12712':
        color='pink'
        box_properties = dict(boxstyle='round', facecolor=color, edgecolor='black')
        ax.text(5e14, ylabelvals[i], 'Duncan+2024', fontsize=labelfontsize-2, style='italic', bbox=box_properties)
        ax.axhspan(ylabelvals[i]-32, ylabelvals[i]+8, color=color, alpha=0.25)
        


ax.set_yticks(ylabelvals)#[2:]
ax.set_yticklabels(labels=plotlabs, fontsize=labelfontsize)
ax.set_xscale('log')
plt.xticks(fontsize=labelfontsize)
if not plot_peak_ratio:
    ax.set_xlabel('(Area Factor) x Total EM >10 MK ['+(u.cm**(-5)).to_string('latex_inline')+']', fontsize=labelfontsize)
    ax.axvline(1.8e22, color='steelblue', zorder=0)
    ax.axvline(1.5e23, color='steelblue', zorder=0)
    ax.axvspan(1.8e22, 1.5e23, alpha=0.3, color='steelblue', label='Ishikawa+2017 95% Interval', zorder=0)
ghost_ticks = np.where(grf)[0]
for i in ghost_ticks:
    ax.get_yticklabels()[i].set_color('red')
print('')

ax.set_ylim([-10,val])
ax.set_xlim([3e14,2e23])
ax.legend(loc='lower right', fontsize=labelfontsize+5)

if plot_all_intervals:
    if plot_peak_ratio:
        plt.savefig('all_values_above10_all_peak_rat.png', dpi=300)
    else:
        plt.savefig('all_values_above10_all.png', dpi=300)

if plot_all_contig:
    if plot_peak_ratio:
        plt.savefig('all_values_above10_contig_peak_rat.png', dpi=300)
    else:
        plt.savefig('all_values_above10_contig.png', dpi=300)

# %%
2e27*

# %%
order = np.argsort(np.array(region_above10s)[:,0])
regids = [samesames[i] for i in order]
grf = [grf[i] for i in order]

ghost_ticks = np.where(grf)[0]

plotlabs = ana.make_labels(regids)

#print('')
#print(len(labs))
#print(len(order))

region_time_hr = np.array((region_totaltime*u.s).to(u.hr))
#print(region_time_hr[order])


fig, ax = plt.subplots(1, 1, figsize=(28,10))


xerrl = (np.array(region_above10s)[:,0][order]/factor - np.array(region_above10s)[:,1][order]/factor)
xerrl[np.where(xerrl < 1e10)] = 0.0
xerrh = (np.array(region_above10s)[:,2][order]/factor - np.array(region_above10s)[:,0][order]/factor)
xerrh[np.where(xerrh < 1e10)] = 0.0

#xerr = [(np.array(region_above10s)[:,0][order] - np.array(region_above10s)[:,1][order]), 
#        (np.array(region_above10s)[:,2][order] - np.array(region_above10s)[:,0][order])]

xerr_nf = [xerrl, xerrh]

ax.errorbar(np.array(region_above10s)[:,0][order]/factor, np.arange(0, len(filelist), 1), 
            xerr=xerr_nf,
           linestyle='', marker='o', linewidth=3, markersize=10, color='indianred', 
            label='New Regions (no area factor)', alpha=0.3, zorder=0)

xerrl = (np.array(region_above10s)[:,0][order] - np.array(region_above10s)[:,1][order])
xerrl[np.where(xerrl < 1e10)] = 0.0
xerrh = (np.array(region_above10s)[:,2][order] - np.array(region_above10s)[:,0][order])
xerrh[np.where(xerrh < 1e10)] = 0.0

#xerr = [(np.array(region_above10s)[:,0][order] - np.array(region_above10s)[:,1][order]), 
#        (np.array(region_above10s)[:,2][order] - np.array(region_above10s)[:,0][order])]

xerr = [xerrl, xerrh]

ax.errorbar(np.array(region_above10s)[:,0][order], np.arange(0, len(filelist), 1), 
            xerr=xerr,
           linestyle='', marker='o', linewidth=3, markersize=10, color='indianred', label='New Regions', zorder=1)



oneerr = np.zeros((2,1))

ginds = [27, 28, 21]
colors = ['darkgreen', 'purple', 'royalblue']
labels = ['Duncan+2024', 'Hannah+2016 "L3"', 'Hannah+2016 "L2"']
gc=0
for gind in ginds:
    oneerr[0] = xerr[0][gind]
    oneerr[1] = xerr[1][gind]
    
    print(oneerr)
    
    ax.errorbar(np.array(region_above10s)[:,0][order][gind]/factor, np.arange(0, len(filelist), 1)[gind],
                xerr=oneerr/factor,
                linestyle='', marker='o', color=colors[gc], linewidth=3, markersize=10, alpha=0.3, zorder=2) #, s=140)
    
    
    ax.errorbar(np.array(region_above10s)[:,0][order][gind], np.arange(0, len(filelist), 1)[gind],
                xerr=oneerr,
                linestyle='', marker='o', color=colors[gc], linewidth=3, markersize=10, label=labels[gc], zorder=2) #, s=140)

    gc+=1



fntsz=25
ax.set_xscale('log')
ax.axvline(1.8e22, color='steelblue', zorder=0)
ax.axvline(1.5e23, color='steelblue', zorder=0)
ax.axvspan(1.8e22, 1.5e23, alpha=0.3, color='steelblue', label='Ishikawa+2017 95% Interval', zorder=0)
ax.set_yticks(np.arange(0, len(filelist))) #[2:]
ax.set_yticklabels(labels=plotlabs, fontsize=17) #[2:]
plt.xticks(fontsize=20)
ax.set_xlabel('Total EM >10 MK ('+(u.cm**(-5)).to_string('latex_inline')+')', fontsize=20)
ax.grid(axis = 'y', linestyle='dotted')
ax.legend(loc='lower right', fontsize=fntsz)
ax.set_ylim([-1,len(filelist)])
#ax.set_xlim([4e17,2e24])
ax.set_title('Time-weighted average and range of EM integrated >10 MK', fontsize=30, fontweight='bold')
for i in ghost_ticks:
    ax.get_yticklabels()[i].set_color('red')
print('')

plt.savefig('per_region_above10_new_postghost_postshut_ghostcorr.png', dpi=300)





def plot_range_v_dur(comp_cases, region_above10s, region_totalvals):

    ranges = np.array(region_above10s)[:,2] - np.array(region_above10s)[:,1]
    int_number = np.array(region_totalvals)
    normranges = ranges/np.array(region_above10s)[:,0]
    
    fig, ax = plt.subplots(1, 1, figsize=(5,5))
    ranges=ranges[comp_cases]
    normranges=normranges[comp_cases]
    int_number=int_number[comp_cases]
    plotlabs = ana.make_labels(samesames)
    sss=np.array(plotlabs)[comp_cases]
    
    TOT_DUR = [(time[1]-time[0]).to(u.min).value for time in times_per]*u.min
    
    TOT_DUR = TOT_DUR[comp_cases]
    
    ax.scatter(normranges, TOT_DUR)
    for i, label in enumerate(sss):
        plt.text(normranges[i] + 0.1, TOT_DUR[i] + 0.1*u.min, label, fontsize=12)
    #ax.set_yscale('log')
    #ax.set_xscale('log')   
    ax.set_title('Entire quiescent observation start-end duration vs. value-normalized range')

ctg_cases = np.where(contigs)[0]
print(ctg_cases)

int_number = np.array(region_totalvals)
comp_cases = np.where(int_number > 1)[0]
print(comp_cases)

both = np.where(np.logical_and(int_number > 1, contigs))[0]
plot_range_v_dur(both, region_above10s, region_totalvals)

nonconts = np.where(np.array(contigs) == False)[0]
print(nonconts)
plot_range_v_dur(nonconts, region_above10s, region_totalvals)

# %% [markdown]
# Below process: removing March 18 2023 region 1 from targets dictionary and saving it elsewhere, as ghost ray correction failed for that region and we are not incluidng it due to high level of potential contamination.

# %%
# with open('/Users/jmdunca2/do-dem/reference_files/all_targets_postghost_postshut.pickle', 'rb') as f:
#     all_targets = pickle.load(f)


# all_targets['18-mar-23_1']

# march23file = '/Users/jmdunca2/do-dem/reference_files/save_18_mar_23_1.pickle'
# with open(march23file, 'wb') as f:
#         # Pickle the 'data' dictionary using the highest protocol available.
#         pickle.dump(all_targets['18-mar-23_1'], f, pickle.HIGHEST_PROTOCOL)

# %%
# with open(march23file, 'rb') as f:
#     march23_target = pickle.load(f)

# march23_target
# Out:
# {'NOAA_ARID': ['AR13247', 'AR13250', 'AR13254'],
#  'HARP': [],
#  'datapaths': ['/Users/jmdunca2/nustar/mar-2023/20801021001/',
#   '/Users/jmdunca2/nustar/mar-2023/20801022001/',
#   '/Users/jmdunca2/nustar/mar-2023/20801023001/',
#   '/Users/jmdunca2/nustar/mar-2023/20801024001/',
#   '/Users/jmdunca2/nustar/mar-2023/20801026001/',
#   '/Users/jmdunca2/nustar/mar-2023/20801027001/'],
#  'obsids': ['20801021001',
#   '20801022001',
#   '20801023001',
#   '20801024001',
#   '20801026001',
#   '20801027001'],
#  'working_dir': '/Users/jmdunca2/do-dem/DEM_folders//initial_dem_18mar23_1/',
#  'loc': ['limb'],
#  'hale_class': [''],
#  'method': 'fit',
#  'notes': '',
#  'goes_satellite': 16,
#  'orbit durations': [<Quantity 59.38333333 min>,
#   <Quantity 59.38333333 min>,
#   <Quantity 59.38333333 min>,
#   <Quantity 59.38333333 min>,
#   <Quantity 41.62916667 min>,
#   <Quantity 58.11666667 min>],
#  'total duration': <Quantity 337.27916667 min>,
#  'total livetime': <Quantity 1.37283489 min>,
#  'gauss_stats': [([], 3), ([], 3), ([], 4), ([], 4), ([], 5), ([], 5)],
#  'directories': ['/Users/jmdunca2/do-dem/DEM_folders//initial_dem_18mar23_1/'],
#  'Ghost_Ray_Rate_B': array([2986.04106857, 1149.15868468,   61.76715301]),
#  'Ghost_Ray_Rate_A': array([2711.19937425, 1150.65189093,   60.37615014]),
#  'per_region_all_time_intervals': [[[<Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 13, 30, 40)
#      datetime.datetime(2023, 3, 18, 13, 31, 25)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 13, 31, 25)
#      datetime.datetime(2023, 3, 18, 13, 31, 55)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 13, 31, 55)
#      datetime.datetime(2023, 3, 18, 13, 32, 40)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 13, 32, 40)
#      datetime.datetime(2023, 3, 18, 13, 33, 55)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 13, 33, 55)
#      datetime.datetime(2023, 3, 18, 13, 34, 25)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 13, 34, 25)
#      datetime.datetime(2023, 3, 18, 13, 34, 55)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 13, 34, 55)
#      datetime.datetime(2023, 3, 18, 13, 35, 25)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 13, 35, 25)
#      datetime.datetime(2023, 3, 18, 13, 36, 40)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 13, 36, 40)
#      datetime.datetime(2023, 3, 18, 13, 37, 55)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 13, 37, 55)
#      datetime.datetime(2023, 3, 18, 13, 38, 25)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 13, 38, 25)
#      datetime.datetime(2023, 3, 18, 13, 43, 40)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 13, 43, 40)
#      datetime.datetime(2023, 3, 18, 13, 48, 45)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 13, 48, 45)
#      datetime.datetime(2023, 3, 18, 13, 53, 35)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 13, 53, 35)
#      datetime.datetime(2023, 3, 18, 13, 55, 5)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 13, 55, 5)
#      datetime.datetime(2023, 3, 18, 13, 55, 55)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 13, 55, 55)
#      datetime.datetime(2023, 3, 18, 13, 56, 25)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 13, 56, 25)
#      datetime.datetime(2023, 3, 18, 13, 57, 10)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 13, 57, 10)
#      datetime.datetime(2023, 3, 18, 13, 58, 15)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 13, 58, 15)
#      datetime.datetime(2023, 3, 18, 13, 58, 45)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 13, 58, 45)
#      datetime.datetime(2023, 3, 18, 13, 59, 40)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 13, 59, 40)
#      datetime.datetime(2023, 3, 18, 14, 2, 30)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 14, 2, 30)
#      datetime.datetime(2023, 3, 18, 14, 6, 10)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 14, 6, 10)
#      datetime.datetime(2023, 3, 18, 14, 8, 15)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 14, 8, 15)
#      datetime.datetime(2023, 3, 18, 14, 9, 20)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 14, 9, 20)
#      datetime.datetime(2023, 3, 18, 14, 11, 10)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 14, 11, 10)
#      datetime.datetime(2023, 3, 18, 14, 12, 30)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 14, 12, 30)
#      datetime.datetime(2023, 3, 18, 14, 16)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 14, 16)
#      datetime.datetime(2023, 3, 18, 14, 17, 40)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 14, 17, 40)
#      datetime.datetime(2023, 3, 18, 14, 19, 50)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 14, 19, 50)
#      datetime.datetime(2023, 3, 18, 14, 20, 40)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 14, 20, 40)
#      datetime.datetime(2023, 3, 18, 14, 21, 25)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 14, 21, 25)
#      datetime.datetime(2023, 3, 18, 14, 22, 15)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 14, 22, 15)
#      datetime.datetime(2023, 3, 18, 14, 22, 45)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 14, 22, 45)
#      datetime.datetime(2023, 3, 18, 14, 23, 20)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 14, 23, 20)
#      datetime.datetime(2023, 3, 18, 14, 23, 50)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 14, 23, 50)
#      datetime.datetime(2023, 3, 18, 14, 24, 20)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 14, 24, 20)
#      datetime.datetime(2023, 3, 18, 14, 24, 50)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 14, 24, 50)
#      datetime.datetime(2023, 3, 18, 14, 29, 55)]>],
#    [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 15, 7, 5)
#      datetime.datetime(2023, 3, 18, 15, 8, 5)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 15, 8, 5)
#      datetime.datetime(2023, 3, 18, 15, 9, 45)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 15, 9, 45)
#      datetime.datetime(2023, 3, 18, 15, 11, 25)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 15, 11, 25)
#      datetime.datetime(2023, 3, 18, 15, 12, 55)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 15, 12, 55)
#      datetime.datetime(2023, 3, 18, 15, 14)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 15, 14)
#      datetime.datetime(2023, 3, 18, 15, 16, 25)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 15, 16, 25)
#      datetime.datetime(2023, 3, 18, 15, 18, 20)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 15, 18, 20)
#      datetime.datetime(2023, 3, 18, 15, 20, 10)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 15, 20, 10)
#      datetime.datetime(2023, 3, 18, 15, 22, 10)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 15, 22, 10)
#      datetime.datetime(2023, 3, 18, 15, 23, 10)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 15, 23, 10)
#      datetime.datetime(2023, 3, 18, 15, 25, 10)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 15, 25, 10)
#      datetime.datetime(2023, 3, 18, 15, 29, 10)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 15, 29, 10)
#      datetime.datetime(2023, 3, 18, 15, 30, 50)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 15, 30, 50)
#      datetime.datetime(2023, 3, 18, 15, 33, 15)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 15, 33, 15)
#      datetime.datetime(2023, 3, 18, 15, 44)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 15, 44)
#      datetime.datetime(2023, 3, 18, 15, 46, 25)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 15, 46, 25)
#      datetime.datetime(2023, 3, 18, 15, 48, 50)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 15, 48, 50)
#      datetime.datetime(2023, 3, 18, 15, 50, 10)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 15, 50, 10)
#      datetime.datetime(2023, 3, 18, 15, 53, 15)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 15, 53, 15)
#      datetime.datetime(2023, 3, 18, 15, 56, 5)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 15, 56, 5)
#      datetime.datetime(2023, 3, 18, 15, 59, 5)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 15, 59, 5)
#      datetime.datetime(2023, 3, 18, 15, 59, 45)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 15, 59, 45)
#      datetime.datetime(2023, 3, 18, 16, 0, 15)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 16, 0, 15)
#      datetime.datetime(2023, 3, 18, 16, 0, 45)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 16, 0, 45)
#      datetime.datetime(2023, 3, 18, 16, 1, 15)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 16, 1, 15)
#      datetime.datetime(2023, 3, 18, 16, 1, 45)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 16, 1, 45)
#      datetime.datetime(2023, 3, 18, 16, 2, 15)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 16, 2, 15)
#      datetime.datetime(2023, 3, 18, 16, 2, 45)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 16, 2, 45)
#      datetime.datetime(2023, 3, 18, 16, 6, 25)]>],
#    [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 16, 43, 35)
#      datetime.datetime(2023, 3, 18, 16, 46, 25)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 16, 46, 25)
#      datetime.datetime(2023, 3, 18, 16, 50, 50)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 16, 50, 50)
#      datetime.datetime(2023, 3, 18, 16, 55, 45)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 16, 55, 45)
#      datetime.datetime(2023, 3, 18, 16, 59)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 16, 59)
#      datetime.datetime(2023, 3, 18, 17, 1, 35)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 17, 1, 35)
#      datetime.datetime(2023, 3, 18, 17, 2, 50)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 17, 2, 50)
#      datetime.datetime(2023, 3, 18, 17, 5, 5)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 17, 5, 5)
#      datetime.datetime(2023, 3, 18, 17, 9, 15)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 17, 9, 15)
#      datetime.datetime(2023, 3, 18, 17, 42, 50)]>],
#    [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 18, 20)
#      datetime.datetime(2023, 3, 18, 18, 22, 50)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 18, 22, 50)
#      datetime.datetime(2023, 3, 18, 18, 23, 55)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 18, 23, 55)
#      datetime.datetime(2023, 3, 18, 18, 25)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 18, 25)
#      datetime.datetime(2023, 3, 18, 18, 25, 50)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 18, 25, 50)
#      datetime.datetime(2023, 3, 18, 18, 26, 45)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 18, 26, 45)
#      datetime.datetime(2023, 3, 18, 18, 27, 15)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 18, 27, 15)
#      datetime.datetime(2023, 3, 18, 18, 27, 45)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 18, 27, 45)
#      datetime.datetime(2023, 3, 18, 18, 28, 15)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 18, 28, 15)
#      datetime.datetime(2023, 3, 18, 18, 28, 45)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 18, 28, 45)
#      datetime.datetime(2023, 3, 18, 18, 29, 15)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 18, 29, 15)
#      datetime.datetime(2023, 3, 18, 18, 29, 45)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 18, 29, 45)
#      datetime.datetime(2023, 3, 18, 18, 30, 15)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 18, 30, 15)
#      datetime.datetime(2023, 3, 18, 18, 30, 45)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 18, 30, 45)
#      datetime.datetime(2023, 3, 18, 18, 31, 15)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 18, 31, 15)
#      datetime.datetime(2023, 3, 18, 18, 31, 45)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 18, 31, 45)
#      datetime.datetime(2023, 3, 18, 18, 32, 15)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 18, 32, 15)
#      datetime.datetime(2023, 3, 18, 18, 32, 45)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 18, 32, 45)
#      datetime.datetime(2023, 3, 18, 18, 33, 15)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 18, 33, 15)
#      datetime.datetime(2023, 3, 18, 18, 33, 45)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 18, 33, 45)
#      datetime.datetime(2023, 3, 18, 18, 34, 15)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 18, 34, 15)
#      datetime.datetime(2023, 3, 18, 18, 34, 45)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 18, 34, 45)
#      datetime.datetime(2023, 3, 18, 18, 35, 15)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 18, 35, 15)
#      datetime.datetime(2023, 3, 18, 18, 35, 45)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 18, 35, 45)
#      datetime.datetime(2023, 3, 18, 18, 36, 15)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 18, 36, 15)
#      datetime.datetime(2023, 3, 18, 18, 36, 45)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 18, 36, 45)
#      datetime.datetime(2023, 3, 18, 18, 37, 15)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 18, 37, 15)
#      datetime.datetime(2023, 3, 18, 18, 37, 45)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 18, 37, 45)
#      datetime.datetime(2023, 3, 18, 18, 38, 15)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 18, 38, 15)
#      datetime.datetime(2023, 3, 18, 18, 38, 45)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 18, 38, 45)
#      datetime.datetime(2023, 3, 18, 18, 39, 15)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 18, 39, 15)
#      datetime.datetime(2023, 3, 18, 18, 39, 45)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 18, 39, 45)
#      datetime.datetime(2023, 3, 18, 18, 40, 15)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 18, 40, 15)
#      datetime.datetime(2023, 3, 18, 18, 40, 45)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 18, 40, 45)
#      datetime.datetime(2023, 3, 18, 18, 41, 15)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 18, 41, 15)
#      datetime.datetime(2023, 3, 18, 18, 41, 45)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 18, 41, 45)
#      datetime.datetime(2023, 3, 18, 18, 42, 15)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 18, 42, 15)
#      datetime.datetime(2023, 3, 18, 18, 42, 45)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 18, 42, 45)
#      datetime.datetime(2023, 3, 18, 18, 43, 15)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 18, 43, 15)
#      datetime.datetime(2023, 3, 18, 18, 43, 45)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 18, 43, 45)
#      datetime.datetime(2023, 3, 18, 18, 44, 15)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 18, 44, 15)
#      datetime.datetime(2023, 3, 18, 18, 44, 45)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 18, 44, 45)
#      datetime.datetime(2023, 3, 18, 18, 45, 25)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 18, 45, 25)
#      datetime.datetime(2023, 3, 18, 18, 45, 55)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 18, 45, 55)
#      datetime.datetime(2023, 3, 18, 18, 46, 30)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 18, 46, 30)
#      datetime.datetime(2023, 3, 18, 18, 47)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 18, 47)
#      datetime.datetime(2023, 3, 18, 18, 47, 50)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 18, 47, 50)
#      datetime.datetime(2023, 3, 18, 18, 48, 20)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 18, 48, 20)
#      datetime.datetime(2023, 3, 18, 18, 49, 5)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 18, 49, 5)
#      datetime.datetime(2023, 3, 18, 18, 49, 45)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 18, 49, 45)
#      datetime.datetime(2023, 3, 18, 18, 50, 45)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 18, 50, 45)
#      datetime.datetime(2023, 3, 18, 18, 51, 40)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 18, 51, 40)
#      datetime.datetime(2023, 3, 18, 18, 52, 15)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 18, 52, 15)
#      datetime.datetime(2023, 3, 18, 18, 53, 25)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 18, 53, 25)
#      datetime.datetime(2023, 3, 18, 18, 54, 25)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 18, 54, 25)
#      datetime.datetime(2023, 3, 18, 18, 55, 25)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 18, 55, 25)
#      datetime.datetime(2023, 3, 18, 18, 57, 25)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 18, 57, 25)
#      datetime.datetime(2023, 3, 18, 19, 11)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 19, 11)
#      datetime.datetime(2023, 3, 18, 19, 11, 30)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 19, 11, 30)
#      datetime.datetime(2023, 3, 18, 19, 12)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 19, 12)
#      datetime.datetime(2023, 3, 18, 19, 12, 30)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 19, 12, 30)
#      datetime.datetime(2023, 3, 18, 19, 13)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 19, 13)
#      datetime.datetime(2023, 3, 18, 19, 13, 30)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 19, 13, 30)
#      datetime.datetime(2023, 3, 18, 19, 14)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 19, 14)
#      datetime.datetime(2023, 3, 18, 19, 14, 30)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 19, 14, 30)
#      datetime.datetime(2023, 3, 18, 19, 15)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 19, 15)
#      datetime.datetime(2023, 3, 18, 19, 15, 30)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 19, 15, 30)
#      datetime.datetime(2023, 3, 18, 19, 16)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 19, 16)
#      datetime.datetime(2023, 3, 18, 19, 16, 30)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 19, 16, 30)
#      datetime.datetime(2023, 3, 18, 19, 17)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 19, 17)
#      datetime.datetime(2023, 3, 18, 19, 17, 30)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 19, 17, 30)
#      datetime.datetime(2023, 3, 18, 19, 18)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 19, 18)
#      datetime.datetime(2023, 3, 18, 19, 18, 30)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 19, 18, 30)
#      datetime.datetime(2023, 3, 18, 19, 19, 20)]>],
#    [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 21, 41, 50)
#      datetime.datetime(2023, 3, 18, 21, 43, 45)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 21, 43, 45)
#      datetime.datetime(2023, 3, 18, 21, 44, 20)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 21, 44, 20)
#      datetime.datetime(2023, 3, 18, 21, 44, 50)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 21, 44, 50)
#      datetime.datetime(2023, 3, 18, 21, 45, 25)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 21, 45, 25)
#      datetime.datetime(2023, 3, 18, 21, 46, 5)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 21, 46, 5)
#      datetime.datetime(2023, 3, 18, 21, 47, 10)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 21, 47, 10)
#      datetime.datetime(2023, 3, 18, 21, 47, 55)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 21, 47, 55)
#      datetime.datetime(2023, 3, 18, 21, 48, 50)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 21, 48, 50)
#      datetime.datetime(2023, 3, 18, 21, 50, 35)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 21, 50, 35)
#      datetime.datetime(2023, 3, 18, 21, 53, 20)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 21, 53, 20)
#      datetime.datetime(2023, 3, 18, 21, 58, 35)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 21, 58, 35)
#      datetime.datetime(2023, 3, 18, 22, 0, 50)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 22, 0, 50)
#      datetime.datetime(2023, 3, 18, 22, 2, 55)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 22, 2, 55)
#      datetime.datetime(2023, 3, 18, 22, 8, 10)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 22, 8, 10)
#      datetime.datetime(2023, 3, 18, 22, 10, 5)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 22, 10, 5)
#      datetime.datetime(2023, 3, 18, 22, 12, 15)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 22, 12, 15)
#      datetime.datetime(2023, 3, 18, 22, 15, 50)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 22, 15, 50)
#      datetime.datetime(2023, 3, 18, 22, 18, 30)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 22, 18, 30)
#      datetime.datetime(2023, 3, 18, 22, 23, 15)]>],
#    [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 23, 9, 25)
#      datetime.datetime(2023, 3, 18, 23, 10, 40)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 23, 10, 40)
#      datetime.datetime(2023, 3, 18, 23, 12, 10)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 23, 12, 10)
#      datetime.datetime(2023, 3, 18, 23, 14, 15)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 23, 14, 15)
#      datetime.datetime(2023, 3, 18, 23, 14, 50)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 23, 14, 50)
#      datetime.datetime(2023, 3, 18, 23, 15, 20)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 23, 15, 20)
#      datetime.datetime(2023, 3, 18, 23, 15, 50)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 23, 15, 50)
#      datetime.datetime(2023, 3, 18, 23, 16, 20)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 23, 16, 20)
#      datetime.datetime(2023, 3, 18, 23, 16, 50)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 23, 16, 50)
#      datetime.datetime(2023, 3, 18, 23, 17, 20)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 23, 17, 20)
#      datetime.datetime(2023, 3, 18, 23, 18, 30)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 23, 18, 30)
#      datetime.datetime(2023, 3, 18, 23, 19, 35)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 23, 19, 35)
#      datetime.datetime(2023, 3, 18, 23, 23, 40)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 23, 23, 40)
#      datetime.datetime(2023, 3, 18, 23, 25, 15)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 23, 25, 15)
#      datetime.datetime(2023, 3, 18, 23, 26, 40)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 23, 26, 40)
#      datetime.datetime(2023, 3, 18, 23, 30, 5)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 23, 30, 5)
#      datetime.datetime(2023, 3, 18, 23, 31, 25)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 23, 31, 25)
#      datetime.datetime(2023, 3, 18, 23, 34, 55)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 23, 34, 55)
#      datetime.datetime(2023, 3, 18, 23, 38, 35)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 23, 38, 35)
#      datetime.datetime(2023, 3, 18, 23, 41, 10)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 23, 41, 10)
#      datetime.datetime(2023, 3, 18, 23, 45, 20)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 23, 45, 20)
#      datetime.datetime(2023, 3, 18, 23, 46, 20)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 23, 46, 20)
#      datetime.datetime(2023, 3, 18, 23, 50, 15)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 23, 50, 15)
#      datetime.datetime(2023, 3, 18, 23, 53, 5)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 23, 53, 5)
#      datetime.datetime(2023, 3, 18, 23, 57, 45)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 23, 57, 45)
#      datetime.datetime(2023, 3, 19, 0, 0, 5)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 19, 0, 0, 5)
#      datetime.datetime(2023, 3, 19, 0, 2, 15)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 19, 0, 2, 15)
#      datetime.datetime(2023, 3, 19, 0, 7, 20)]>]]],
#  'per_region_quiet_time_intervals': [[[<Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 13, 48, 45)
#      datetime.datetime(2023, 3, 18, 13, 53, 35)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 14, 2, 30)
#      datetime.datetime(2023, 3, 18, 14, 6, 10)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 14, 11, 10)
#      datetime.datetime(2023, 3, 18, 14, 12, 30)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 14, 12, 30)
#      datetime.datetime(2023, 3, 18, 14, 16)]>],
#    [],
#    [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 16, 46, 25)
#      datetime.datetime(2023, 3, 18, 16, 50, 50)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 16, 50, 50)
#      datetime.datetime(2023, 3, 18, 16, 55, 45)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 16, 55, 45)
#      datetime.datetime(2023, 3, 18, 16, 59)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 16, 59)
#      datetime.datetime(2023, 3, 18, 17, 1, 35)]>],
#    [],
#    [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 21, 50, 35)
#      datetime.datetime(2023, 3, 18, 21, 53, 20)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 21, 53, 20)
#      datetime.datetime(2023, 3, 18, 21, 58, 35)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 21, 58, 35)
#      datetime.datetime(2023, 3, 18, 22, 0, 50)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 22, 0, 50)
#      datetime.datetime(2023, 3, 18, 22, 2, 55)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 22, 2, 55)
#      datetime.datetime(2023, 3, 18, 22, 8, 10)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 22, 8, 10)
#      datetime.datetime(2023, 3, 18, 22, 10, 5)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 22, 10, 5)
#      datetime.datetime(2023, 3, 18, 22, 12, 15)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 22, 12, 15)
#      datetime.datetime(2023, 3, 18, 22, 15, 50)]>],
#    [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 23, 9, 25)
#      datetime.datetime(2023, 3, 18, 23, 10, 40)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 23, 10, 40)
#      datetime.datetime(2023, 3, 18, 23, 12, 10)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 23, 30, 5)
#      datetime.datetime(2023, 3, 18, 23, 31, 25)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 23, 31, 25)
#      datetime.datetime(2023, 3, 18, 23, 34, 55)]>]]],
#  'nushift': [70, -30],
#  'regdicts': [[{'radius': 150.0,
#     'centerx': <Quantity 858.9779265 arcsec>,
#     'centery': <Quantity -356.8147197 arcsec>},
#    {'radius': 150.0,
#     'centerx': <Quantity 878.25761642 arcsec>,
#     'centery': <Quantity -440.58908111 arcsec>},
#    {'radius': 150.0,
#     'centerx': <Quantity 844.85332462 arcsec>,
#     'centery': <Quantity -428.21463852 arcsec>},
#    {'radius': 150.0,
#     'centerx': <Quantity 867.24042815 arcsec>,
#     'centery': <Quantity -414.05767496 arcsec>},
#    {'radius': 150.0,
#     'centerx': <Quantity 898.49683611 arcsec>,
#     'centery': <Quantity -410.93943335 arcsec>},
#    {'radius': 150.0,
#     'centerx': <Quantity 847.40354042 arcsec>,
#     'centery': <Quantity -365.8818837 arcsec>}]],
#  'sub_keys': ['18-mar-23_1 region_0'],
#  'res_file_dict(s)': [{'key': '18-mar-23_1',
#    'flare files onlyaia': [],
#    'quiet files onlyaia': [],
#    'flare times ': [],
#    'quiet times ': [<Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 13, 48, 45)
#      datetime.datetime(2023, 3, 18, 13, 53, 35)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 14, 2, 30)
#      datetime.datetime(2023, 3, 18, 14, 6, 10)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 14, 11, 10)
#      datetime.datetime(2023, 3, 18, 14, 12, 30)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 14, 12, 30)
#      datetime.datetime(2023, 3, 18, 14, 16)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 16, 46, 25)
#      datetime.datetime(2023, 3, 18, 16, 50, 50)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 16, 50, 50)
#      datetime.datetime(2023, 3, 18, 16, 55, 45)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 16, 55, 45)
#      datetime.datetime(2023, 3, 18, 16, 59)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 16, 59)
#      datetime.datetime(2023, 3, 18, 17, 1, 35)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 21, 50, 35)
#      datetime.datetime(2023, 3, 18, 21, 53, 20)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 21, 53, 20)
#      datetime.datetime(2023, 3, 18, 21, 58, 35)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 21, 58, 35)
#      datetime.datetime(2023, 3, 18, 22, 0, 50)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 22, 0, 50)
#      datetime.datetime(2023, 3, 18, 22, 2, 55)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 22, 2, 55)
#      datetime.datetime(2023, 3, 18, 22, 8, 10)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 22, 8, 10)
#      datetime.datetime(2023, 3, 18, 22, 10, 5)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 22, 10, 5)
#      datetime.datetime(2023, 3, 18, 22, 12, 15)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 22, 12, 15)
#      datetime.datetime(2023, 3, 18, 22, 15, 50)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 23, 9, 25)
#      datetime.datetime(2023, 3, 18, 23, 10, 40)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 23, 10, 40)
#      datetime.datetime(2023, 3, 18, 23, 12, 10)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 23, 30, 5)
#      datetime.datetime(2023, 3, 18, 23, 31, 25)]>,
#     <Time object: scale='utc' format='datetime' value=[datetime.datetime(2023, 3, 18, 23, 31, 25)
#      datetime.datetime(2023, 3, 18, 23, 34, 55)]>],
#    'rejected times': [],
#    'rejected files': [],
#    'flare files aiaxrt': [],
#    'quiet files aiaxrt': [],
#    'flare xrt times ': [],
#    'quiet xrt times ': [],
#    'flare files no_xrt': [],
#    'quiet files no_xrt': [],
#    'flare files all-inst-gr-corr': ['/Users/jmdunca2/do-dem/DEM_folders//initial_dem_18mar23_1//14-06-10_14-08-15/14-06-10_14-08-15_5.6_7.2_18-mar-23_1ghost_corr_MC_DEM_result_withparams.pickle',
#     '/Users/jmdunca2/do-dem/DEM_folders//initial_dem_18mar23_1//14-08-15_14-09-20/14-08-15_14-09-20_5.6_7.2_18-mar-23_1ghost_corr_MC_DEM_result_withparams.pickle',
#     '/Users/jmdunca2/do-dem/DEM_folders//initial_dem_18mar23_1//14-09-20_14-11-10/14-09-20_14-11-10_5.6_7.2_18-mar-23_1ghost_corr_MC_DEM_result_withparams.pickle',
#     '/Users/jmdunca2/do-dem/DEM_folders//initial_dem_18mar23_1//15-30-50_15-33-15/15-30-50_15-33-15_5.6_7.2_18-mar-23_1ghost_corr_MC_DEM_result_withparams.pickle',
#     '/Users/jmdunca2/do-dem/DEM_folders//initial_dem_18mar23_1//15-33-15_15-44-00/15-33-15_15-44-00_5.6_7.2_18-mar-23_1ghost_corr_MC_DEM_result_withparams.pickle',
#     '/Users/jmdunca2/do-dem/DEM_folders//initial_dem_18mar23_1//15-44-00_15-46-25/15-44-00_15-46-25_5.6_7.2_18-mar-23_1ghost_corr_MC_DEM_result_withparams.pickle',
#     '/Users/jmdunca2/do-dem/DEM_folders//initial_dem_18mar23_1//15-46-25_15-48-50/15-46-25_15-48-50_5.6_7.2_18-mar-23_1ghost_corr_MC_DEM_result_withparams.pickle',
#     '/Users/jmdunca2/do-dem/DEM_folders//initial_dem_18mar23_1//15-48-50_15-50-10/15-48-50_15-50-10_5.6_7.2_18-mar-23_1ghost_corr_MC_DEM_result_withparams.pickle',
#     '/Users/jmdunca2/do-dem/DEM_folders//initial_dem_18mar23_1//15-50-10_15-53-15/15-50-10_15-53-15_5.6_7.2_18-mar-23_1ghost_corr_MC_DEM_result_withparams.pickle',
#     '/Users/jmdunca2/do-dem/DEM_folders//initial_dem_18mar23_1//15-53-15_15-56-05/15-53-15_15-56-05_5.6_7.2_18-mar-23_1ghost_corr_MC_DEM_result_withparams.pickle',
#     '/Users/jmdunca2/do-dem/DEM_folders//initial_dem_18mar23_1//16-43-35_16-46-25/16-43-35_16-46-25_5.6_7.2_18-mar-23_1ghost_corr_MC_DEM_result_withparams.pickle'],
#    'quiet files all-inst-gr-corr': ['/Users/jmdunca2/do-dem/DEM_folders//initial_dem_18mar23_1//13-48-45_13-53-35/13-48-45_13-53-35_5.6_7.2_18-mar-23_1ghost_corr_MC_DEM_result_withparams.pickle',
#     '/Users/jmdunca2/do-dem/DEM_folders//initial_dem_18mar23_1//14-02-30_14-06-10/14-02-30_14-06-10_5.6_7.2_18-mar-23_1ghost_corr_MC_DEM_result_withparams.pickle',
#     '/Users/jmdunca2/do-dem/DEM_folders//initial_dem_18mar23_1//14-11-10_14-12-30/14-11-10_14-12-30_5.6_7.2_18-mar-23_1ghost_corr_MC_DEM_result_withparams.pickle',
#     '/Users/jmdunca2/do-dem/DEM_folders//initial_dem_18mar23_1//14-12-30_14-16-00/14-12-30_14-16-00_5.6_7.2_18-mar-23_1ghost_corr_MC_DEM_result_withparams.pickle',
#     '/Users/jmdunca2/do-dem/DEM_folders//initial_dem_18mar23_1//16-46-25_16-50-50/16-46-25_16-50-50_5.6_7.2_18-mar-23_1ghost_corr_MC_DEM_result_withparams.pickle',
#     '/Users/jmdunca2/do-dem/DEM_folders//initial_dem_18mar23_1//16-50-50_16-55-45/16-50-50_16-55-45_5.6_7.2_18-mar-23_1ghost_corr_MC_DEM_result_withparams.pickle',
#     '/Users/jmdunca2/do-dem/DEM_folders//initial_dem_18mar23_1//16-55-45_16-59-00/16-55-45_16-59-00_5.6_7.2_18-mar-23_1ghost_corr_MC_DEM_result_withparams.pickle',
#     '/Users/jmdunca2/do-dem/DEM_folders//initial_dem_18mar23_1//16-59-00_17-01-35/16-59-00_17-01-35_5.6_7.2_18-mar-23_1ghost_corr_MC_DEM_result_withparams.pickle',
#     '/Users/jmdunca2/do-dem/DEM_folders//initial_dem_18mar23_1//21-50-35_21-53-20/21-50-35_21-53-20_5.6_7.2_18-mar-23_1ghost_corr_MC_DEM_result_withparams.pickle',
#     '/Users/jmdunca2/do-dem/DEM_folders//initial_dem_18mar23_1//21-53-20_21-58-35/21-53-20_21-58-35_5.6_7.2_18-mar-23_1ghost_corr_MC_DEM_result_withparams.pickle',
#     '/Users/jmdunca2/do-dem/DEM_folders//initial_dem_18mar23_1//21-58-35_22-00-50/21-58-35_22-00-50_5.6_7.2_18-mar-23_1ghost_corr_MC_DEM_result_withparams.pickle',
#     '/Users/jmdunca2/do-dem/DEM_folders//initial_dem_18mar23_1//22-00-50_22-02-55/22-00-50_22-02-55_5.6_7.2_18-mar-23_1ghost_corr_MC_DEM_result_withparams.pickle',
#     '/Users/jmdunca2/do-dem/DEM_folders//initial_dem_18mar23_1//22-02-55_22-08-10/22-02-55_22-08-10_5.6_7.2_18-mar-23_1ghost_corr_MC_DEM_result_withparams.pickle',
#     '/Users/jmdunca2/do-dem/DEM_folders//initial_dem_18mar23_1//22-08-10_22-10-05/22-08-10_22-10-05_5.6_7.2_18-mar-23_1ghost_corr_MC_DEM_result_withparams.pickle',
#     '/Users/jmdunca2/do-dem/DEM_folders//initial_dem_18mar23_1//22-10-05_22-12-15/22-10-05_22-12-15_5.6_7.2_18-mar-23_1ghost_corr_MC_DEM_result_withparams.pickle',
#     '/Users/jmdunca2/do-dem/DEM_folders//initial_dem_18mar23_1//22-12-15_22-15-50/22-12-15_22-15-50_5.6_7.2_18-mar-23_1ghost_corr_MC_DEM_result_withparams.pickle',
#     '/Users/jmdunca2/do-dem/DEM_folders//initial_dem_18mar23_1//23-09-25_23-10-40/23-09-25_23-10-40_5.6_7.2_18-mar-23_1ghost_corr_MC_DEM_result_withparams.pickle',
#     '/Users/jmdunca2/do-dem/DEM_folders//initial_dem_18mar23_1//23-10-40_23-12-10/23-10-40_23-12-10_5.6_7.2_18-mar-23_1ghost_corr_MC_DEM_result_withparams.pickle',
#     '/Users/jmdunca2/do-dem/DEM_folders//initial_dem_18mar23_1//23-30-05_23-31-25/23-30-05_23-31-25_5.6_7.2_18-mar-23_1ghost_corr_MC_DEM_result_withparams.pickle',
#     '/Users/jmdunca2/do-dem/DEM_folders//initial_dem_18mar23_1//23-31-25_23-34-55/23-31-25_23-34-55_5.6_7.2_18-mar-23_1ghost_corr_MC_DEM_result_withparams.pickle'],
#    'flare files all-inst': [],
#    'quiet files all-inst': ['/Users/jmdunca2/do-dem/DEM_folders//initial_dem_18mar23_1//13-48-45_13-53-35/13-48-45_13-53-35_5.6_7.2_18-mar-23_1_MC_DEM_result_withparams.pickle',
#     '/Users/jmdunca2/do-dem/DEM_folders//initial_dem_18mar23_1//14-02-30_14-06-10/14-02-30_14-06-10_5.6_7.2_18-mar-23_1_MC_DEM_result_withparams.pickle',
#     '/Users/jmdunca2/do-dem/DEM_folders//initial_dem_18mar23_1//14-11-10_14-12-30/14-11-10_14-12-30_5.6_7.2_18-mar-23_1_MC_DEM_result_withparams.pickle',
#     '/Users/jmdunca2/do-dem/DEM_folders//initial_dem_18mar23_1//14-12-30_14-16-00/14-12-30_14-16-00_5.6_7.2_18-mar-23_1_MC_DEM_result_withparams.pickle',
#     '/Users/jmdunca2/do-dem/DEM_folders//initial_dem_18mar23_1//16-46-25_16-50-50/16-46-25_16-50-50_5.6_7.2_18-mar-23_1_MC_DEM_result_withparams.pickle',
#     '/Users/jmdunca2/do-dem/DEM_folders//initial_dem_18mar23_1//16-50-50_16-55-45/16-50-50_16-55-45_5.6_7.2_18-mar-23_1_MC_DEM_result_withparams.pickle',
#     '/Users/jmdunca2/do-dem/DEM_folders//initial_dem_18mar23_1//16-55-45_16-59-00/16-55-45_16-59-00_5.6_7.2_18-mar-23_1_MC_DEM_result_withparams.pickle',
#     '/Users/jmdunca2/do-dem/DEM_folders//initial_dem_18mar23_1//16-59-00_17-01-35/16-59-00_17-01-35_5.6_7.2_18-mar-23_1_MC_DEM_result_withparams.pickle',
#     '/Users/jmdunca2/do-dem/DEM_folders//initial_dem_18mar23_1//21-50-35_21-53-20/21-50-35_21-53-20_5.6_7.2_18-mar-23_1_MC_DEM_result_withparams.pickle',
#     '/Users/jmdunca2/do-dem/DEM_folders//initial_dem_18mar23_1//21-53-20_21-58-35/21-53-20_21-58-35_5.6_7.2_18-mar-23_1_MC_DEM_result_withparams.pickle',
#     '/Users/jmdunca2/do-dem/DEM_folders//initial_dem_18mar23_1//21-58-35_22-00-50/21-58-35_22-00-50_5.6_7.2_18-mar-23_1_MC_DEM_result_withparams.pickle',
#     '/Users/jmdunca2/do-dem/DEM_folders//initial_dem_18mar23_1//22-00-50_22-02-55/22-00-50_22-02-55_5.6_7.2_18-mar-23_1_MC_DEM_result_withparams.pickle',
#     '/Users/jmdunca2/do-dem/DEM_folders//initial_dem_18mar23_1//22-02-55_22-08-10/22-02-55_22-08-10_5.6_7.2_18-mar-23_1_MC_DEM_result_withparams.pickle',
#     '/Users/jmdunca2/do-dem/DEM_folders//initial_dem_18mar23_1//22-08-10_22-10-05/22-08-10_22-10-05_5.6_7.2_18-mar-23_1_MC_DEM_result_withparams.pickle',
#     '/Users/jmdunca2/do-dem/DEM_folders//initial_dem_18mar23_1//22-10-05_22-12-15/22-10-05_22-12-15_5.6_7.2_18-mar-23_1_MC_DEM_result_withparams.pickle',
#     '/Users/jmdunca2/do-dem/DEM_folders//initial_dem_18mar23_1//22-12-15_22-15-50/22-12-15_22-15-50_5.6_7.2_18-mar-23_1_MC_DEM_result_withparams.pickle',
#     '/Users/jmdunca2/do-dem/DEM_folders//initial_dem_18mar23_1//23-09-25_23-10-40/23-09-25_23-10-40_5.6_7.2_18-mar-23_1_MC_DEM_result_withparams.pickle',
#     '/Users/jmdunca2/do-dem/DEM_folders//initial_dem_18mar23_1//23-10-40_23-12-10/23-10-40_23-12-10_5.6_7.2_18-mar-23_1_MC_DEM_result_withparams.pickle',
#     '/Users/jmdunca2/do-dem/DEM_folders//initial_dem_18mar23_1//23-30-05_23-31-25/23-30-05_23-31-25_5.6_7.2_18-mar-23_1_MC_DEM_result_withparams.pickle',
#     '/Users/jmdunca2/do-dem/DEM_folders//initial_dem_18mar23_1//23-31-25_23-34-55/23-31-25_23-34-55_5.6_7.2_18-mar-23_1_MC_DEM_result_withparams.pickle']}],
#  'HARP params': [],
#  'Region Ages': [],
#  'ghost_ray_flag': True}

# %%
# with open('/Users/jmdunca2/do-dem/reference_files/all_targets_postghost_postshut.pickle', 'rb') as f:
#     all_targets = pickle.load(f)

# print(all_targets.keys())
    
# all_targets.pop('18-mar-23_1')

# print(all_targets.keys())

# with open('/Users/jmdunca2/do-dem/reference_files/all_targets_postghost_postshut.pickle', 'wb') as f:
#         # Pickle the 'data' dictionary using the highest protocol available.
#         pickle.dump(all_targets, f, pickle.HIGHEST_PROTOCOL)
# Out:
# dict_keys(['01-nov-14_1', '01-nov-14_2', '11-dec-14', '19-feb-16', '22-apr-16_1', '22-apr-16_2', '26-jul-16_1', '27-jul-16_1', '26-jul-16_2', '10-oct-17', '29-may-18_1', '29-may-18_2', '07-sep-18', '09-sep-18', '10-sep-18', '12-apr-19', '13-apr-19', '29-jan-20', '06-jun-20', '07-jun-20', '08-jun-20', '09-jun-20', '08-jan-21', '14-jan-21', '20-jan-21', '29-apr-21', '03-may-21_1', '03-may-21_2', '30-jul-21_1', '30-jul-21_2', '17-nov-21_1', '19-nov-21', '20-nov-21', '22-nov-21_1', '22-nov-21_2', '03-jun-22_1', '03-jun-22_2', '06-sep-22', '09-dec-22', '17-nov-21_2', '21-nov-21', '30-jan-20', '20-jul-21', '24-feb-22', '25-feb-22', '27-feb-22', '18-mar-23_1', '18-mar-23_2', '11-dec-22_2'])
# dict_keys(['01-nov-14_1', '01-nov-14_2', '11-dec-14', '19-feb-16', '22-apr-16_1', '22-apr-16_2', '26-jul-16_1', '27-jul-16_1', '26-jul-16_2', '10-oct-17', '29-may-18_1', '29-may-18_2', '07-sep-18', '09-sep-18', '10-sep-18', '12-apr-19', '13-apr-19', '29-jan-20', '06-jun-20', '07-jun-20', '08-jun-20', '09-jun-20', '08-jan-21', '14-jan-21', '20-jan-21', '29-apr-21', '03-may-21_1', '03-may-21_2', '30-jul-21_1', '30-jul-21_2', '17-nov-21_1', '19-nov-21', '20-nov-21', '22-nov-21_1', '22-nov-21_2', '03-jun-22_1', '03-jun-22_2', '06-sep-22', '09-dec-22', '17-nov-21_2', '21-nov-21', '30-jan-20', '20-jul-21', '24-feb-22', '25-feb-22', '27-feb-22', '18-mar-23_2', '11-dec-22_2'])

# %%
# with open('/Users/jmdunca2/do-dem/reference_files/all_targets_postghost_postshut.pickle', 'rb') as f:
#     all_targets = pickle.load(f)

# print(all_targets.keys())
# Out:
# dict_keys(['01-nov-14_1', '01-nov-14_2', '11-dec-14', '19-feb-16', '22-apr-16_1', '22-apr-16_2', '26-jul-16_1', '27-jul-16_1', '26-jul-16_2', '10-oct-17', '29-may-18_1', '29-may-18_2', '07-sep-18', '09-sep-18', '10-sep-18', '12-apr-19', '13-apr-19', '29-jan-20', '06-jun-20', '07-jun-20', '08-jun-20', '09-jun-20', '08-jan-21', '14-jan-21', '20-jan-21', '29-apr-21', '03-may-21_1', '03-may-21_2', '30-jul-21_1', '30-jul-21_2', '17-nov-21_1', '19-nov-21', '20-nov-21', '22-nov-21_1', '22-nov-21_2', '03-jun-22_1', '03-jun-22_2', '06-sep-22', '09-dec-22', '17-nov-21_2', '21-nov-21', '30-jan-20', '20-jul-21', '24-feb-22', '25-feb-22', '27-feb-22', '18-mar-23_2', '11-dec-22_2'])
